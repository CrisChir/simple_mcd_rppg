# %%
import os
import json
import math
from pathlib import Path
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.signal import butter, filtfilt, welch
import random
from torch.optim.lr_scheduler import LinearLR, CosineAnnealingLR, SequentialLR

# Configure high-quality visualization styles
plt.style.use('seaborn-v0_8-whitegrid' if 'seaborn-v0_8-whitegrid' in plt.style.available else 'default')
sns.set_palette("muted")

# Setup default configurations
PREPROCESSED_DATA_PATH = Path('/home/cristic/preprocessed_data/')
CACHE_FILES = ["valid_files.txt", "train_files_cache.txt", "val_files_cache.txt"]
# Force usage of the second GPU (index 1)
gpu_id = 1 
DEVICE = torch.device(f'cuda:{gpu_id}' if torch.cuda.is_available() else 'cpu')
MODEL_SAVE_PATH = Path("spatiotemporal_physnet_best_shuffle.pth")

# Clean existing cache files before starting run
for cache in CACHE_FILES:
    if os.path.exists(cache):
        try:
            os.remove(cache)
            print(f"Removed old cache: {cache}")
        except Exception as e:
            print(f"Error removing cache {cache}: {e}")

# Strict order representing the 9 sub-ROIs + full face boundary configurations
ROI_ORDER = [
    'roi_forehead',
    'roi_left_cheek_280',
    'roi_right_cheek_50',
    'roi_nose',
    'roi_chin',
    'roi_chin_199',
    'roi_left_eye',
    'roi_right_eye',
    'roi_mouth',
    'roi_full_face'
]

def inspect_npz_color_space(npz_path, roi_key='roi_forehead'):
    """
    Diagnose NPZ color-space representations and plot channel intensities.
    Ensures RGB channels align with spatial tracking configurations.
    """
    print(f"\nEvaluating color space for path: {npz_path}")
    if not os.path.exists(npz_path):
        print(f"Color Space Inspector Notice: Sample {npz_path} does not exist yet.")
        return

    with np.load(npz_path) as data:
        if roi_key not in data:
            available = [k for k in data.keys() if k.startswith('roi_')]
            if not available:
                print("No ROIs found in file keys.")
                return
            print(f"Key '{roi_key}' not found. Available ROIs: {available}")
            roi_key = available[0]
            
        roi_data = data[roi_key]
        
    print(f"Loaded '{roi_key}' with shape: {roi_data.shape} and dtype: {roi_data.dtype}")
    
    first_frame = roi_data[0].copy()
    
    if first_frame.max() > 1.0:
        first_frame_norm = first_frame.astype(np.float32) / 255.0
    else:
        first_frame_norm = first_frame.astype(np.float32)
        
    c0 = first_frame_norm[:, :, 0]
    c1 = first_frame_norm[:, :, 1]
    c2 = first_frame_norm[:, :, 2]
    
    mean_c0, mean_c1, mean_c2 = c0.mean(), c1.mean(), c2.mean()
    
    print("\n--- Channel Intensity Statistics ---")
    print(f"Channel 0 Mean: {mean_c0:.4f}")
    print(f"Channel 1 Mean: {mean_c1:.4f}")
    print(f"Channel 2 Mean: {mean_c2:.4f}")
    print("------------------------------------\n")
    
    fig, axes = plt.subplots(1, 4, figsize=(16, 4))
    
    axes[0].imshow(first_frame_norm)
    axes[0].set_title("Direct Render (Assumes RGB)")
    axes[0].axis('off')
    
    im0 = axes[1].imshow(c0, cmap='gray', vmin=0, vmax=1)
    axes[1].set_title(f"Channel 0\n(Mean: {mean_c0:.3f})")
    axes[1].axis('off')
    plt.colorbar(im0, ax=axes[1], fraction=0.046, pad=0.04)
    
    im1 = axes[2].imshow(c1, cmap='gray', vmin=0, vmax=1)
    axes[2].set_title(f"Channel 1\n(Mean: {mean_c1:.3f})")
    axes[2].axis('off')
    plt.colorbar(im1, ax=axes[2], fraction=0.046, pad=0.04)
    
    im2 = axes[3].imshow(c2, cmap='gray', vmin=0, vmax=1)
    axes[3].set_title(f"Channel 2\n(Mean: {mean_c2:.3f})")
    axes[3].axis('off')
    plt.colorbar(im2, ax=axes[3], fraction=0.046, pad=0.04)
    
    plt.tight_layout()
    plt.show()

def butter_bandpass_filter(data, lowcut=0.75, highcut=2.5, fs=30.0, order=4):
    """Apply zero-phase Butterworth bandpass filter to capture human heart rate (45-150 BPM)."""
    nyq = 0.5 * fs
    low = lowcut / nyq
    high = highcut / nyq
    b, a = butter(order, [low, high], btype='band')
    return filtfilt(b, a, data)

def calculate_bpm_from_fft(signal_1d, fs=30.0, lowcut=0.75, highcut=2.5):
    """Extract heart rate (BPM) from the dominant peak of the Power Spectral Density."""
    signal_cleaned = signal_1d - np.mean(signal_1d)
    freqs, psd = welch(signal_cleaned, fs=fs, nperseg=len(signal_cleaned))
    
    valid_idx = np.where((freqs >= lowcut) & (freqs <= highcut))[0]
    if len(valid_idx) == 0:
        return 75.0
    
    peak_freq = freqs[valid_idx[np.argmax(psd[valid_idx])]]
    return peak_freq * 60.0

def load_npz_file(file_path):
    """Securely load and parse an NPZ file."""
    try:
        data = np.load(file_path, allow_pickle=True)
        return data
    except Exception as e:
        print(f"Error loading {file_path}: {e}")
        return None

def analyze_npz_structure(data):
    """Analyze and print the metadata keys and array dimensions of loaded files."""
    if data is None:
        print("NPZ Analysis Error: Provided data object is None.")
        return
    print("\n" + "=" * 75)
    print("               NPZ FILE STRUCTURE SHOWCASE (9-ROI + Face Configuration)")
    print("=" * 75)
    for key in sorted(data.files):
        item = data[key]
        if hasattr(item, 'shape'):
            print(f"  {key:<27} : Shape {str(item.shape):<20} | Dtype {item.dtype}")
        else:
            print(f"  {key:<27} : Metadata / Scalar Object")
    print("=" * 75 + "\n")

def create_synthetic_dataset(target_dir, num_files=6, num_frames=450):
    """Generate mock datasets matching strict multi-ROI formatting standards."""
    target_dir.mkdir(parents=True, exist_ok=True)
    print(f"\nTarget dataset directory '{target_dir}' is empty or missing.")
    print("Generating synthetic 9-ROI + face NPZ dataset mimicking real schemas...")
    
    fs = 30.0
    t = np.arange(num_frames) / fs
    
    for i in range(num_files):
        hr_hz = np.random.uniform(1.0, 1.5)
        bvp = np.sin(2 * np.pi * hr_hz * t) + 0.35 * np.sin(2 * np.pi * (hr_hz * 2) * t)
        bvp += 0.2 * np.sin(2 * np.pi * 0.2 * t)
        bvp = (bvp - np.mean(bvp)) / (np.std(bvp) + 1e-8)
        
        data_dict = {
            'time_deltas': (t * 1000.0).astype(np.float64),
            'ppg_values': bvp.astype(np.float64)
        }
        
        for roi in ROI_ORDER:
            base_skin = np.array([185.0, 125.0, 105.0]) if "eye" not in roi else np.array([210.0, 190.0, 180.0])
            pixel_noise = np.random.normal(0, 1.2, size=(num_frames, 24, 24, 3))
            
            pulse_modulator = np.zeros((num_frames, 24, 24, 3))
            pulse_modulator[..., 0] = bvp[:, None, None] * 0.15
            pulse_modulator[..., 1] = bvp[:, None, None] * 0.55
            pulse_modulator[..., 2] = bvp[:, None, None] * 0.05
            
            roi_frames = (base_skin + pulse_modulator + pixel_noise).clip(0, 255).astype(np.uint8)
            data_dict[roi] = roi_frames
            
        np.savez(target_dir / f"subject_{i+1:02d}_session_01.npz", **data_dict)
    print("Synthetic dataset successfully created!\n")

class PPGMultiROIDataset(Dataset):
    """Optimized Dataset class with inline spatial and temporal sequence augmentations."""
    def __init__(self, file_paths, sequence_length=450, fs=30.0, augment=False):
        self.file_paths = file_paths
        self.sequence_length = sequence_length
        self.fs = fs
        self.augment = augment
        self.samples = []
        
        self._prepare_samples()

    def _prepare_samples(self):
        """Pre-segment matching timelines into sequence lengths."""
        for path in self.file_paths:
            data = load_npz_file(path)
            if data is None:
                continue
            
            ppg_key = 'ppg_values' if 'ppg_values' in data else 'ppg'
            length = len(data[ppg_key])
            num_windows = length // self.sequence_length
            
            for w in range(num_windows):
                start_idx = w * self.sequence_length
                end_idx = start_idx + self.sequence_length
                self.samples.append((path, start_idx, end_idx))

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        file_path, start, end = self.samples[idx]
        data = load_npz_file(file_path)
        
        ppg_key = 'ppg_values' if 'ppg_values' in data else 'ppg'
        ppg_segment = data[ppg_key][start:end]
        ppg_segment = butter_bandpass_filter(ppg_segment, fs=self.fs)
        ppg_normalized = (ppg_segment - np.mean(ppg_segment)) / (np.std(ppg_segment) + 1e-8)
        
        roi_inputs = []
        for roi_name in ROI_ORDER:
            actual_key = next((k for k in data.files if roi_name == k), None)
            
            if actual_key is not None:
                roi_data = data[actual_key][start:end]
            else:
                roi_data = np.zeros((self.sequence_length, 24, 24, 3), dtype=np.uint8)
                
            roi_data = roi_data.astype(np.float32) / 255.0
            roi_inputs.append(roi_data)
            
        # Perform coordinated sequence augmentations across all 10 regions
        if self.augment:
            # 50% chance of random horizontal flip
            if np.random.rand() > 0.5:
                roi_inputs = [np.flip(roi, axis=2) for roi in roi_inputs]
                
            # 50% chance of random vertical flip
            if np.random.rand() > 0.5:
                roi_inputs = [np.flip(roi, axis=1) for roi in roi_inputs]
                
            # 50% chance of brightness jittering
            if np.random.rand() > 0.5:
                brightness_factor = np.random.uniform(0.9, 1.1)
                roi_inputs = [np.clip(roi * brightness_factor, 0.0, 1.0) for roi in roi_inputs]
                
        # Structure dimension mapping: (10, T, H, W, C) -> (10, C, T, H, W) -> (10 * C, T, H, W)
        stacked_rois = np.stack(roi_inputs, axis=0)
        stacked_rois = np.transpose(stacked_rois, (0, 4, 1, 2, 3))
        stacked_rois = np.reshape(stacked_rois, (10 * 3, self.sequence_length, 24, 24))
        
        return torch.tensor(stacked_rois, dtype=torch.float32), torch.tensor(ppg_normalized, dtype=torch.float32)

class SpatioTemporalPhysNet(nn.Module):
    """
    Spatio-Temporal convolutional network engineered to extract micro-color variations
    harmoniously across 10 face zones (30 raw input channels).
    """
    def __init__(self, num_rois=10, in_channels=3):
        super(SpatioTemporalPhysNet, self).__init__()
        self.num_rois = num_rois
        self.total_channels = num_rois * in_channels
        
        self.spatial_conv = nn.Sequential(
            nn.Conv3d(self.total_channels, 64, kernel_size=(1, 3, 3), padding=(0, 1, 1)),
            nn.BatchNorm3d(64),
            nn.ELU(),
            nn.AdaptiveAvgPool3d((None, 1, 1))
        )
        
        self.temporal_encoder = nn.Sequential(
            nn.Conv1d(64, 32, kernel_size=5, padding=2),
            nn.BatchNorm1d(32),
            nn.ELU(),
            nn.Conv1d(32, 16, kernel_size=5, padding=2),
            nn.BatchNorm1d(16),
            nn.ELU(),
            nn.Conv1d(16, 1, kernel_size=1)
        )

    def forward(self, x):
        x_spatial = self.spatial_conv(x)
        x_spatial = torch.squeeze(x_spatial, dim=-1)
        x_spatial = torch.squeeze(x_spatial, dim=-1)
        
        ppg_pred = self.temporal_encoder(x_spatial)
        return torch.squeeze(ppg_pred, dim=1)

class NegativePearsonCorrelationLoss(nn.Module):
    """Loss module measuring BVP signal phase synchronization."""
    def __init__(self):
        super(NegativePearsonCorrelationLoss, self).__init__()

    def forward(self, pred, target):
        pred_mean = torch.mean(pred, dim=-1, keepdim=True)
        target_mean = torch.mean(target, dim=-1, keepdim=True)
        
        pred_centered = pred - pred_mean
        target_centered = target - target_mean
        
        r_num = torch.sum(pred_centered * target_centered, dim=-1)
        r_den = torch.sqrt(torch.sum(pred_centered ** 2, dim=-1) * torch.sum(target_centered ** 2, dim=-1) + 1e-8)
        
        pearson_coeff = r_num / r_den
        return 1.0 - torch.mean(pearson_coeff)

def calculate_metrics(y_pred, y_true, fs=30.0):
    """Extract performance evaluation metrics (PCC, MAE, RMSE, and SNR)."""
    pcc_list, mae_list, rmse_list, snr_list = [], [], [], []
    
    for i in range(len(y_pred)):
        pred, true = y_pred[i], y_true[i]
        
        pcc = np.corrcoef(pred, true)[0, 1]
        pcc_list.append(0.0 if np.isnan(pcc) else pcc)
        
        bpm_pred = calculate_bpm_from_fft(pred, fs=fs)
        bpm_true = calculate_bpm_from_fft(true, fs=fs)
        
        mae_list.append(abs(bpm_pred - bpm_true))
        rmse_list.append((bpm_pred - bpm_true) ** 2)
        
        pred_detrended = pred - np.mean(pred)
        freqs, psd = welch(pred_detrended, fs=fs, nperseg=len(pred_detrended))
        
        gt_freq = bpm_true / 60.0
        signal_mask = (freqs >= (gt_freq - 0.15)) & (freqs <= (gt_freq + 0.15))
        noise_mask = ~signal_mask & (freqs >= 0.75) & (freqs <= 2.5)
        
        signal_power = np.sum(psd[signal_mask])
        noise_power = np.sum(psd[noise_mask]) + 1e-8
        snr_list.append(10 * np.log10(signal_power / noise_power))
        
    return {
        'PCC': np.mean(pcc_list),
        'MAE': np.mean(mae_list),
        'RMSE': math.sqrt(np.mean(rmse_list)),
        'SNR': np.mean(snr_list)
    }

def save_model_checkpoint(model, optimizer, epoch, metrics, save_path=MODEL_SAVE_PATH):
    """Save model checkpoint along with optimizer state and validation metrics."""
    checkpoint = {
        'epoch': epoch,
        'model_state_dict': model.state_dict(),
        'optimizer_state_dict': optimizer.state_dict(),
        'metrics': metrics
    }
    torch.save(checkpoint, save_path)
    print(f"Model checkpoint successfully saved to: {save_path}")

# def load_model_checkpoint(save_path, model, optimizer=None):
#     """Load model weights and optional optimizer states from a checkpoint."""
#     if not os.path.exists(save_path):
#         print(f"Checkpoint path {save_path} does not exist.")
#         return None
#     checkpoint = torch.load(save_path, map_location=DEVICE)
#     model.load_state_dict(checkpoint['model_state_dict'])
#     if optimizer is not None and 'optimizer_state_dict' in checkpoint:
#         optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
#     print(f"Loaded model checkpoint from: {save_path} (Epoch {checkpoint.get('epoch', 'N/A')})")
#     return checkpoint

if not any(PREPROCESSED_DATA_PATH.glob('*.npz')):
    create_synthetic_dataset(PREPROCESSED_DATA_PATH, num_files=6)

npz_files = sorted(list(PREPROCESSED_DATA_PATH.glob('*.npz')))
print(f"Total files available for analysis: {len(npz_files)}")

first_file_data = load_npz_file(npz_files[0])
analyze_npz_structure(first_file_data)
inspect_npz_color_space(npz_files[0])
###shuffle files
random.seed(42)
shuffled_files = npz_files.copy()
random.shuffle(shuffled_files)

# Perform split on the shuffled list
split_idx = int(len(shuffled_files) * 0.75)
train_split = shuffled_files[:split_idx]
val_split = shuffled_files[split_idx:]

# train_split = npz_files[:int(len(npz_files) * 0.75)]
# val_split = npz_files[int(len(npz_files) * 0.75):]

train_dataset = PPGMultiROIDataset(train_split, augment=True)
val_dataset = PPGMultiROIDataset(val_split, augment=False)

train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True,prefetch_factor=4,num_workers=8, pin_memory=True, persistent_workers=True)
val_loader = DataLoader(train_dataset, batch_size=16, shuffle=True,prefetch_factor=4,num_workers=8, pin_memory=True, persistent_workers=True)

# model = SpatioTemporalPhysNet(num_rois=10).to(DEVICE)
# criterion_pearson = NegativePearsonCorrelationLoss()
# criterion_mse = nn.MSELoss()
# # optimizer = optim.Adam(model.parameters(), lr=1e-3, weight_decay=1e-4)

# optimizer = torch.optim.AdamW(model.parameters(), lr=3e-4, weight_decay=1e-2)
# # scheduler = CosineAnnealingLR(optimizer, T_max=50, eta_min=1e-6)


# num_epochs = 75
# warmup_epochs = 5
# train_losses, val_losses = [], []
# # scheduler = CosineAnnealingLR(optimizer, T_max=num_epochs, eta_min=1e-6)
# scheduler1 = LinearLR(optimizer, start_factor=0.1, total_iters=warmup_epochs)
# scheduler2 = CosineAnnealingLR(optimizer, T_max=num_epochs - warmup_epochs, eta_min=1e-6)
# scheduler = SequentialLR(optimizer, schedulers=[scheduler1, scheduler2], milestones=[warmup_epochs])
# print("Starting optimization loop...")

# for epoch in range(num_epochs):
#     model.train()
#     running_loss = 0.0
#     for inputs, targets in train_loader:
#         inputs, targets = inputs.to(DEVICE), targets.to(DEVICE)
        
#         optimizer.zero_grad()
#         outputs = model(inputs)
        
#         loss = criterion_pearson(outputs, targets) + 0.3 * criterion_mse(outputs, targets)
#         loss.backward()
#         optimizer.step()
        
#         running_loss += loss.item() * inputs.size(0)
        
#     train_loss = running_loss / len(train_loader.dataset)
#     train_losses.append(train_loss)
    
#     model.eval()
#     running_val_loss = 0.0
#     with torch.no_grad():
#         for val_inputs, val_targets in val_loader:
#             val_inputs, val_targets = val_inputs.to(DEVICE), val_targets.to(DEVICE)
#             val_outputs = model(val_inputs)
#             val_loss = criterion_pearson(val_outputs, val_targets) + 0.3 * criterion_mse(val_outputs, val_targets)
#             running_val_loss += val_loss.item() * val_inputs.size(0)
            
#     val_loss = running_val_loss / len(val_loader.dataset)
#     val_losses.append(val_loss)
    
#     print(f"Epoch {epoch+1:02d}/{num_epochs:02d} | Train Loss: {train_loss:.4f} | Val Loss: {val_loss:.4f}")

# model.eval()
# all_preds, all_trues = [], []

# with torch.no_grad():
#     for val_inputs, val_targets in val_loader:
#         val_inputs = val_inputs.to(DEVICE)
#         preds = model(val_inputs).cpu().numpy()
#         all_preds.extend(preds)
#         all_trues.extend(val_targets.numpy())

# all_preds, all_trues = np.array(all_preds), np.array(all_trues)
# metrics = calculate_metrics(all_preds, all_trues)

# print("\n" + "=" * 50)
# print("              VAL METRICS EVALUATION")
# print("=" * 50)
# print(f"  Pearson Correlation Coefficient (PCC) : {metrics['PCC']:.4f}")
# print(f"  Mean Absolute Error (MAE)            : {metrics['MAE']:.2f} BPM")
# print(f"  Root Mean Squared Error (RMSE)       : {metrics['RMSE']:.2f} BPM")
# print(f"  Signal-to-Noise Ratio (SNR)          : {metrics['SNR']:.2f} dB")
# print("=" * 50 + "\n")

# # Save model and demonstrate loading functionality
# ----------------------------------------------------------------------------
# 1. Setup Model, Loss, Optimizer & Scheduler
# ----------------------------------------------------------------------------
model = SpatioTemporalPhysNet(num_rois=10).to(DEVICE)
criterion_pearson = NegativePearsonCorrelationLoss()
criterion_mse = nn.MSELoss()

optimizer = torch.optim.AdamW(model.parameters(), lr=3e-4, weight_decay=1e-2)

num_epochs = 75
warmup_epochs = 5

scheduler1 = LinearLR(optimizer, start_factor=0.1, total_iters=warmup_epochs)
scheduler2 = CosineAnnealingLR(optimizer, T_max=num_epochs - warmup_epochs, eta_min=1e-6)
scheduler = SequentialLR(optimizer, schedulers=[scheduler1, scheduler2], milestones=[warmup_epochs])

# ----------------------------------------------------------------------------
# 2. Checkpointing & Early Stopping Settings
# ----------------------------------------------------------------------------
CHECKPOINT_SAVE_PATH = "best_spatiotemporal_physnet.pt"
patience = 15              # Stop after 15 consecutive epochs without improvement
patience_counter = 0
best_val_loss = float('inf')
best_model_weights = None

train_losses, val_losses = [], []

print("Starting optimization loop...")

# ----------------------------------------------------------------------------
# 3. Training & Validation Loop
# ----------------------------------------------------------------------------
for epoch in range(num_epochs):
    # --- Training Phase ---
    model.train()
    running_loss = 0.0
    
    for inputs, targets in train_loader:
        inputs, targets = inputs.to(DEVICE), targets.to(DEVICE)
        
        optimizer.zero_grad()
        outputs = model(inputs)
        
        loss = criterion_pearson(outputs, targets) + 0.3 * criterion_mse(outputs, targets)
        loss.backward()
        
        # Clip gradients to prevent stability issues in spatio-temporal convolutions
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        
        optimizer.step()
        running_loss += loss.item() * inputs.size(0)
        
    train_loss = running_loss / len(train_loader.dataset)
    train_losses.append(train_loss)
    
    # --- Validation Phase ---
    model.eval()
    running_val_loss = 0.0
    with torch.no_grad():
        for val_inputs, val_targets in val_loader:
            val_inputs, val_targets = val_inputs.to(DEVICE), val_targets.to(DEVICE)
            val_outputs = model(val_inputs)
            
            val_loss = criterion_pearson(val_outputs, val_targets) + 0.3 * criterion_mse(val_outputs, val_targets)
            running_val_loss += val_loss.item() * val_inputs.size(0)
            
    val_loss = running_val_loss / len(val_loader.dataset)
    val_losses.append(val_loss)
    
    # --- Update Scheduler ---
    scheduler.step()
    current_lr = scheduler.get_last_lr()[0]
    
    print(f"Epoch {epoch+1:02d}/{num_epochs:02d} | LR: {current_lr:.6f} | Train Loss: {train_loss:.4f} | Val Loss: {val_loss:.4f}")

    # --- Best Model Checkpointing & Early Stopping Logic ---
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        patience_counter = 0
        # best_model_weights = copy.deepcopy(model.state_dict())
        best_model_weights = {k: v.cpu().clone() for k, v in model.state_dict().items()}
        # Save best model to disk
        torch.save({
            'epoch': epoch + 1,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'val_loss': val_loss,
        }, CHECKPOINT_SAVE_PATH)
        print(f"   ---> Improved! Saved new best model checkpoint to '{CHECKPOINT_SAVE_PATH}' (Val Loss: {val_loss:.4f})")
    else:
        patience_counter += 1
        print(f"   ---> No improvement in validation loss for {patience_counter}/{patience} epochs.")
        if patience_counter >= patience:
            print(f"\n[Early Stopping Triggered] Stopping training early at Epoch {epoch+1}.")
            break

# ----------------------------------------------------------------------------
# 4. Load Best Model Weights for Evaluation
# ----------------------------------------------------------------------------
if best_model_weights is not None:
    print(f"\nLoading best model state dict from memory (Best Val Loss: {best_val_loss:.4f})...")
    model.load_state_dict(best_model_weights)

# ----------------------------------------------------------------------------
# 5. Validation Metrics Evaluation
# ----------------------------------------------------------------------------
model.eval()
all_preds, all_trues = [], []

with torch.no_grad():
    for val_inputs, val_targets in val_loader:
        val_inputs = val_inputs.to(DEVICE)
        preds = model(val_inputs).cpu().numpy()
        all_preds.extend(preds)
        all_trues.extend(val_targets.numpy())

all_preds, all_trues = np.array(all_preds), np.array(all_trues)
metrics = calculate_metrics(all_preds, all_trues)

print("\n" + "=" * 50)
print("              VAL METRICS EVALUATION")
print("=" * 50)
print(f"  Pearson Correlation Coefficient (PCC) : {metrics['PCC']:.4f}")
print(f"  Mean Absolute Error (MAE)            : {metrics['MAE']:.2f} BPM")
print(f"  Root Mean Squared Error (RMSE)       : {metrics['RMSE']:.2f} BPM")
print(f"  Signal-to-Noise Ratio (SNR)          : {metrics['SNR']:.2f} dB")
print("=" * 50 + "\n")

# Demonstration: How to reload from disk in a future session
print(f"Demonstration: Checkpoint stored at '{os.path.abspath(CHECKPOINT_SAVE_PATH)}'")
# Out:
# Total files available for analysis: 20747
#
# ===========================================================================
#                NPZ FILE STRUCTURE SHOWCASE (9-ROI + Face Configuration)
# ===========================================================================
#   landmarks                   : Shape (450, 468, 2)        | Dtype float32
#   meta_camera_type            : Shape ()                   | Dtype <U12
#   meta_chunk_index            : Shape ()                   | Dtype int64
#   meta_condition              : Shape ()                   | Dtype <U5
#   meta_end_frame              : Shape ()                   | Dtype int64
#   meta_num_frames             : Shape ()                   | Dtype int64
#   meta_start_frame            : Shape ()                   | Dtype int64
#   meta_subject_id             : Shape ()                   | Dtype int64
#   meta_view_type              : Shape ()                   | Dtype <U5
#   ppg_values                  : Shape (450,)               | Dtype float64
#   roi_chin                    : Shape (450, 24, 24, 3)     | Dtype uint8
#   roi_chin_199                : Shape (450, 24, 24, 3)     | Dtype uint8
#   roi_forehead                : Shape (450, 24, 24, 3)     | Dtype uint8
#   roi_full_face               : Shape (450, 24, 24, 3)     | Dtype uint8
#   roi_left_cheek_280          : Shape (450, 24, 24, 3)     | Dtype uint8
#   roi_left_eye                : Shape (450, 24, 24, 3)     | Dtype uint8
#   roi_mouth                   : Shape (450, 24, 24, 3)     | Dtype uint8
#   roi_nose                    : Shape (450, 24, 24, 3)     | Dtype uint8
#   roi_right_cheek_50          : Shape (450, 24, 24, 3)     | Dtype uint8
#   roi_right_eye               : Shape (450, 24, 24, 3)     | Dtype uint8
#   time_deltas                 : Shape (450,)               | Dtype float64
#   vital_cholesterol           : Shape ()                   | Dtype float64
#   vital_glycated_hemoglobin   : Shape ()                   | Dtype float64
#   vital_hemoglobin            : Shape ()                   | Dtype float64
#   vital_lower_ap              : Shape ()                   | Dtype float64
#   vital_pulse                 : Shape ()                   | Dtype float64
#   vital_respiratory           : Shape ()                   | Dtype float64
#   vital_rigidity              : Shape ()                   | Dtype float64
#   vital_saturation            : Shape ()                   | Dtype float64
#   vital_stress                : Shape ()                   | Dtype float64
#   vital_upper_ap              : Shape ()                   | Dtype float64
# ===========================================================================
#
#
# Evaluating color space for path: /home/cristic/preprocessed_data/1020_FullHDwebcam_after_chunk0.npz
# Loaded 'roi_forehead' with shape: (450, 24, 24, 3) and dtype: uint8
#
# --- Channel Intensity Statistics ---
# Channel 0 Mean: 0.5472
# Channel 1 Mean: 0.4347
# Channel 2 Mean: 0.3352
# ------------------------------------
# Starting optimization loop...
# Epoch 01/75 | LR: 0.000084 | Train Loss: 1.3089 | Val Loss: 1.3000
#    ---> Improved! Saved new best model checkpoint to 'best_spatiotemporal_physnet.pt' (Val Loss: 1.3000)
# Epoch 02/75 | LR: 0.000138 | Train Loss: 1.2978 | Val Loss: 1.2947
#    ---> Improved! Saved new best model checkpoint to 'best_spatiotemporal_physnet.pt' (Val Loss: 1.2947)
# Epoch 03/75 | LR: 0.000192 | Train Loss: 1.2941 | Val Loss: 1.2922
#    ---> Improved! Saved new best model checkpoint to 'best_spatiotemporal_physnet.pt' (Val Loss: 1.2922)
# Epoch 04/75 | LR: 0.000246 | Train Loss: 1.2928 | Val Loss: 1.2906
#    ---> Improved! Saved new best model checkpoint to 'best_spatiotemporal_physnet.pt' (Val Loss: 1.2906)
# /home/cristic/anaconda3/envs/rppg/lib/python3.11/site-packages/torch/optim/lr_scheduler.py:243: UserWarning: The epoch parameter in `scheduler.step()` was not necessary and is being deprecated where possible. Please use `scheduler.step()` to step the scheduler. During the deprecation, if epoch is different from None, the closed form is used instead of the new chainable form, where available. Please open an issue if you are unable to replicate your use case: https://github.com/pytorch/pytorch/issues/new/choose.
#   warnings.warn(EPOCH_DEPRECATION_WARNING, UserWarning)
# Epoch 05/75 | LR: 0.000300 | Train Loss: 1.2917 | Val Loss: 1.2896
#    ---> Improved! Saved new best model checkpoint to 'best_spatiotemporal_physnet.pt' (Val Loss: 1.2896)
# Epoch 06/75 | LR: 0.000300 | Train Loss: 1.2911 | Val Loss: 1.2895
#    ---> Improved! Saved new best model checkpoint to 'best_spatiotemporal_physnet.pt' (Val Loss: 1.2895)
# Epoch 07/75 | LR: 0.000299 | Train Loss: 1.2898 | Val Loss: 1.2866
#    ---> Improved! Saved new best model checkpoint to 'best_spatiotemporal_physnet.pt' (Val Loss: 1.2866)
# Epoch 08/75 | LR: 0.000299 | Train Loss: 1.2880 | Val Loss: 1.2863
#    ---> Improved! Saved new best model checkpoint to 'best_spatiotemporal_physnet.pt' (Val Loss: 1.2863)
# Epoch 09/75 | LR: 0.000298 | Train Loss: 1.2875 | Val Loss: 1.2868
#    ---> No improvement in validation loss for 1/15 epochs.
# Epoch 10/75 | LR: 0.000296 | Train Loss: 1.2870 | Val Loss: 1.2860
#    ---> Improved! Saved new best model checkpoint to 'best_spatiotemporal_physnet.pt' (Val Loss: 1.2860)
# Epoch 11/75 | LR: 0.000295 | Train Loss: 1.2862 | Val Loss: 1.2865
#    ---> No improvement in validation loss for 1/15 epochs.
# Epoch 12/75 | LR: 0.000293 | Train Loss: 1.2854 | Val Loss: 1.2837
#    ---> Improved! Saved new best model checkpoint to 'best_spatiotemporal_physnet.pt' (Val Loss: 1.2837)
# Epoch 13/75 | LR: 0.000290 | Train Loss: 1.2850 | Val Loss: 1.2817
#    ---> Improved! Saved new best model checkpoint to 'best_spatiotemporal_physnet.pt' (Val Loss: 1.2817)
# Epoch 14/75 | LR: 0.000288 | Train Loss: 1.2842 | Val Loss: 1.2830
#    ---> No improvement in validation loss for 1/15 epochs.
# Epoch 15/75 | LR: 0.000285 | Train Loss: 1.2837 | Val Loss: 1.2822
#    ---> No improvement in validation loss for 2/15 epochs.
# Epoch 16/75 | LR: 0.000282 | Train Loss: 1.2831 | Val Loss: 1.2805
#    ---> Improved! Saved new best model checkpoint to 'best_spatiotemporal_physnet.pt' (Val Loss: 1.2805)
# Epoch 17/75 | LR: 0.000279 | Train Loss: 1.2825 | Val Loss: 1.2817
#    ---> No improvement in validation loss for 1/15 epochs.
# Epoch 18/75 | LR: 0.000275 | Train Loss: 1.2822 | Val Loss: 1.2798
#    ---> Improved! Saved new best model checkpoint to 'best_spatiotemporal_physnet.pt' (Val Loss: 1.2798)
# Epoch 19/75 | LR: 0.000271 | Train Loss: 1.2815 | Val Loss: 1.2830
#    ---> No improvement in validation loss for 1/15 epochs.
# Epoch 20/75 | LR: 0.000267 | Train Loss: 1.2824 | Val Loss: 1.2803
#    ---> No improvement in validation loss for 2/15 epochs.
# Epoch 21/75 | LR: 0.000263 | Train Loss: 1.2815 | Val Loss: 1.2792
#    ---> Improved! Saved new best model checkpoint to 'best_spatiotemporal_physnet.pt' (Val Loss: 1.2792)
# Epoch 22/75 | LR: 0.000259 | Train Loss: 1.2809 | Val Loss: 1.2801
#    ---> No improvement in validation loss for 1/15 epochs.
# Epoch 23/75 | LR: 0.000254 | Train Loss: 1.2810 | Val Loss: 1.2793
#    ---> No improvement in validation loss for 2/15 epochs.
# Epoch 24/75 | LR: 0.000249 | Train Loss: 1.2806 | Val Loss: 1.2791
#    ---> Improved! Saved new best model checkpoint to 'best_spatiotemporal_physnet.pt' (Val Loss: 1.2791)
# Epoch 25/75 | LR: 0.000244 | Train Loss: 1.2800 | Val Loss: 1.2804
#    ---> No improvement in validation loss for 1/15 epochs.
# Epoch 26/75 | LR: 0.000238 | Train Loss: 1.2798 | Val Loss: 1.2789
#    ---> Improved! Saved new best model checkpoint to 'best_spatiotemporal_physnet.pt' (Val Loss: 1.2789)
# Epoch 27/75 | LR: 0.000233 | Train Loss: 1.2795 | Val Loss: 1.2771
#    ---> Improved! Saved new best model checkpoint to 'best_spatiotemporal_physnet.pt' (Val Loss: 1.2771)
# Epoch 28/75 | LR: 0.000227 | Train Loss: 1.2792 | Val Loss: 1.2764
#    ---> Improved! Saved new best model checkpoint to 'best_spatiotemporal_physnet.pt' (Val Loss: 1.2764)
# Epoch 29/75 | LR: 0.000221 | Train Loss: 1.2787 | Val Loss: 1.2776
#    ---> No improvement in validation loss for 1/15 epochs.
# Epoch 30/75 | LR: 0.000215 | Train Loss: 1.2785 | Val Loss: 1.2778
#    ---> No improvement in validation loss for 2/15 epochs.
# Epoch 31/75 | LR: 0.000209 | Train Loss: 1.2786 | Val Loss: 1.2763
#    ---> Improved! Saved new best model checkpoint to 'best_spatiotemporal_physnet.pt' (Val Loss: 1.2763)
# Epoch 32/75 | LR: 0.000203 | Train Loss: 1.2781 | Val Loss: 1.2757
#    ---> Improved! Saved new best model checkpoint to 'best_spatiotemporal_physnet.pt' (Val Loss: 1.2757)
# Epoch 33/75 | LR: 0.000197 | Train Loss: 1.2778 | Val Loss: 1.2762
#    ---> No improvement in validation loss for 1/15 epochs.
# Epoch 34/75 | LR: 0.000190 | Train Loss: 1.2777 | Val Loss: 1.2744
#    ---> Improved! Saved new best model checkpoint to 'best_spatiotemporal_physnet.pt' (Val Loss: 1.2744)
# Epoch 35/75 | LR: 0.000184 | Train Loss: 1.2774 | Val Loss: 1.2742
#    ---> Improved! Saved new best model checkpoint to 'best_spatiotemporal_physnet.pt' (Val Loss: 1.2742)
# Epoch 36/75 | LR: 0.000177 | Train Loss: 1.2767 | Val Loss: 1.2748
#    ---> No improvement in validation loss for 1/15 epochs.
# Epoch 37/75 | LR: 0.000171 | Train Loss: 1.2767 | Val Loss: 1.2738
#    ---> Improved! Saved new best model checkpoint to 'best_spatiotemporal_physnet.pt' (Val Loss: 1.2738)
# Epoch 38/75 | LR: 0.000164 | Train Loss: 1.2766 | Val Loss: 1.2739
#    ---> No improvement in validation loss for 1/15 epochs.
# Epoch 39/75 | LR: 0.000157 | Train Loss: 1.2759 | Val Loss: 1.2741
#    ---> No improvement in validation loss for 2/15 epochs.
# Epoch 40/75 | LR: 0.000150 | Train Loss: 1.2759 | Val Loss: 1.2749
#    ---> No improvement in validation loss for 3/15 epochs.
# Epoch 41/75 | LR: 0.000144 | Train Loss: 1.2756 | Val Loss: 1.2731
#    ---> Improved! Saved new best model checkpoint to 'best_spatiotemporal_physnet.pt' (Val Loss: 1.2731)
# Epoch 42/75 | LR: 0.000137 | Train Loss: 1.2747 | Val Loss: 1.2731
#    ---> Improved! Saved new best model checkpoint to 'best_spatiotemporal_physnet.pt' (Val Loss: 1.2731)
# Epoch 43/75 | LR: 0.000130 | Train Loss: 1.2749 | Val Loss: 1.2720
#    ---> Improved! Saved new best model checkpoint to 'best_spatiotemporal_physnet.pt' (Val Loss: 1.2720)
# Epoch 44/75 | LR: 0.000124 | Train Loss: 1.2743 | Val Loss: 1.2727
#    ---> No improvement in validation loss for 1/15 epochs.
# Epoch 45/75 | LR: 0.000117 | Train Loss: 1.2745 | Val Loss: 1.2719
#    ---> Improved! Saved new best model checkpoint to 'best_spatiotemporal_physnet.pt' (Val Loss: 1.2719)
# Epoch 46/75 | LR: 0.000111 | Train Loss: 1.2740 | Val Loss: 1.2724
#    ---> No improvement in validation loss for 1/15 epochs.
# Epoch 47/75 | LR: 0.000104 | Train Loss: 1.2740 | Val Loss: 1.2712
#    ---> Improved! Saved new best model checkpoint to 'best_spatiotemporal_physnet.pt' (Val Loss: 1.2712)
# Epoch 48/75 | LR: 0.000098 | Train Loss: 1.2734 | Val Loss: 1.2713
#    ---> No improvement in validation loss for 1/15 epochs.
# Epoch 49/75 | LR: 0.000092 | Train Loss: 1.2734 | Val Loss: 1.2709
#    ---> Improved! Saved new best model checkpoint to 'best_spatiotemporal_physnet.pt' (Val Loss: 1.2709)
# Epoch 50/75 | LR: 0.000086 | Train Loss: 1.2730 | Val Loss: 1.2705
#    ---> Improved! Saved new best model checkpoint to 'best_spatiotemporal_physnet.pt' (Val Loss: 1.2705)
# Epoch 51/75 | LR: 0.000080 | Train Loss: 1.2729 | Val Loss: 1.2702
#    ---> Improved! Saved new best model checkpoint to 'best_spatiotemporal_physnet.pt' (Val Loss: 1.2702)
# Epoch 52/75 | LR: 0.000074 | Train Loss: 1.2726 | Val Loss: 1.2699
#    ---> Improved! Saved new best model checkpoint to 'best_spatiotemporal_physnet.pt' (Val Loss: 1.2699)
# Epoch 53/75 | LR: 0.000068 | Train Loss: 1.2721 | Val Loss: 1.2703
#    ---> No improvement in validation loss for 1/15 epochs.
# Epoch 54/75 | LR: 0.000063 | Train Loss: 1.2715 | Val Loss: 1.2701
#    ---> No improvement in validation loss for 2/15 epochs.
# Epoch 55/75 | LR: 0.000057 | Train Loss: 1.2718 | Val Loss: 1.2696
#    ---> Improved! Saved new best model checkpoint to 'best_spatiotemporal_physnet.pt' (Val Loss: 1.2696)
# Epoch 56/75 | LR: 0.000052 | Train Loss: 1.2716 | Val Loss: 1.2692
#    ---> Improved! Saved new best model checkpoint to 'best_spatiotemporal_physnet.pt' (Val Loss: 1.2692)
# Epoch 57/75 | LR: 0.000047 | Train Loss: 1.2710 | Val Loss: 1.2689
#    ---> Improved! Saved new best model checkpoint to 'best_spatiotemporal_physnet.pt' (Val Loss: 1.2689)
# Epoch 58/75 | LR: 0.000042 | Train Loss: 1.2710 | Val Loss: 1.2690
#    ---> No improvement in validation loss for 1/15 epochs.
# Epoch 59/75 | LR: 0.000038 | Train Loss: 1.2713 | Val Loss: 1.2690
#    ---> No improvement in validation loss for 2/15 epochs.
# Epoch 60/75 | LR: 0.000034 | Train Loss: 1.2708 | Val Loss: 1.2685
#    ---> Improved! Saved new best model checkpoint to 'best_spatiotemporal_physnet.pt' (Val Loss: 1.2685)
# Epoch 61/75 | LR: 0.000030 | Train Loss: 1.2704 | Val Loss: 1.2689
#    ---> No improvement in validation loss for 1/15 epochs.
# Epoch 62/75 | LR: 0.000026 | Train Loss: 1.2703 | Val Loss: 1.2685
#    ---> Improved! Saved new best model checkpoint to 'best_spatiotemporal_physnet.pt' (Val Loss: 1.2685)
# Epoch 63/75 | LR: 0.000022 | Train Loss: 1.2702 | Val Loss: 1.2681
#    ---> Improved! Saved new best model checkpoint to 'best_spatiotemporal_physnet.pt' (Val Loss: 1.2681)
# Epoch 64/75 | LR: 0.000019 | Train Loss: 1.2701 | Val Loss: 1.2685
#    ---> No improvement in validation loss for 1/15 epochs.
# Epoch 65/75 | LR: 0.000016 | Train Loss: 1.2699 | Val Loss: 1.2682
#    ---> No improvement in validation loss for 2/15 epochs.
# Epoch 66/75 | LR: 0.000013 | Train Loss: 1.2698 | Val Loss: 1.2680
#    ---> Improved! Saved new best model checkpoint to 'best_spatiotemporal_physnet.pt' (Val Loss: 1.2680)
# Epoch 67/75 | LR: 0.000011 | Train Loss: 1.2699 | Val Loss: 1.2681
#    ---> No improvement in validation loss for 1/15 epochs.
# Epoch 68/75 | LR: 0.000008 | Train Loss: 1.2695 | Val Loss: 1.2681
#    ---> No improvement in validation loss for 2/15 epochs.
# Epoch 69/75 | LR: 0.000006 | Train Loss: 1.2697 | Val Loss: 1.2680
#    ---> Improved! Saved new best model checkpoint to 'best_spatiotemporal_physnet.pt' (Val Loss: 1.2680)
# Epoch 70/75 | LR: 0.000005 | Train Loss: 1.2697 | Val Loss: 1.2679
#    ---> Improved! Saved new best model checkpoint to 'best_spatiotemporal_physnet.pt' (Val Loss: 1.2679)
# Epoch 71/75 | LR: 0.000003 | Train Loss: 1.2689 | Val Loss: 1.2678
#    ---> Improved! Saved new best model checkpoint to 'best_spatiotemporal_physnet.pt' (Val Loss: 1.2678)
# Epoch 72/75 | LR: 0.000002 | Train Loss: 1.2693 | Val Loss: 1.2677
#    ---> Improved! Saved new best model checkpoint to 'best_spatiotemporal_physnet.pt' (Val Loss: 1.2677)
# Epoch 73/75 | LR: 0.000002 | Train Loss: 1.2694 | Val Loss: 1.2678
#    ---> No improvement in validation loss for 1/15 epochs.
# Epoch 74/75 | LR: 0.000001 | Train Loss: 1.2694 | Val Loss: 1.2679
#    ---> No improvement in validation loss for 2/15 epochs.
# Epoch 75/75 | LR: 0.000001 | Train Loss: 1.2693 | Val Loss: 1.2679
#    ---> No improvement in validation loss for 3/15 epochs.
#
# Loading best model state dict from memory (Best Val Loss: 1.2677)...
#
# ==================================================
#               VAL METRICS EVALUATION
# ==================================================
#   Pearson Correlation Coefficient (PCC) : 0.0322
#   Mean Absolute Error (MAE)            : 16.97 BPM
#   Root Mean Squared Error (RMSE)       : 24.95 BPM
#   Signal-to-Noise Ratio (SNR)          : -3.89 dB
# ==================================================
#
# Demonstration: Checkpoint stored at '/home/cristic/mcd_rppg/best_spatiotemporal_physnet.pt'

# %%
def calculate_metrics(y_pred, y_true, fs=30.0):
    """Extract performance evaluation metrics (PCC, MAE, RMSE, and SNR)."""
    pcc_list, mae_list, rmse_list, snr_list = [], [], [], []
    
    for i in range(len(y_pred)):
        pred, true = y_pred[i], y_true[i]
        
        pcc = np.corrcoef(pred, true)[0, 1]
        pcc_list.append(0.0 if np.isnan(pcc) else pcc)
        
        bpm_pred = calculate_bpm_from_fft(pred, fs=fs)
        bpm_true = calculate_bpm_from_fft(true, fs=fs)
        
        mae_list.append(abs(bpm_pred - bpm_true))
        rmse_list.append((bpm_pred - bpm_true) ** 2)
        
        pred_detrended = pred - np.mean(pred)
        freqs, psd = welch(pred_detrended, fs=fs, nperseg=len(pred_detrended))
        
        gt_freq = bpm_true / 60.0
        signal_mask = (freqs >= (gt_freq - 0.15)) & (freqs <= (gt_freq + 0.15))
        noise_mask = ~signal_mask & (freqs >= 0.75) & (freqs <= 2.5)
        
        signal_power = np.sum(psd[signal_mask])
        noise_power = np.sum(psd[noise_mask]) + 1e-8
        snr_list.append(10 * np.log10(signal_power / noise_power))
        
    return {
        'PCC': np.mean(pcc_list),
        'MAE': np.mean(mae_list),
        'RMSE': math.sqrt(np.mean(rmse_list)),
        'SNR': np.mean(snr_list)
    }

# %%
model.eval()
all_preds, all_trues = [], []

with torch.no_grad():
    for val_inputs, val_targets in val_loader:
        val_inputs = val_inputs.to(DEVICE)
        preds = model(val_inputs).cpu().numpy()
        all_preds.extend(preds)
        all_trues.extend(val_targets.numpy())

all_preds, all_trues = np.array(all_preds), np.array(all_trues)
metrics = calculate_metrics(all_preds, all_trues)

print("\n" + "=" * 50)
print("              VAL METRICS EVALUATION")
print("=" * 50)
print(f"  Pearson Correlation Coefficient (PCC) : {metrics['PCC']:.4f}")
print(f"  Mean Absolute Error (MAE)            : {metrics['MAE']:.2f} BPM")
print(f"  Root Mean Squared Error (RMSE)       : {metrics['RMSE']:.2f} BPM")
print(f"  Signal-to-Noise Ratio (SNR)          : {metrics['SNR']:.2f} dB")
print("=" * 50 + "\n")
# Out:
# ==================================================
#               VAL METRICS EVALUATION
# ==================================================
#   Pearson Correlation Coefficient (PCC) : 0.0322
#   Mean Absolute Error (MAE)            : 17.03 BPM
#   Root Mean Squared Error (RMSE)       : 25.07 BPM
#   Signal-to-Noise Ratio (SNR)          : -3.89 dB
# ==================================================

# %%
MODEL_SAVE_PATH = Path("spatiotemporal_long_window450_physnet_best2.pth")
def load_model_checkpoint(save_path, model, optimizer=None):
    if not os.path.exists(save_path):
        print(f"Checkpoint path {save_path} does not exist.")
        return None
        
    # Pass weights_only=False to allow loading custom dicts (metrics, scalar types)
    checkpoint = torch.load(save_path, map_location=DEVICE, weights_only=False)
    
    model.load_state_dict(checkpoint['model_state_dict'])
    if optimizer is not None and 'optimizer_state_dict' in checkpoint:
        optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
    print(f"Loaded model checkpoint from: {save_path} (Epoch {checkpoint.get('epoch', 'N/A')})")
    return checkpoint
save_model_checkpoint(model, optimizer, num_epochs, metrics, MODEL_SAVE_PATH)
trained_model = load_model_checkpoint(MODEL_SAVE_PATH, model, optimizer)
# Out:
# Model checkpoint successfully saved to: spatiotemporal_long_window450_physnet_best2.pth
# Loaded model checkpoint from: spatiotemporal_long_window450_physnet_best2.pth (Epoch 75)

# %%
def run_inference_on_sample(npz_file_path, trained_model, sequence_length=450, fs=30.0):
    """Execute inference on a single NPZ validation sample sequence."""
    print(f"--- INFERENCE RUN ON: {os.path.basename(npz_file_path)} ---")
    data = load_npz_file(npz_file_path)
    if data is None:
        return None
    
    ppg_key = 'ppg_values' if 'ppg_values' in data else 'ppg'
    if len(data[ppg_key]) < sequence_length:
        print("Error: Input file length is shorter than the sequence length.")
        return None
        
    target_ppg = data[ppg_key][:sequence_length]
    target_ppg = butter_bandpass_filter(target_ppg, fs=fs)
    target_norm = (target_ppg - np.mean(target_ppg)) / (np.std(target_ppg) + 1e-8)
    
    roi_inputs = []
    for roi_name in ROI_ORDER:
        actual_key = next((k for k in data.files if roi_name == k), None)
        if actual_key is not None:
            roi_data = data[actual_key][:sequence_length]
        else:
            roi_data = np.zeros((sequence_length, 24, 24, 3), dtype=np.uint8)
        roi_inputs.append(roi_data.astype(np.float32) / 255.0)
        
    stacked_rois = np.stack(roi_inputs, axis=0)
    stacked_rois = np.transpose(stacked_rois, (0, 4, 1, 2, 3))
    stacked_rois = np.reshape(stacked_rois, (30, sequence_length, 24, 24))
    
    input_tensor = torch.tensor(stacked_rois, dtype=torch.float32).unsqueeze(0).to(DEVICE)
    
    trained_model.eval()
    with torch.no_grad():
        output_signal = trained_model(input_tensor).cpu().numpy()[0]
        
    filtered_pred = butter_bandpass_filter(output_signal, fs=fs)
    filtered_pred = (filtered_pred - np.mean(filtered_pred)) / (np.std(filtered_pred) + 1e-8)
    
    hr_pred = calculate_bpm_from_fft(filtered_pred, fs=fs)
    hr_true = calculate_bpm_from_fft(target_norm, fs=fs)
    
    print(f"  Predicted HR : {hr_pred:.2f} BPM")
    print(f"  Ground-Truth : {hr_true:.2f} BPM")
    print(f"  Absolute Error: {abs(hr_pred - hr_true):.2f} BPM")
    print("----------------------------------------------------\n")
    return filtered_pred, target_norm

sample_val_file = val_split[1]
inference_pred, inference_gt = run_inference_on_sample(sample_val_file, model)

fig, axs = plt.subplots(2, 2, figsize=(14, 10))

axs[0, 0].plot(train_losses, label='Train Loss', color='#1f77b4', linewidth=2.5, marker='o')
axs[0, 0].plot(val_losses, label='Val Loss', color='#ff7f0e', linewidth=2.5, marker='s')
axs[0, 0].set_title('Spatio-Temporal Model Loss Convergence')
axs[0, 0].set_xlabel('Training Epochs')
axs[0, 0].set_ylabel('Dual-Objective Loss Value')
axs[0, 0].legend()

if inference_pred is not None:
    axs[0, 1].plot(inference_gt, label='GT PPG (BVP)', color='#7f7f7f', alpha=0.75, linewidth=2)
    axs[0, 1].plot(inference_pred, label='10-ROI Predicted rPPG', color='#2ca02c', linewidth=2.5)
    axs[0, 1].set_title('Signal Waveform Comparison (Inference Showcase)')
    axs[0, 1].set_xlabel('Frames Timeline')
    axs[0, 1].set_ylabel('Normalized Amplitude')
    axs[0, 1].legend()

if inference_pred is not None:
    pred_det = inference_pred - np.mean(inference_pred)
    true_det = inference_gt - np.mean(inference_gt)
    
    freqs_p, psd_p = welch(pred_det, fs=30.0, nperseg=len(pred_det))
    freqs_t, psd_t = welch(true_det, fs=30.0, nperseg=len(true_det))
    
    axs[1, 0].plot(freqs_t * 60.0, psd_t, label='GT Spectrum', color='#7f7f7f', alpha=0.75, linewidth=2)
    axs[1, 0].plot(freqs_p * 60.0, psd_p, label='Pred Spectrum', color='#d62728', linewidth=2.5)
    axs[1, 0].set_xlim(45, 150)
    axs[1, 0].set_title('Power Spectral Density (PSD) Comparison')
    axs[1, 0].set_xlabel('Heart Rate (BPM)')
    axs[1, 0].set_ylabel('Spectral Magnitude')
    axs[1, 0].legend()

axs[1, 1].axis('off')
metric_summary_card = (
    "10-ROI Spatio-Temporal Evaluation Summary\n\n"
    f"• Pearson Correlation Coefficient (PCC): {metrics['PCC']:.4f}\n"
    f"• MAE: {metrics['MAE']:.2f} BPM\n"
    f"• RMSE: {metrics['RMSE']:.2f} BPM\n"
    f"• Signal-to-Noise Ratio (SNR): {metrics['SNR']:.2f} dB\n\n"
    f"Configuration Info:\n"
    f"• Spatio-Temporal Model input channels: 30 (10 ROIs × 3 RGB)\n"
    f"• Sequence segment window: 128 frames\n"
    f"• Aligned to 'ppg_values' and raw NPZ skin zones\n"
    f"• Optimization: Vectorised augmentations (Spatial & Brightness)"
)
axs[1, 1].text(0.05, 0.2, metric_summary_card, fontsize=11, 
              bbox=dict(boxstyle='round,pad=1.2', facecolor='#f8f9fa', edgecolor='#dee2e6'))

plt.tight_layout()
plt.show()
# Out:
# --- INFERENCE RUN ON: 3385_FullHDwebcam_after_chunk12.npz ---
#   Predicted HR : 88.00 BPM
#   Ground-Truth : 76.00 BPM
#   Absolute Error: 12.00 BPM
# ----------------------------------------------------

# %%
# ============================================================================
# Standalone Inference Cell: Video (.avi) -> MediaPipe 10-ROI -> PhysNet Model
# ============================================================================
import os
import cv2
import math
import imageio
import numpy as np
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
from scipy.signal import butter, filtfilt, welch
import mediapipe as mp
from mediapipe.tasks import python
from mediapipe.tasks.python import vision

# ----------------------------------------------------------------------------
# 1. Configuration & Constants
# ----------------------------------------------------------------------------
VIDEO_PATH = '/home/cristic/data/Bgeorge/mcd_rppg/snapshots/929fb19c5ff2b5c8ed64a7c3a123744346674e88/video/9998_USBVideo_after.avi'  # Path to your target .avi video
MEDIAPIPE_MODEL_PATH = '/home/cristic/face_landmarker.task'
MODEL_CHECKPOINT_PATH = 'spatiotemporal_physnet_best.pth'

CHUNK_SIZE = 450
ROI_BOX_SIZE = (24, 24)
DEVICE = torch.device('cuda:1' if torch.cuda.is_available() else 'cpu')

# Exact 10 ROI ordering expected by SpatioTemporalPhysNet (30 input channels)
ROI_ORDER = [
    'roi_forehead',
    'roi_left_cheek_280',
    'roi_right_cheek_50',
    'roi_nose',
    'roi_chin',
    'roi_chin_199',
    'roi_left_eye',
    'roi_right_eye',
    'roi_mouth',
    'roi_full_face'
]

# MediaPipe landmark mappings for the 10 ROIs
ROIS_MAPPING = {
    'roi_full_face': list(range(468)),
    'roi_forehead': [10, 67, 69, 108, 109, 151, 337, 338, 297, 299, 9, 8],
    'roi_left_eye': [33, 7, 163, 144, 145, 153, 154, 155, 133, 173, 157, 158, 159, 160, 161, 246],
    'roi_right_eye': [362, 382, 381, 380, 374, 373, 390, 249, 263, 466, 388, 387, 386, 385, 384, 398],
    'roi_nose': [1, 2, 98, 327, 328, 2, 4, 5, 195, 197, 6, 168],
    'roi_mouth': [61, 146, 91, 181, 84, 17, 314, 405, 321, 375, 291, 308, 324, 318, 402, 317, 14, 87, 178, 95],
    'roi_chin': [152, 148, 176, 149, 150, 136, 172, 377, 400, 378, 379, 365, 397],
    'roi_right_cheek_50': [50],
    'roi_left_cheek_280': [280],
    'roi_chin_199': [199]
}

# ----------------------------------------------------------------------------
# 2. MediaPipe Detector & ROI Helper Definitions
# ----------------------------------------------------------------------------
class ModernFaceMeshDetector:
    def __init__(self, model_path):
        base_options = python.BaseOptions(model_asset_path=model_path)
        options = vision.FaceLandmarkerOptions(
            base_options=base_options,
            running_mode=vision.RunningMode.VIDEO,
            num_faces=1,
            min_face_detection_confidence=0.5,
            min_face_presence_confidence=0.5,
            min_tracking_confidence=0.5
        )
        self.landmarker = vision.FaceLandmarker.create_from_options(options)
        self.timestamp_ms = 0

    def detect_landmarks(self, frame_rgb):
        mp_image = mp.Image(image_format=mp.ImageFormat.SRGB, data=frame_rgb)
        self.timestamp_ms += 33  # ~30 FPS step
        detection_result = self.landmarker.detect_for_video(mp_image, self.timestamp_ms)
        
        if detection_result.face_landmarks:
            h, w = frame_rgb.shape[:2]
            landmarks = detection_result.face_landmarks[0]
            # Convert normalized coordinates to pixel coordinates
            return np.array([[lm.x * w, lm.y * h] for lm in landmarks], dtype=np.float32)
        return None

    def reset(self):
        self.timestamp_ms = 0

    def close(self):
        self.landmarker.close()


def extract_roi_bbox(landmarks, indices, frame_shape, target_size=(24, 24)):
    h, w = frame_shape
    roi_lms = landmarks[indices]
    
    if len(indices) == 1:
        # Point landmark (e.g., cheek, chin point) -> center crop around landmark
        cx, cy = roi_lms[0]
        crop_w, crop_h = target_size
        x = int(cx - crop_w / 2)
        y = int(cy - crop_h / 2)
    else:
        # Multi-point ROI -> calculate bounding box
        min_x, min_y = np.min(roi_lms, axis=0)
        max_x, max_y = np.max(roi_lms, axis=0)
        x, y = int(min_x), int(min_y)
        crop_w, crop_h = int(max_x - min_x), int(max_y - min_y)
        
    x = max(0, min(x, w - 1))
    y = max(0, min(y, h - 1))
    crop_w = max(1, min(crop_w, w - x))
    crop_h = max(1, min(crop_h, h - y))
    
    return (x, y, crop_w, crop_h)


def extract_roi_region(frame, bbox, target_size=ROI_BOX_SIZE):
    x, y, w, h = bbox
    crop = frame[y:y+h, x:x+w]
    if crop.size == 0:
        return np.zeros((*target_size, 3), dtype=np.uint8)
    return cv2.resize(crop, target_size, interpolation=cv2.INTER_AREA)

# ----------------------------------------------------------------------------
# 3. Signal Processing Helper Functions
# ----------------------------------------------------------------------------
def butter_bandpass_filter(data, lowcut=0.75, highcut=2.5, fs=30.0, order=4):
    nyq = 0.5 * fs
    low = lowcut / nyq
    high = highcut / nyq
    b, a = butter(order, [low, high], btype='band')
    return filtfilt(b, a, data)

def calculate_bpm_from_fft(signal_1d, fs=30.0, lowcut=0.75, highcut=2.5):
    signal_cleaned = signal_1d - np.mean(signal_1d)
    freqs, psd = welch(signal_cleaned, fs=fs, nperseg=len(signal_cleaned))
    valid_idx = np.where((freqs >= lowcut) & (freqs <= highcut))[0]
    if len(valid_idx) == 0:
        return 75.0
    peak_freq = freqs[valid_idx[np.argmax(psd[valid_idx])]]
    return peak_freq * 60.0

# ----------------------------------------------------------------------------
# 4. Model Architecture Load
# ----------------------------------------------------------------------------
class SpatioTemporalPhysNet(nn.Module):
    def __init__(self, num_rois=10, in_channels=3):
        super(SpatioTemporalPhysNet, self).__init__()
        self.num_rois = num_rois
        self.total_channels = num_rois * in_channels
        
        self.spatial_conv = nn.Sequential(
            nn.Conv3d(self.total_channels, 64, kernel_size=(1, 3, 3), padding=(0, 1, 1)),
            nn.BatchNorm3d(64),
            nn.ELU(),
            nn.AdaptiveAvgPool3d((None, 1, 1))
        )
        
        self.temporal_encoder = nn.Sequential(
            nn.Conv1d(64, 32, kernel_size=5, padding=2),
            nn.BatchNorm1d(32),
            nn.ELU(),
            nn.Conv1d(32, 16, kernel_size=5, padding=2),
            nn.BatchNorm1d(16),
            nn.ELU(),
            nn.Conv1d(16, 1, kernel_size=1)
        )

    def forward(self, x):
        x_spatial = self.spatial_conv(x)
        x_spatial = torch.squeeze(x_spatial, dim=-1)
        x_spatial = torch.squeeze(x_spatial, dim=-1)
        ppg_pred = self.temporal_encoder(x_spatial)
        return torch.squeeze(ppg_pred, dim=1)

# ----------------------------------------------------------------------------
# 5. Video Processing Pipeline
# ----------------------------------------------------------------------------
def process_video_for_physnet(video_path, detector, chunk_size=CHUNK_SIZE):
    if not os.path.exists(video_path):
        raise FileNotFoundError(f"Video file not found at: {video_path}")
        
    reader = imageio.get_reader(video_path, 'ffmpeg')
    meta = reader.get_meta_data()
    fps = meta.get('fps', 30.0)
    
    frames = []
    for i, frame in enumerate(reader):
        if i >= chunk_size:
            break
        frames.append(frame)
    reader.close()
    
    num_frames = len(frames)
    print(f"Loaded {num_frames} frames from '{os.path.basename(video_path)}' @ {fps:.2f} FPS")
    
    # Pad short videos if needed
    if num_frames < chunk_size:
        pad_count = chunk_size - num_frames
        frames += [frames[-1]] * pad_count
        print(f"Padded video from {num_frames} to {chunk_size} frames.")
        
    # Extract landmarks per frame
    chunk_landmarks = []
    detector.reset()
    for frame in frames:
        lms = detector.detect_landmarks(frame)
        if lms is not None:
            chunk_landmarks.append(lms)
        elif chunk_landmarks:
            chunk_landmarks.append(chunk_landmarks[-1].copy())
        else:
            chunk_landmarks.append(np.zeros((468, 2), dtype='float32'))
            
    chunk_landmarks = np.array(chunk_landmarks)
    
    # Crop ROIs for all frames
    roi_inputs = []
    for roi_name in ROI_ORDER:
        roi_indices = ROIS_MAPPING[roi_name]
        roi_frames = []
        for frame_idx, frame in enumerate(frames):
            landmarks = chunk_landmarks[frame_idx]
            if np.all(landmarks == 0):
                h, w = frame.shape[:2]
                bbox = (w // 2 - ROI_BOX_SIZE[0] // 2, h // 2 - ROI_BOX_SIZE[1] // 2, ROI_BOX_SIZE[0], ROI_BOX_SIZE[1])
            else:
                bbox = extract_roi_bbox(landmarks, roi_indices, frame.shape[:2], ROI_BOX_SIZE)
            
            roi_region = extract_roi_region(frame, bbox)
            roi_frames.append(roi_region)
            
        roi_array = np.array(roi_frames, dtype=np.float32) / 255.0  # (T, 24, 24, 3)
        roi_inputs.append(roi_array)
        
    # Format shape to match model input: (10, T, H, W, C) -> (1, 30, T, 24, 24)
    stacked_rois = np.stack(roi_inputs, axis=0)                     # (10, 450, 24, 24, 3)
    stacked_rois = np.transpose(stacked_rois, (0, 4, 1, 2, 3))     # (10, 3, 450, 24, 24)
    stacked_rois = np.reshape(stacked_rois, (10 * 3, CHUNK_SIZE, 24, 24)) # (30, 450, 24, 24)
    
    tensor_input = torch.tensor(stacked_rois, dtype=torch.float32).unsqueeze(0) # (1, 30, 450, 24, 24)
    return tensor_input, fps

# ----------------------------------------------------------------------------
# 6. Pipeline Execution
# ----------------------------------------------------------------------------
# Initialize MediaPipe Detector
detector = ModernFaceMeshDetector(model_path=MEDIAPIPE_MODEL_PATH)

# Initialize Model & Load Weights
model = SpatioTemporalPhysNet(num_rois=10).to(DEVICE)
if os.path.exists(MODEL_CHECKPOINT_PATH):
    # checkpoint = torch.load(MODEL_CHECKPOINT_PATH, map_location=DEVICE)
    checkpoint = torch.load(MODEL_CHECKPOINT_PATH, map_location=DEVICE, weights_only=False)
    if 'model_state_dict' in checkpoint:
        model.load_state_dict(checkpoint['model_state_dict'])
    else:
        model.load_state_dict(checkpoint)
    print(f"Successfully loaded model weights from: {MODEL_CHECKPOINT_PATH}")
else:
    print(f"[Warning] Checkpoint '{MODEL_CHECKPOINT_PATH}' not found. Using randomly initialized model.")

model.eval()

# Process video and perform forward pass
input_tensor, video_fps = process_video_for_physnet(VIDEO_PATH, detector, chunk_size=CHUNK_SIZE)
input_tensor = input_tensor.to(DEVICE)

print(f"\nModel Input Tensor Shape : {input_tensor.shape}")
print(f"Target Hardware Execution : {DEVICE}")

with torch.no_grad():
    predicted_ppg = model(input_tensor).squeeze(0).cpu().numpy()

# Post-processing & HR Extraction
filtered_ppg = butter_bandpass_filter(predicted_ppg, fs=video_fps)
normalized_ppg = (filtered_ppg - np.mean(filtered_ppg)) / (np.std(filtered_ppg) + 1e-8)
estimated_bpm = calculate_bpm_from_fft(filtered_ppg, fs=video_fps)

# Render Waveform Visualization
timeline = np.arange(len(normalized_ppg)) / video_fps
plt.figure(figsize=(15, 4))
plt.plot(timeline, normalized_ppg, color='#e91e63', linewidth=2, label='Predicted rPPG Signal')
plt.title(f"SpatioTemporalPhysNet Inference | Video: {os.path.basename(VIDEO_PATH)} | Estimated HR: {estimated_bpm:.1f} BPM", fontsize=12, fontweight='bold')
plt.xlabel("Time (seconds)")
plt.ylabel("Normalized BVP Signal")
plt.grid(True, linestyle=":", alpha=0.6)
plt.legend(loc="upper right")
plt.tight_layout()
plt.show()

# Clean up detector
detector.close()
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# W0000 00:00:1784871478.100184 1738736 face_landmarker_graph.cc:174] Sets FaceBlendshapesGraph acceleration to xnnpack by default.
# I0000 00:00:1784871478.740774 1738736 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# W0000 00:00:1784871478.792232 1739047 gl_context.cc:343] failed to get GL_VERSION string
# I0000 00:00:1784871478.792281 1739047 gl_context.cc:385] GL version: 3.2 (), renderer: (null)
# E0000 00:00:1784871478.792308 1739047 gl_context.cc:310] Error querying for GL extensions
# I0000 00:00:1784871478.792593 1738736 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# W0000 00:00:1784871478.795459 1739048 gl_context.cc:343] failed to get GL_VERSION string
# I0000 00:00:1784871478.795501 1739048 gl_context.cc:385] GL version: 3.2 (), renderer: (null)
# E0000 00:00:1784871478.795523 1739048 gl_context.cc:310] Error querying for GL extensions
# I0000 00:00:1784871478.795727 1738736 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# W0000 00:00:1784871478.798164 1739049 gl_context.cc:343] failed to get GL_VERSION string
# I0000 00:00:1784871478.798190 1739049 gl_context.cc:385] GL version: 3.2 (), renderer: (null)
# E0000 00:00:1784871478.798212 1739049 gl_context.cc:310] Error querying for GL extensions
# I0000 00:00:1784871478.798407 1738736 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# W0000 00:00:1784871478.800938 1739050 gl_context.cc:343] failed to get GL_VERSION string
# I0000 00:00:1784871478.800960 1739050 gl_context.cc:385] GL version: 3.2 (), renderer: (null)
# E0000 00:00:1784871478.800981 1739050 gl_context.cc:310] Error querying for GL extensions
# I0000 00:00:1784871478.801190 1738736 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# W0000 00:00:1784871478.803703 1739051 gl_context.cc:343] failed to get GL_VERSION string
# I0000 00:00:1784871478.803724 1739051 gl_context.cc:385] GL version: 3.2 (), renderer: (null)
# E0000 00:00:1784871478.803746 1739051 gl_context.cc:310] Error querying for GL extensions
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# W0000 00:00:1784871478.840395 1738737 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1784871478.866361 1738737 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# Successfully loaded model weights from: spatiotemporal_physnet_best.pth
# Loaded 450 frames from '9998_USBVideo_after.avi' @ 30.00 FPS
#
# Model Input Tensor Shape : torch.Size([1, 30, 450, 24, 24])
# Target Hardware Execution : cuda:1

# %%
import pandas as pd

CSV_PATH = "/home/cristic/data/Bgeorge/mcd_rppg/snapshots/929fb19c5ff2b5c8ed64a7c3a123744346674e88/db.csv"

# Load header only for instant inspection
df = pd.read_csv(CSV_PATH, nrows=5)

print(f"Total Columns ({len(df.columns)}):")
print(df.columns.tolist())
# Out:
# Total Columns (25):
# ['patient_id', 'weight', 'height', 'bmi', 'age', 'sex', 'upper_ap', 'lower_ap', 'saturation', 'temperature', 'hemoglobin', 'glycated_hemoglobin', 'cholesterol', 'respiratory', 'rigidity', 'pulse', 'stress', 'step', 'camera', 'view', 'ecg', 'ppg', 'video', 'meta', 'ppg_sync']

# %%
import pandas as pd

CSV_PATH = "/home/cristic/data/Bgeorge/mcd_rppg/snapshots/929fb19c5ff2b5c8ed64a7c3a123744346674e88/db.csv"
df = pd.read_csv(CSV_PATH)

# Support flexible column naming depending on exact header case/alias
patient_col = 'patient_id' if 'patient_id' in df.columns else 'patient'

# Filter by subject 9998 and USBVideo camera
filtered_df = df[
    (df[patient_col].astype(str).str.contains('9998')) & 
    (df['camera'].astype(str).str.contains('USBVideo', case=False, na=False))
]

# Display relevant identification columns alongside pulse
display_cols = [col for col in [patient_col, 'step', 'camera', 'view', 'pulse'] if col in df.columns]
print(filtered_df[display_cols])
# Out:
#       patient_id    step    camera  view  pulse
# 3595        9998   after  USBVideo  left  117.0
# 3598        9998  before  USBVideo  left  100.0

# %%
# Process video and perform forward pass
VIDEO_PATH = '/home/cristic/data/Bgeorge/mcd_rppg/snapshots/929fb19c5ff2b5c8ed64a7c3a123744346674e88/video/1091_USBVideo_before.avi' 
input_tensor, video_fps = process_video_for_physnet(VIDEO_PATH, detector, chunk_size=CHUNK_SIZE)
input_tensor = input_tensor.to(DEVICE)

print(f"\nModel Input Tensor Shape : {input_tensor.shape}")
print(f"Target Hardware Execution : {DEVICE}")

with torch.no_grad():
    predicted_ppg = model(input_tensor).squeeze(0).cpu().numpy()

# Post-processing & HR Extraction
filtered_ppg = butter_bandpass_filter(predicted_ppg, fs=video_fps)
normalized_ppg = (filtered_ppg - np.mean(filtered_ppg)) / (np.std(filtered_ppg) + 1e-8)
estimated_bpm = calculate_bpm_from_fft(filtered_ppg, fs=video_fps)

# Render Waveform Visualization
timeline = np.arange(len(normalized_ppg)) / video_fps
plt.figure(figsize=(15, 4))
plt.plot(timeline, normalized_ppg, color='#e91e63', linewidth=2, label='Predicted rPPG Signal')
plt.title(f"SpatioTemporalPhysNet Inference | Video: {os.path.basename(VIDEO_PATH)} | Estimated HR: {estimated_bpm:.1f} BPM", fontsize=12, fontweight='bold')
plt.xlabel("Time (seconds)")
plt.ylabel("Normalized BVP Signal")
plt.grid(True, linestyle=":", alpha=0.6)
plt.legend(loc="upper right")
plt.tight_layout()
plt.show()

# Clean up detector
detector.close()
# Out:
# Loaded 450 frames from '1091_USBVideo_before.avi' @ 30.00 FPS
#
# Model Input Tensor Shape : torch.Size([1, 30, 450, 24, 24])
# Target Hardware Execution : cuda:1

# %%
# Filter by subject 9998 and USBVideo camera
filtered_df = df[
    (df[patient_col].astype(str).str.contains('1091')) & 
    (df['camera'].astype(str).str.contains('USBVideo', case=False, na=False))
]

# Display relevant identification columns alongside pulse
display_cols = [col for col in [patient_col, 'step', 'camera', 'view', 'pulse'] if col in df.columns]
print(filtered_df[display_cols])
# Out:
#     patient_id    step    camera  view  pulse
# 19        1091   after  USBVideo  left  132.0
# 22        1091  before  USBVideo  left   94.0

# %%
# ============================================================================
# Standalone Inference Cell: Video (.avi) -> MediaPipe 10-ROI -> PhysNet Model
# ============================================================================
import os
import cv2
import math
import imageio
import numpy as np
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
from scipy.signal import butter, filtfilt, welch
import mediapipe as mp
from mediapipe.tasks import python
from mediapipe.tasks.python import vision

# ----------------------------------------------------------------------------
# 1. Configuration & Constants
# ----------------------------------------------------------------------------
VIDEO_PATH = '/home/cristic/data/Bgeorge/mcd_rppg/snapshots/929fb19c5ff2b5c8ed64a7c3a123744346674e88/video/9998_USBVideo_after.avi'  # Path to your target .avi video
MEDIAPIPE_MODEL_PATH = '/home/cristic/face_landmarker.task'
MODEL_CHECKPOINT_PATH = 'spatiotemporal_long_window450_physnet_best2.pth'

CHUNK_SIZE = 450
ROI_BOX_SIZE = (24, 24)
DEVICE = torch.device('cuda:1' if torch.cuda.is_available() else 'cpu')

# Exact 10 ROI ordering expected by SpatioTemporalPhysNet (30 input channels)
ROI_ORDER = [
    'roi_forehead',
    'roi_left_cheek_280',
    'roi_right_cheek_50',
    'roi_nose',
    'roi_chin',
    'roi_chin_199',
    'roi_left_eye',
    'roi_right_eye',
    'roi_mouth',
    'roi_full_face'
]

# MediaPipe landmark mappings for the 10 ROIs
ROIS_MAPPING = {
    'roi_full_face': list(range(468)),
    'roi_forehead': [10, 67, 69, 108, 109, 151, 337, 338, 297, 299, 9, 8],
    'roi_left_eye': [33, 7, 163, 144, 145, 153, 154, 155, 133, 173, 157, 158, 159, 160, 161, 246],
    'roi_right_eye': [362, 382, 381, 380, 374, 373, 390, 249, 263, 466, 388, 387, 386, 385, 384, 398],
    'roi_nose': [1, 2, 98, 327, 328, 2, 4, 5, 195, 197, 6, 168],
    'roi_mouth': [61, 146, 91, 181, 84, 17, 314, 405, 321, 375, 291, 308, 324, 318, 402, 317, 14, 87, 178, 95],
    'roi_chin': [152, 148, 176, 149, 150, 136, 172, 377, 400, 378, 379, 365, 397],
    'roi_right_cheek_50': [50],
    'roi_left_cheek_280': [280],
    'roi_chin_199': [199]
}

# ----------------------------------------------------------------------------
# 2. MediaPipe Detector & ROI Helper Definitions
# ----------------------------------------------------------------------------
class ModernFaceMeshDetector:
    def __init__(self, model_path):
        base_options = python.BaseOptions(model_asset_path=model_path)
        options = vision.FaceLandmarkerOptions(
            base_options=base_options,
            running_mode=vision.RunningMode.VIDEO,
            num_faces=1,
            min_face_detection_confidence=0.5,
            min_face_presence_confidence=0.5,
            min_tracking_confidence=0.5
        )
        self.landmarker = vision.FaceLandmarker.create_from_options(options)
        self.timestamp_ms = 0

    def detect_landmarks(self, frame_rgb):
        mp_image = mp.Image(image_format=mp.ImageFormat.SRGB, data=frame_rgb)
        self.timestamp_ms += 33  # ~30 FPS step
        detection_result = self.landmarker.detect_for_video(mp_image, self.timestamp_ms)
        
        if detection_result.face_landmarks:
            h, w = frame_rgb.shape[:2]
            landmarks = detection_result.face_landmarks[0]
            # Convert normalized coordinates to pixel coordinates
            return np.array([[lm.x * w, lm.y * h] for lm in landmarks], dtype=np.float32)
        return None

    def reset(self):
        self.timestamp_ms = 0

    def close(self):
        self.landmarker.close()


def extract_roi_bbox(landmarks, indices, frame_shape, target_size=(24, 24)):
    h, w = frame_shape
    roi_lms = landmarks[indices]
    
    if len(indices) == 1:
        # Point landmark (e.g., cheek, chin point) -> center crop around landmark
        cx, cy = roi_lms[0]
        crop_w, crop_h = target_size
        x = int(cx - crop_w / 2)
        y = int(cy - crop_h / 2)
    else:
        # Multi-point ROI -> calculate bounding box
        min_x, min_y = np.min(roi_lms, axis=0)
        max_x, max_y = np.max(roi_lms, axis=0)
        x, y = int(min_x), int(min_y)
        crop_w, crop_h = int(max_x - min_x), int(max_y - min_y)
        
    x = max(0, min(x, w - 1))
    y = max(0, min(y, h - 1))
    crop_w = max(1, min(crop_w, w - x))
    crop_h = max(1, min(crop_h, h - y))
    
    return (x, y, crop_w, crop_h)


def extract_roi_region(frame, bbox, target_size=ROI_BOX_SIZE):
    x, y, w, h = bbox
    crop = frame[y:y+h, x:x+w]
    if crop.size == 0:
        return np.zeros((*target_size, 3), dtype=np.uint8)
    return cv2.resize(crop, target_size, interpolation=cv2.INTER_AREA)

# ----------------------------------------------------------------------------
# 3. Signal Processing Helper Functions
# ----------------------------------------------------------------------------
def butter_bandpass_filter(data, lowcut=0.75, highcut=2.5, fs=30.0, order=4):
    nyq = 0.5 * fs
    low = lowcut / nyq
    high = highcut / nyq
    b, a = butter(order, [low, high], btype='band')
    return filtfilt(b, a, data)

def calculate_bpm_from_fft(signal_1d, fs=30.0, lowcut=0.75, highcut=2.5):
    signal_cleaned = signal_1d - np.mean(signal_1d)
    freqs, psd = welch(signal_cleaned, fs=fs, nperseg=len(signal_cleaned))
    valid_idx = np.where((freqs >= lowcut) & (freqs <= highcut))[0]
    if len(valid_idx) == 0:
        return 75.0
    peak_freq = freqs[valid_idx[np.argmax(psd[valid_idx])]]
    return peak_freq * 60.0

# ----------------------------------------------------------------------------
# 4. Model Architecture Load
# ----------------------------------------------------------------------------
class SpatioTemporalPhysNet(nn.Module):
    def __init__(self, num_rois=10, in_channels=3):
        super(SpatioTemporalPhysNet, self).__init__()
        self.num_rois = num_rois
        self.total_channels = num_rois * in_channels
        
        self.spatial_conv = nn.Sequential(
            nn.Conv3d(self.total_channels, 64, kernel_size=(1, 3, 3), padding=(0, 1, 1)),
            nn.BatchNorm3d(64),
            nn.ELU(),
            nn.AdaptiveAvgPool3d((None, 1, 1))
        )
        
        self.temporal_encoder = nn.Sequential(
            nn.Conv1d(64, 32, kernel_size=5, padding=2),
            nn.BatchNorm1d(32),
            nn.ELU(),
            nn.Conv1d(32, 16, kernel_size=5, padding=2),
            nn.BatchNorm1d(16),
            nn.ELU(),
            nn.Conv1d(16, 1, kernel_size=1)
        )

    def forward(self, x):
        x_spatial = self.spatial_conv(x)
        x_spatial = torch.squeeze(x_spatial, dim=-1)
        x_spatial = torch.squeeze(x_spatial, dim=-1)
        ppg_pred = self.temporal_encoder(x_spatial)
        return torch.squeeze(ppg_pred, dim=1)

# ----------------------------------------------------------------------------
# 5. Video Processing Pipeline
# ----------------------------------------------------------------------------
def process_video_for_physnet(video_path, detector, chunk_size=CHUNK_SIZE):
    if not os.path.exists(video_path):
        raise FileNotFoundError(f"Video file not found at: {video_path}")
        
    reader = imageio.get_reader(video_path, 'ffmpeg')
    meta = reader.get_meta_data()
    fps = meta.get('fps', 30.0)
    
    frames = []
    for i, frame in enumerate(reader):
        if i >= chunk_size:
            break
        frames.append(frame)
    reader.close()
    
    num_frames = len(frames)
    print(f"Loaded {num_frames} frames from '{os.path.basename(video_path)}' @ {fps:.2f} FPS")
    
    # Pad short videos if needed
    if num_frames < chunk_size:
        pad_count = chunk_size - num_frames
        frames += [frames[-1]] * pad_count
        print(f"Padded video from {num_frames} to {chunk_size} frames.")
        
    # Extract landmarks per frame
    chunk_landmarks = []
    detector.reset()
    for frame in frames:
        lms = detector.detect_landmarks(frame)
        if lms is not None:
            chunk_landmarks.append(lms)
        elif chunk_landmarks:
            chunk_landmarks.append(chunk_landmarks[-1].copy())
        else:
            chunk_landmarks.append(np.zeros((468, 2), dtype='float32'))
            
    chunk_landmarks = np.array(chunk_landmarks)
    
    # Crop ROIs for all frames
    roi_inputs = []
    for roi_name in ROI_ORDER:
        roi_indices = ROIS_MAPPING[roi_name]
        roi_frames = []
        for frame_idx, frame in enumerate(frames):
            landmarks = chunk_landmarks[frame_idx]
            if np.all(landmarks == 0):
                h, w = frame.shape[:2]
                bbox = (w // 2 - ROI_BOX_SIZE[0] // 2, h // 2 - ROI_BOX_SIZE[1] // 2, ROI_BOX_SIZE[0], ROI_BOX_SIZE[1])
            else:
                bbox = extract_roi_bbox(landmarks, roi_indices, frame.shape[:2], ROI_BOX_SIZE)
            
            roi_region = extract_roi_region(frame, bbox)
            roi_frames.append(roi_region)
            
        roi_array = np.array(roi_frames, dtype=np.float32) / 255.0  # (T, 24, 24, 3)
        roi_inputs.append(roi_array)
        
    # Format shape to match model input: (10, T, H, W, C) -> (1, 30, T, 24, 24)
    stacked_rois = np.stack(roi_inputs, axis=0)                     # (10, 450, 24, 24, 3)
    stacked_rois = np.transpose(stacked_rois, (0, 4, 1, 2, 3))     # (10, 3, 450, 24, 24)
    stacked_rois = np.reshape(stacked_rois, (10 * 3, CHUNK_SIZE, 24, 24)) # (30, 450, 24, 24)
    
    tensor_input = torch.tensor(stacked_rois, dtype=torch.float32).unsqueeze(0) # (1, 30, 450, 24, 24)
    return tensor_input, fps

# ----------------------------------------------------------------------------
# 6. Pipeline Execution
# ----------------------------------------------------------------------------
# Initialize MediaPipe Detector
detector = ModernFaceMeshDetector(model_path=MEDIAPIPE_MODEL_PATH)

# Initialize Model & Load Weights
model = SpatioTemporalPhysNet(num_rois=10).to(DEVICE)
if os.path.exists(MODEL_CHECKPOINT_PATH):
    # checkpoint = torch.load(MODEL_CHECKPOINT_PATH, map_location=DEVICE)
    checkpoint = torch.load(MODEL_CHECKPOINT_PATH, map_location=DEVICE, weights_only=False)
    if 'model_state_dict' in checkpoint:
        model.load_state_dict(checkpoint['model_state_dict'])
    else:
        model.load_state_dict(checkpoint)
    print(f"Successfully loaded model weights from: {MODEL_CHECKPOINT_PATH}")
else:
    print(f"[Warning] Checkpoint '{MODEL_CHECKPOINT_PATH}' not found. Using randomly initialized model.")

model.eval()

# Process video and perform forward pass
input_tensor, video_fps = process_video_for_physnet(VIDEO_PATH, detector, chunk_size=CHUNK_SIZE)
input_tensor = input_tensor.to(DEVICE)

print(f"\nModel Input Tensor Shape : {input_tensor.shape}")
print(f"Target Hardware Execution : {DEVICE}")

with torch.no_grad():
    predicted_ppg = model(input_tensor).squeeze(0).cpu().numpy()

# Post-processing & HR Extraction
filtered_ppg = butter_bandpass_filter(predicted_ppg, fs=video_fps)
normalized_ppg = (filtered_ppg - np.mean(filtered_ppg)) / (np.std(filtered_ppg) + 1e-8)
estimated_bpm = calculate_bpm_from_fft(filtered_ppg, fs=video_fps)

# Render Waveform Visualization
timeline = np.arange(len(normalized_ppg)) / video_fps
plt.figure(figsize=(15, 4))
plt.plot(timeline, normalized_ppg, color='#e91e63', linewidth=2, label='Predicted rPPG Signal')
plt.title(f"SpatioTemporalPhysNet Inference | Video: {os.path.basename(VIDEO_PATH)} | Estimated HR: {estimated_bpm:.1f} BPM", fontsize=12, fontweight='bold')
plt.xlabel("Time (seconds)")
plt.ylabel("Normalized BVP Signal")
plt.grid(True, linestyle=":", alpha=0.6)
plt.legend(loc="upper right")
plt.tight_layout()
plt.show()

# Clean up detector
detector.close()
# Out:
# W0000 00:00:1784828864.871238  384288 face_landmarker_graph.cc:174] Sets FaceBlendshapesGraph acceleration to xnnpack by default.
# I0000 00:00:1784828864.901005  384288 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# W0000 00:00:1784828864.919883  384347 gl_context.cc:343] failed to get GL_VERSION string
# I0000 00:00:1784828864.920044  384347 gl_context.cc:385] GL version: 3.2 (), renderer: (null)
# E0000 00:00:1784828864.920104  384347 gl_context.cc:310] Error querying for GL extensions
# I0000 00:00:1784828864.920818  384288 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# W0000 00:00:1784828864.928227  384348 gl_context.cc:343] failed to get GL_VERSION string
# I0000 00:00:1784828864.928252  384348 gl_context.cc:385] GL version: 3.2 (), renderer: (null)
# E0000 00:00:1784828864.928272  384348 gl_context.cc:310] Error querying for GL extensions
# I0000 00:00:1784828864.929400  384288 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# W0000 00:00:1784828864.949620  384349 gl_context.cc:343] failed to get GL_VERSION string
# I0000 00:00:1784828864.949715  384349 gl_context.cc:385] GL version: 3.2 (), renderer: (null)
# E0000 00:00:1784828864.949796  384349 gl_context.cc:310] Error querying for GL extensions
# I0000 00:00:1784828864.950588  384288 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# W0000 00:00:1784828864.960141  384350 gl_context.cc:343] failed to get GL_VERSION string
# I0000 00:00:1784828864.960224  384350 gl_context.cc:385] GL version: 3.2 (), renderer: (null)
# E0000 00:00:1784828864.960316  384350 gl_context.cc:310] Error querying for GL extensions
# I0000 00:00:1784828864.960929  384288 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# W0000 00:00:1784828864.968476  384351 gl_context.cc:343] failed to get GL_VERSION string
# I0000 00:00:1784828864.968503  384351 gl_context.cc:385] GL version: 3.2 (), renderer: (null)
# E0000 00:00:1784828864.968525  384351 gl_context.cc:310] Error querying for GL extensions
# W0000 00:00:1784828864.976351  384297 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1784828865.036294  384306 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# Successfully loaded model weights from: spatiotemporal_long_window450_physnet_best2.pth
# Loaded 450 frames from '9998_USBVideo_after.avi' @ 30.00 FPS
#
# Model Input Tensor Shape : torch.Size([1, 30, 450, 24, 24])
# Target Hardware Execution : cuda:1

# %%
PSDloss Model

# %%
import os
import json
import math
import copy
import random
from pathlib import Path
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.signal import butter, filtfilt, welch
from torch.optim.lr_scheduler import LinearLR, CosineAnnealingLR, SequentialLR

# Configure high-quality visualization styles
plt.style.use('seaborn-v0_8-whitegrid' if 'seaborn-v0_8-whitegrid' in plt.style.available else 'default')
sns.set_palette("muted")

# Setup default configurations
PREPROCESSED_DATA_PATH = Path('/home/cristic/preprocessed_data/')
CACHE_FILES = ["valid_files.txt", "train_files_cache.txt", "val_files_cache.txt"]
# Force usage of the second GPU (index 1)
gpu_id = 1 
DEVICE = torch.device(f'cuda:{gpu_id}' if torch.cuda.is_available() else 'cpu')
MODEL_SAVE_PATH = Path("spatiotemporal_physnet_best_shuffle.pth")

# Clean existing cache files before starting run
for cache in CACHE_FILES:
    if os.path.exists(cache):
        try:
            os.remove(cache)
            print(f"Removed old cache: {cache}")
        except Exception as e:
            print(f"Error removing cache {cache}: {e}")

# Strict order representing the 9 sub-ROIs + full face boundary configurations
ROI_ORDER = [
    'roi_forehead',
    'roi_left_cheek_280',
    'roi_right_cheek_50',
    'roi_nose',
    'roi_chin',
    'roi_chin_199',
    'roi_left_eye',
    'roi_right_eye',
    'roi_mouth',
    'roi_full_face'
]

def inspect_npz_color_space(npz_path, roi_key='roi_forehead'):
    """
    Diagnose NPZ color-space representations and plot channel intensities.
    Ensures RGB channels align with spatial tracking configurations.
    """
    print(f"\nEvaluating color space for path: {npz_path}")
    if not os.path.exists(npz_path):
        print(f"Color Space Inspector Notice: Sample {npz_path} does not exist yet.")
        return

    with np.load(npz_path) as data:
        if roi_key not in data:
            available = [k for k in data.keys() if k.startswith('roi_')]
            if not available:
                print("No ROIs found in file keys.")
                return
            print(f"Key '{roi_key}' not found. Available ROIs: {available}")
            roi_key = available[0]
            
        roi_data = data[roi_key]
        
    print(f"Loaded '{roi_key}' with shape: {roi_data.shape} and dtype: {roi_data.dtype}")
    
    first_frame = roi_data[0].copy()
    
    if first_frame.max() > 1.0:
        first_frame_norm = first_frame.astype(np.float32) / 255.0
    else:
        first_frame_norm = first_frame.astype(np.float32)
        
    c0 = first_frame_norm[:, :, 0]
    c1 = first_frame_norm[:, :, 1]
    c2 = first_frame_norm[:, :, 2]
    
    mean_c0, mean_c1, mean_c2 = c0.mean(), c1.mean(), c2.mean()
    
    print("\n--- Channel Intensity Statistics ---")
    print(f"Channel 0 Mean: {mean_c0:.4f}")
    print(f"Channel 1 Mean: {mean_c1:.4f}")
    print(f"Channel 2 Mean: {mean_c2:.4f}")
    print("------------------------------------\n")
    
    fig, axes = plt.subplots(1, 4, figsize=(16, 4))
    
    axes[0].imshow(first_frame_norm)
    axes[0].set_title("Direct Render (Assumes RGB)")
    axes[0].axis('off')
    
    im0 = axes[1].imshow(c0, cmap='gray', vmin=0, vmax=1)
    axes[1].set_title(f"Channel 0\n(Mean: {mean_c0:.3f})")
    axes[1].axis('off')
    plt.colorbar(im0, ax=axes[1], fraction=0.046, pad=0.04)
    
    im1 = axes[2].imshow(c1, cmap='gray', vmin=0, vmax=1)
    axes[2].set_title(f"Channel 1\n(Mean: {mean_c1:.3f})")
    axes[2].axis('off')
    plt.colorbar(im1, ax=axes[2], fraction=0.046, pad=0.04)
    
    im2 = axes[3].imshow(c2, cmap='gray', vmin=0, vmax=1)
    axes[3].set_title(f"Channel 2\n(Mean: {mean_c2:.3f})")
    axes[3].axis('off')
    plt.colorbar(im2, ax=axes[3], fraction=0.046, pad=0.04)
    
    plt.tight_layout()
    plt.show()

def butter_bandpass_filter(data, lowcut=0.75, highcut=2.5, fs=30.0, order=4):
    """Apply zero-phase Butterworth bandpass filter to capture human heart rate (45-150 BPM)."""
    nyq = 0.5 * fs
    low = lowcut / nyq
    high = highcut / nyq
    b, a = butter(order, [low, high], btype='band')
    return filtfilt(b, a, data)

def calculate_bpm_from_fft(signal_1d, fs=30.0, lowcut=0.75, highcut=2.5):
    """Extract heart rate (BPM) from the dominant peak of the Power Spectral Density."""
    signal_cleaned = signal_1d - np.mean(signal_1d)
    freqs, psd = welch(signal_cleaned, fs=fs, nperseg=len(signal_cleaned))
    
    valid_idx = np.where((freqs >= lowcut) & (freqs <= highcut))[0]
    if len(valid_idx) == 0:
        return 75.0
    
    peak_freq = freqs[valid_idx[np.argmax(psd[valid_idx])]]
    return peak_freq * 60.0

def load_npz_file(file_path):
    """Securely load and parse an NPZ file."""
    try:
        data = np.load(file_path, allow_pickle=True)
        return data
    except Exception as e:
        print(f"Error loading {file_path}: {e}")
        return None

def analyze_npz_structure(data):
    """Analyze and print the metadata keys and array dimensions of loaded files."""
    if data is None:
        print("NPZ Analysis Error: Provided data object is None.")
        return
    print("\n" + "=" * 75)
    print("               NPZ FILE STRUCTURE SHOWCASE (9-ROI + Face Configuration)")
    print("=" * 75)
    for key in sorted(data.files):
        item = data[key]
        if hasattr(item, 'shape'):
            print(f"  {key:<27} : Shape {str(item.shape):<20} | Dtype {item.dtype}")
        else:
            print(f"  {key:<27} : Metadata / Scalar Object")
    print("=" * 75 + "\n")

def create_synthetic_dataset(target_dir, num_files=12, num_frames=450):
    """Generate mock datasets matching strict multi-ROI formatting standards."""
    target_dir.mkdir(parents=True, exist_ok=True)
    print(f"\nTarget dataset directory '{target_dir}' is empty or missing.")
    print("Generating synthetic 9-ROI + face NPZ dataset mimicking real schemas...")
    
    fs = 30.0
    t = np.arange(num_frames) / fs
    
    for i in range(num_files):
        hr_hz = np.random.uniform(1.0, 1.5)
        bvp = np.sin(2 * np.pi * hr_hz * t) + 0.35 * np.sin(2 * np.pi * (hr_hz * 2) * t)
        bvp += 0.2 * np.sin(2 * np.pi * 0.2 * t)
        bvp = (bvp - np.mean(bvp)) / (np.std(bvp) + 1e-8)
        
        data_dict = {
            'time_deltas': (t * 1000.0).astype(np.float64),
            'ppg_values': bvp.astype(np.float64)
        }
        
        for roi in ROI_ORDER:
            base_skin = np.array([185.0, 125.0, 105.0]) if "eye" not in roi else np.array([210.0, 190.0, 180.0])
            pixel_noise = np.random.normal(0, 1.2, size=(num_frames, 24, 24, 3))
            
            pulse_modulator = np.zeros((num_frames, 24, 24, 3))
            pulse_modulator[..., 0] = bvp[:, None, None] * 0.15
            pulse_modulator[..., 1] = bvp[:, None, None] * 0.55
            pulse_modulator[..., 2] = bvp[:, None, None] * 0.05
            
            roi_frames = (base_skin + pulse_modulator + pixel_noise).clip(0, 255).astype(np.uint8)
            data_dict[roi] = roi_frames
            
        np.savez(target_dir / f"subject_{i+1:02d}_session_01.npz", **data_dict)
    print("Synthetic dataset successfully created!\n")

class PPGMultiROIDataset(Dataset):
    """Optimized Dataset class with inline spatial and temporal sequence augmentations."""
    def __init__(self, file_paths, sequence_length=450, fs=30.0, augment=False):
        self.file_paths = file_paths
        self.sequence_length = sequence_length
        self.fs = fs
        self.augment = augment
        self.samples = []
        
        self._prepare_samples()

    def _prepare_samples(self):
        """Pre-segment matching timelines into sequence lengths."""
        for path in self.file_paths:
            data = load_npz_file(path)
            if data is None:
                continue
            
            ppg_key = 'ppg_values' if 'ppg_values' in data else 'ppg'
            length = len(data[ppg_key])
            num_windows = length // self.sequence_length
            
            for w in range(num_windows):
                start_idx = w * self.sequence_length
                end_idx = start_idx + self.sequence_length
                self.samples.append((path, start_idx, end_idx))

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        file_path, start, end = self.samples[idx]
        data = load_npz_file(file_path)
        
        ppg_key = 'ppg_values' if 'ppg_values' in data else 'ppg'
        ppg_segment = data[ppg_key][start:end]
        ppg_segment = butter_bandpass_filter(ppg_segment, fs=self.fs)
        
        # 2. Standardize Target Waveforms (Zero-mean, unit-variance)
        ppg_normalized = (ppg_segment - np.mean(ppg_segment)) / (np.std(ppg_segment) + 1e-8)
        
        roi_inputs = []
        for roi_name in ROI_ORDER:
            actual_key = next((k for k in data.files if roi_name == k), None)
            
            if actual_key is not None:
                roi_data = data[actual_key][start:end]
            else:
                roi_data = np.zeros((self.sequence_length, 24, 24, 3), dtype=np.uint8)
                
            roi_data = roi_data.astype(np.float32) / 255.0
            roi_inputs.append(roi_data)
            
        # Perform coordinated sequence augmentations across all 10 regions
        if self.augment:
            # 50% chance of random horizontal flip
            if np.random.rand() > 0.5:
                roi_inputs = [np.flip(roi, axis=2) for roi in roi_inputs]
                
            # 50% chance of random vertical flip
            if np.random.rand() > 0.5:
                roi_inputs = [np.flip(roi, axis=1) for roi in roi_inputs]
                
            # 50% chance of brightness jittering
            if np.random.rand() > 0.5:
                brightness_factor = np.random.uniform(0.9, 1.1)
                roi_inputs = [np.clip(roi * brightness_factor, 0.0, 1.0) for roi in roi_inputs]
                
        # Structure dimension mapping: (10, T, H, W, C) -> (10, C, T, H, W) -> (10 * C, T, H, W)
        stacked_rois = np.stack(roi_inputs, axis=0)
        stacked_rois = np.transpose(stacked_rois, (0, 4, 1, 2, 3))
        stacked_rois = np.reshape(stacked_rois, (10 * 3, self.sequence_length, 24, 24))
        
        return torch.tensor(stacked_rois, dtype=torch.float32), torch.tensor(ppg_normalized, dtype=torch.float32)

class SpatioTemporalPhysNet(nn.Module):
    """
    Spatio-Temporal convolutional network engineered to extract micro-color variations
    harmoniously across 10 face zones (30 raw input channels).
    """
    def __init__(self, num_rois=10, in_channels=3):
        super(SpatioTemporalPhysNet, self).__init__()
        self.num_rois = num_rois
        self.total_channels = num_rois * in_channels
        
        self.spatial_conv = nn.Sequential(
            nn.Conv3d(self.total_channels, 64, kernel_size=(1, 3, 3), padding=(0, 1, 1)),
            nn.BatchNorm3d(64),
            nn.ELU(),
            nn.AdaptiveAvgPool3d((None, 1, 1))
        )
        
        self.temporal_encoder = nn.Sequential(
            nn.Conv1d(64, 32, kernel_size=5, padding=2),
            nn.BatchNorm1d(32),
            nn.ELU(),
            nn.Conv1d(32, 16, kernel_size=5, padding=2),
            nn.BatchNorm1d(16),
            nn.ELU(),
            nn.Conv1d(16, 1, kernel_size=1)
        )

    def forward(self, x):
        # 1. Standard Normalization for Input Tensors (Temporal Z-Score Standardization)
        # x shape: (B, C, T, H, W) -> standardize over T per channel
        mean = x.mean(dim=2, keepdim=True)
        # std = x.std(dim=2, keepdim=True) + 1e-8
        # x = (x - mean) / std
        x = (x - mean) / (mean + 1e-8) 
        
        x_spatial = self.spatial_conv(x)
        x_spatial = torch.squeeze(x_spatial, dim=-1)
        x_spatial = torch.squeeze(x_spatial, dim=-1)
        
        ppg_pred = self.temporal_encoder(x_spatial)
        return torch.squeeze(ppg_pred, dim=1)

# class NegativePearsonCorrelationLoss(nn.Module):
#     """Loss module measuring BVP signal phase synchronization."""
#     def __init__(self):
#         super(NegativePearsonCorrelationLoss, self).__init__()

#     def forward(self, pred, target):
#         pred_mean = torch.mean(pred, dim=-1, keepdim=True)
#         target_mean = torch.mean(target, dim=-1, keepdim=True)
        
#         pred_centered = pred - pred_mean
#         target_centered = target - target_mean
        
#         r_num = torch.sum(pred_centered * target_centered, dim=-1)
#         r_den = torch.sqrt(torch.sum(pred_centered ** 2, dim=-1) * torch.sum(target_centered ** 2, dim=-1) + 1e-8)
        
#         pearson_coeff = r_num / r_den
#         return 1.0 - torch.mean(pearson_coeff)

import torch
import torch.nn as nn

# class NegativePearsonCorrelationLoss(nn.Module):
#     """Loss module measuring BVP signal phase synchronization."""
#     def __init__(self, eps=1e-8):
#         super(NegativePearsonCorrelationLoss, self).__init__()
#         self.eps = eps

#     def forward(self, pred, target):
#         # Flatten extra spatial/channel dims if needed, keeping batch (dim 0) and time (dim -1)
#         pred = pred.view(pred.size(0), -1)
#         target = target.view(target.size(0), -1)

#         pred_mean = torch.mean(pred, dim=-1, keepdim=True)
#         target_mean = torch.mean(target, dim=-1, keepdim=True)
        
#         pred_centered = pred - pred_mean
#         target_centered = target - target_mean
        
#         r_num = torch.sum(pred_centered * target_centered, dim=-1)
        
#         # Calculate variances safely with separate square roots
#         var_pred = torch.sum(pred_centered ** 2, dim=-1)
#         var_target = torch.sum(target_centered ** 2, dim=-1)
        
#         # Safe denominator with epsilon outside sqrt
#         r_den = torch.sqrt(var_pred) * torch.sqrt(var_target) + self.eps
        
#         pearson_coeff = r_num / r_den
#         return 1.0 - torch.mean(pearson_coeff)
class NegativePearsonCorrelationLoss(nn.Module):
    """Loss module measuring BVP signal phase synchronization."""
    def __init__(self, eps=1e-8):
        super(NegativePearsonCorrelationLoss, self).__init__()
        self.eps = eps

    def forward(self, pred, target):
        # Flatten extra spatial/channel dims, keeping batch (dim 0) and time (dim -1)
        pred = pred.view(pred.size(0), -1)
        target = target.view(target.size(0), -1)

        pred_mean = torch.mean(pred, dim=-1, keepdim=True)
        target_mean = torch.mean(target, dim=-1, keepdim=True)
        
        pred_centered = pred - pred_mean
        target_centered = target - target_mean
        
        r_num = torch.sum(pred_centered * target_centered, dim=-1)
        
        # Calculate sum of squares
        var_pred = torch.sum(pred_centered ** 2, dim=-1)
        var_target = torch.sum(target_centered ** 2, dim=-1)
        
        # Add epsilon INSIDE the square roots to prevent infinite gradients (sqrt(0)' -> inf)
        r_den = torch.sqrt(var_pred + self.eps) * torch.sqrt(var_target + self.eps)
        
        # Clamp PCC output between -1.0 and 1.0 to guarantee numerical bounds
        pearson_coeff = torch.clamp(r_num / r_den, min=-1.0, max=1.0)
        
        return 1.0 - torch.mean(pearson_coeff)    
# class NegPearsonLoss(nn.Module):
#     def __init__(self):
#         super(NegPearsonLoss, self).__init__()

#     def forward(self, pred, target):
#         # Ensure shape is (Batch, Frames)
#         pred = pred.view(pred.size(0), -1)
#         target = target.view(target.size(0), -1)

#         # Mean-center along TIME axis
#         pred_mean = pred - torch.mean(pred, dim=-1, keepdim=True)
#         target_mean = target - torch.mean(target, dim=-1, keepdim=True)

#         # Compute covariance & variance along TIME axis
#         cov = torch.sum(pred_mean * target_mean, dim=-1)
#         var_pred = torch.sum(pred_mean ** 2, dim=-1)
#         var_target = torch.sum(target_mean ** 2, dim=-1)

#         # Per-sample Pearson correlation
#         pcc = cov / (torch.sqrt(var_pred * var_target) + 1e-8)

#         # Return 1 - average PCC across batch
#         return torch.mean(1.0 - pcc)
class PSDLoss(nn.Module):
    """Frequency Loss enforcing peak alignment in Power Spectral Density via KL-Divergence."""
    def __init__(self, fps=30.0, low_bpm=40.0, high_bpm=180.0):
        super(PSDLoss, self).__init__()
        self.fps = fps
        self.low_bpm = low_bpm
        self.high_bpm = high_bpm

    def forward(self, pred, target):
        N = pred.size(-1)
        window = torch.hann_window(N, device=pred.device)
        
        pred_fft = torch.abs(torch.fft.rfft(pred * window, dim=-1))
        target_fft = torch.abs(torch.fft.rfft(target * window, dim=-1))
        
        freqs = torch.fft.rfftfreq(N, d=1.0 / self.fps).to(pred.device)
        mask = (freqs >= self.low_bpm / 60.0) & (freqs <= self.high_bpm / 60.0)
        
        pred_psd = pred_fft[..., mask]
        target_psd = target_fft[..., mask]
        
        pred_prob = F.softmax(pred_psd, dim=-1)
        target_prob = F.softmax(target_psd, dim=-1)
        
        return F.kl_div(torch.log(pred_prob + 1e-8), target_prob, reduction='batchmean')

def calculate_metrics(y_pred, y_true, fs=30.0):
    """Extract performance evaluation metrics (PCC, MAE, RMSE, and SNR)."""
    pcc_list, mae_list, rmse_list, snr_list = [], [], [], []
    
    for i in range(len(y_pred)):
        pred, true = y_pred[i], y_true[i]
        
        pcc = np.corrcoef(pred, true)[0, 1]
        pcc_list.append(0.0 if np.isnan(pcc) else pcc)
        
        bpm_pred = calculate_bpm_from_fft(pred, fs=fs)
        bpm_true = calculate_bpm_from_fft(true, fs=fs)
        
        mae_list.append(abs(bpm_pred - bpm_true))
        rmse_list.append((bpm_pred - bpm_true) ** 2)
        
        pred_detrended = pred - np.mean(pred)
        freqs, psd = welch(pred_detrended, fs=fs, nperseg=len(pred_detrended))
        
        gt_freq = bpm_true / 60.0
        signal_mask = (freqs >= (gt_freq - 0.15)) & (freqs <= (gt_freq + 0.15))
        noise_mask = ~signal_mask & (freqs >= 0.75) & (freqs <= 2.5)
        
        signal_power = np.sum(psd[signal_mask])
        noise_power = np.sum(psd[noise_mask]) + 1e-8
        snr_list.append(10 * np.log10(signal_power / noise_power))
        
    return {
        'PCC': np.mean(pcc_list),
        'MAE': np.mean(mae_list),
        'RMSE': math.sqrt(np.mean(rmse_list)),
        'SNR': np.mean(snr_list)
    }

def save_model_checkpoint(model, optimizer, epoch, metrics, save_path=MODEL_SAVE_PATH):
    """Save model checkpoint along with optimizer state and validation metrics."""
    checkpoint = {
        'epoch': epoch,
        'model_state_dict': model.state_dict(),
        'optimizer_state_dict': optimizer.state_dict(),
        'metrics': metrics
    }
    torch.save(checkpoint, save_path)
    print(f"Model checkpoint successfully saved to: {save_path}")

if not any(PREPROCESSED_DATA_PATH.glob('*.npz')):
    create_synthetic_dataset(PREPROCESSED_DATA_PATH, num_files=12)

npz_files = sorted(list(PREPROCESSED_DATA_PATH.glob('*.npz')))
print(f"Total files available for analysis: {len(npz_files)}")

first_file_data = load_npz_file(npz_files[0])
analyze_npz_structure(first_file_data)
inspect_npz_color_space(npz_files[0])

# --- Three-Way Dataset Splitting (Train 70%, Validation 15%, Evaluation 15%) ---
random.seed(42)
shuffled_files = npz_files.copy()
random.shuffle(shuffled_files)

n_total = len(shuffled_files)
n_train = max(1, int(n_total * 0.70))
n_val = max(1, int(n_total * 0.15))

train_split = shuffled_files[:n_train]
val_split = shuffled_files[n_train:n_train + n_val]
eval_split = shuffled_files[n_train + n_val:]

train_dataset = PPGMultiROIDataset(train_split, augment=True)
val_dataset = PPGMultiROIDataset(val_split, augment=False)
eval_dataset = PPGMultiROIDataset(eval_split, augment=False)

batch_sz = 16
train_loader = DataLoader(train_dataset, batch_size=batch_sz, shuffle=True, prefetch_factor=4, num_workers=8, pin_memory=True, persistent_workers=True)
val_loader = DataLoader(val_dataset, batch_size=batch_sz, shuffle=False, prefetch_factor=4, num_workers=8, pin_memory=True, persistent_workers=True)
eval_loader = DataLoader(eval_dataset, batch_size=batch_sz, shuffle=False, prefetch_factor=4, num_workers=8, pin_memory=True, persistent_workers=True)

# ----------------------------------------------------------------------------
# 1. Setup Model, Loss Functions, Optimizer & Scheduler
# ----------------------------------------------------------------------------
model = SpatioTemporalPhysNet(num_rois=10).to(DEVICE)
criterion_pearson = NegativePearsonCorrelationLoss()
criterion_mse = nn.MSELoss()
criterion_psd = PSDLoss(fps=30.0)

optimizer = torch.optim.AdamW(model.parameters(), lr=3e-4, weight_decay=1e-2)

num_epochs = 150
warmup_epochs = 20

scheduler1 = LinearLR(optimizer, start_factor=0.1, total_iters=warmup_epochs)
scheduler2 = CosineAnnealingLR(optimizer, T_max=num_epochs - warmup_epochs, eta_min=1e-6)
scheduler = SequentialLR(optimizer, schedulers=[scheduler1, scheduler2], milestones=[warmup_epochs])

# ----------------------------------------------------------------------------
# 2. Checkpointing & Early Stopping Settings
# ----------------------------------------------------------------------------
CHECKPOINT_SAVE_PATH = "best_spatiotemporal_physnet.pt"
patience = 15              # Stop after 15 consecutive epochs without improvement
patience_counter = 0
best_val_loss = float('inf')
best_model_weights = None

train_losses, val_losses ,val_pccs = [], [],[]

print("Starting optimization loop...")

# ----------------------------------------------------------------------------
# 3. Training & Validation Loop
# ----------------------------------------------------------------------------
for epoch in range(num_epochs):
    # --- Training Phase ---
    model.train()
    # 1. Dynamically update loss weights based on the current epoch
    if epoch <= warmup_epochs:
        # Phase 1 (Warm-up): Higher PSD weight to quickly anchor the HR frequency
        # w_p = 2.0   # Pearson Phase weight
        # w_m = 0.3   # MSE weight
        # w_s = 0.75  # PSD Spectral weight
        # Calculate interpolation factor (0.0 to 1.0)
        alpha = min(1.0, epoch / warmup_epochs)
        
        # Linearly interpolate between starting and ending weights
        w_p = 2.0 + (4.0 - 2.0) * alpha
        w_m = 0.3 + (0.1 - 0.3) * alpha
        w_s = 0.75 + (0.15 - 0.75) * alpha
    else:
        # Phase 2 (Fine-tuning): Drop PSD/MSE and heavily boost Pearson for exact frame alignment
        w_p = 4.0   # Boosted Pearson weight
        w_m = 0.1   # Reduced MSE weight
        w_s = 0.15  # Dropped PSD weight (prevents phase hijacking)
        
    running_loss = 0.0
    # running_loss = 0.0
    
    for inputs, targets in train_loader:
        inputs, targets = inputs.to(DEVICE), targets.to(DEVICE)
        
        optimizer.zero_grad()
        outputs = model(inputs)
        
        # Combined Phase Loss + MSE + Spectral Peak Loss
        loss_p = criterion_pearson(outputs, targets)
        loss_m = criterion_mse(outputs, targets)
        loss_s = criterion_psd(outputs, targets)
        
        # loss = 2*loss_p + 0.3 * loss_m + 0.75 * loss_s
        loss = (w_p * loss_p) + (w_m * loss_m) + (w_s * loss_s)
        loss.backward()
        
        # Clip gradients to prevent stability issues in spatio-temporal convolutions
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        
        optimizer.step()
        running_loss += loss.item() * inputs.size(0)
        
    train_loss = running_loss / len(train_loader.dataset)
    train_losses.append(train_loss)
    
    # --- Validation Phase ---
    model.eval()
    running_val_loss = 0.0
    val_pcc_accum = 0.0
    with torch.no_grad():
        for val_inputs, val_targets in val_loader:
            val_inputs, val_targets = val_inputs.to(DEVICE), val_targets.to(DEVICE)
            val_outputs = model(val_inputs)
            
            val_loss_p = criterion_pearson(val_outputs, val_targets)
            val_loss_m = criterion_mse(val_outputs, val_targets)
            val_loss_s = criterion_psd(val_outputs, val_targets)
            
            # val_loss = val_loss_p + 0.3 * val_loss_m + 1.0 * val_loss_s
            val_loss = (w_p * val_loss_p) + (w_m * val_loss_m) + (w_s * val_loss_s)
            running_val_loss += val_loss.item() * val_inputs.size(0)
            batch_pcc = 1.0 - val_loss_p.item()
            val_pcc_accum += batch_pcc
            
    val_loss = running_val_loss / len(val_loader.dataset)
    val_losses.append(val_loss)

    val_pcc = val_pcc_accum / len(val_loader)
    val_pccs.append(val_pcc)  # Optional: keep history array for plotting                             )
    # --- Update Scheduler ---
    scheduler.step()
    current_lr = scheduler.get_last_lr()[0]
    
    print(f"Epoch {epoch+1:02d}/{num_epochs:02d} | LR: {current_lr:.6f} | Train Loss: {train_loss:.4f} | Val Loss: {val_loss:.4f} | Val PCC: {val_pcc:+.4f}")

    # --- Best Model Checkpointing & Early Stopping Logic ---
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        patience_counter = 0
        best_model_weights = {k: v.cpu().clone() for k, v in model.state_dict().items()}
        # Save best model to disk
        torch.save({
            'epoch': epoch + 1,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'val_loss': val_loss,
        }, CHECKPOINT_SAVE_PATH)
        print(f"   ---> Improved! Saved new best model checkpoint to '{CHECKPOINT_SAVE_PATH}' (Val Loss: {val_loss:.4f})")
    else:
        patience_counter += 1
        print(f"   ---> No improvement in validation loss for {patience_counter}/{patience} epochs.")
        if patience_counter >= patience:
            print(f"\n[Early Stopping Triggered] Stopping training early at Epoch {epoch+1}.")
            break

# ----------------------------------------------------------------------------
# 4. Load Best Model Weights for Evaluation
# ----------------------------------------------------------------------------
if best_model_weights is not None:
    print(f"\nLoading best model state dict from memory (Best Val Loss: {best_val_loss:.4f})...")
    model.load_state_dict(best_model_weights)

# ----------------------------------------------------------------------------
# 5. Held-Out Evaluation Set Assessment
# ----------------------------------------------------------------------------
model.eval()
all_preds, all_trues = [], []

with torch.no_grad():
    for eval_inputs, eval_targets in eval_loader:
        eval_inputs = eval_inputs.to(DEVICE)
        preds = model(eval_inputs).cpu().numpy()
        all_preds.extend(preds)
        all_trues.extend(eval_targets.numpy())

all_preds, all_trues = np.array(all_preds), np.array(all_trues)
metrics = calculate_metrics(all_preds, all_trues)

print("\n" + "=" * 50)
print("             EVALUATION SET METRICS RESULTS")
print("=" * 50)
print(f"  Pearson Correlation Coefficient (PCC) : {metrics['PCC']:.4f}")
print(f"  Mean Absolute Error (MAE)            : {metrics['MAE']:.2f} BPM")
print(f"  Root Mean Squared Error (RMSE)       : {metrics['RMSE']:.2f} BPM")
print(f"  Signal-to-Noise Ratio (SNR)          : {metrics['SNR']:.2f} dB")
print("=" * 50 + "\n")

# Save final checkpoint
save_model_checkpoint(model, optimizer, epoch + 1, metrics)

# ----------------------------------------------------------------------------
# 6. Final Dataset Sample Statistics Table
# ----------------------------------------------------------------------------
n_total_samples = len(train_dataset) + len(val_dataset) + len(eval_dataset)

print("\n" + "=" * 70)
print("                DATASET SPLIT & SAMPLE SUMMARY TABLE")
print("=" * 70)
print(f"{'Split Set':<15} | {'NPZ Files':<10} | {'450-Frame Windows':<20} | {'Batches':<10} | {'Ratio':<8}")
print("-" * 70)
print(f"{'Train':<15} | {len(train_split):<10} | {len(train_dataset):<20} | {len(train_loader):<10} | {len(train_dataset)/max(1,n_total_samples)*100:.1f}%")
print(f"{'Validation':<15} | {len(val_split):<10} | {len(val_dataset):<20} | {len(val_loader):<10} | {len(val_dataset)/max(1,n_total_samples)*100:.1f}%")
print(f"{'Evaluation':<15} | {len(eval_split):<10} | {len(eval_dataset):<20} | {len(eval_loader):<10} | {len(eval_dataset)/max(1,n_total_samples)*100:.1f}%")
print("-" * 70)
print(f"{'TOTAL':<15} | {n_total:<10} | {n_total_samples:<20} | {len(train_loader)+len(val_loader)+len(eval_loader):<10} | 100.0%")
print("=" * 70 + "\n")
# Out:
# Total files available for analysis: 26322
#
# ===========================================================================
#                NPZ FILE STRUCTURE SHOWCASE (9-ROI + Face Configuration)
# ===========================================================================
#   landmarks                   : Shape (450, 468, 2)        | Dtype float32
#   meta_camera_type            : Shape ()                   | Dtype <U12
#   meta_chunk_index            : Shape ()                   | Dtype int64
#   meta_condition              : Shape ()                   | Dtype <U5
#   meta_end_frame              : Shape ()                   | Dtype int64
#   meta_num_frames             : Shape ()                   | Dtype int64
#   meta_start_frame            : Shape ()                   | Dtype int64
#   meta_subject_id             : Shape ()                   | Dtype int64
#   meta_view_type              : Shape ()                   | Dtype <U5
#   ppg_values                  : Shape (450,)               | Dtype float64
#   roi_chin                    : Shape (450, 24, 24, 3)     | Dtype uint8
#   roi_chin_199                : Shape (450, 24, 24, 3)     | Dtype uint8
#   roi_forehead                : Shape (450, 24, 24, 3)     | Dtype uint8
#   roi_full_face               : Shape (450, 24, 24, 3)     | Dtype uint8
#   roi_left_cheek_280          : Shape (450, 24, 24, 3)     | Dtype uint8
#   roi_left_eye                : Shape (450, 24, 24, 3)     | Dtype uint8
#   roi_mouth                   : Shape (450, 24, 24, 3)     | Dtype uint8
#   roi_nose                    : Shape (450, 24, 24, 3)     | Dtype uint8
#   roi_right_cheek_50          : Shape (450, 24, 24, 3)     | Dtype uint8
#   roi_right_eye               : Shape (450, 24, 24, 3)     | Dtype uint8
#   time_deltas                 : Shape (450,)               | Dtype float64
#   vital_cholesterol           : Shape ()                   | Dtype float64
#   vital_glycated_hemoglobin   : Shape ()                   | Dtype float64
#   vital_hemoglobin            : Shape ()                   | Dtype float64
#   vital_lower_ap              : Shape ()                   | Dtype float64
#   vital_pulse                 : Shape ()                   | Dtype float64
#   vital_respiratory           : Shape ()                   | Dtype float64
#   vital_rigidity              : Shape ()                   | Dtype float64
#   vital_saturation            : Shape ()                   | Dtype float64
#   vital_stress                : Shape ()                   | Dtype float64
#   vital_upper_ap              : Shape ()                   | Dtype float64
# ===========================================================================
#
#
# Evaluating color space for path: /home/cristic/preprocessed_data/1020_FullHDwebcam_after_chunk0.npz
# Loaded 'roi_forehead' with shape: (450, 24, 24, 3) and dtype: uint8
#
# --- Channel Intensity Statistics ---
# Channel 0 Mean: 0.5472
# Channel 1 Mean: 0.4347
# Channel 2 Mean: 0.3352
# ------------------------------------
# Starting optimization loop...
# Epoch 01/150 | LR: 0.000043 | Train Loss: 4.8899 | Val Loss: 4.6437 | Val PCC: -0.0075
#    ---> Improved! Saved new best model checkpoint to 'best_spatiotemporal_physnet.pt' (Val Loss: 4.6437)
# Epoch 02/150 | LR: 0.000057 | Train Loss: 4.6220 | Val Loss: 4.5884 | Val PCC: -0.0091
#    ---> Improved! Saved new best model checkpoint to 'best_spatiotemporal_physnet.pt' (Val Loss: 4.5884)
# Epoch 03/150 | LR: 0.000070 | Train Loss: 4.5741 | Val Loss: 4.5553 | Val PCC: -0.0080
#    ---> Improved! Saved new best model checkpoint to 'best_spatiotemporal_physnet.pt' (Val Loss: 4.5553)
# Epoch 04/150 | LR: 0.000084 | Train Loss: 4.5386 | Val Loss: 4.5331 | Val PCC: -0.0069
#    ---> Improved! Saved new best model checkpoint to 'best_spatiotemporal_physnet.pt' (Val Loss: 4.5331)
# Epoch 05/150 | LR: 0.000097 | Train Loss: 4.5089 | Val Loss: 4.5138 | Val PCC: -0.0060
#    ---> Improved! Saved new best model checkpoint to 'best_spatiotemporal_physnet.pt' (Val Loss: 4.5138)
# Epoch 06/150 | LR: 0.000111 | Train Loss: 4.4814 | Val Loss: 4.4859 | Val PCC: -0.0054
#    ---> Improved! Saved new best model checkpoint to 'best_spatiotemporal_physnet.pt' (Val Loss: 4.4859)
# Epoch 07/150 | LR: 0.000124 | Train Loss: 4.4587 | Val Loss: 4.4762 | Val PCC: -0.0042
#    ---> Improved! Saved new best model checkpoint to 'best_spatiotemporal_physnet.pt' (Val Loss: 4.4762)
# Epoch 08/150 | LR: 0.000138 | Train Loss: 4.4405 | Val Loss: 4.4515 | Val PCC: -0.0044
#    ---> Improved! Saved new best model checkpoint to 'best_spatiotemporal_physnet.pt' (Val Loss: 4.4515)
# Epoch 09/150 | LR: 0.000151 | Train Loss: 4.4206 | Val Loss: 4.4462 | Val PCC: -0.0045
#    ---> Improved! Saved new best model checkpoint to 'best_spatiotemporal_physnet.pt' (Val Loss: 4.4462)
# Epoch 10/150 | LR: 0.000165 | Train Loss: 4.4055 | Val Loss: 4.4229 | Val PCC: -0.0039
#    ---> Improved! Saved new best model checkpoint to 'best_spatiotemporal_physnet.pt' (Val Loss: 4.4229)
# Epoch 11/150 | LR: 0.000179 | Train Loss: 4.3879 | Val Loss: 4.4476 | Val PCC: -0.0028
#    ---> No improvement in validation loss for 1/15 epochs.
# Epoch 12/150 | LR: 0.000192 | Train Loss: 4.3816 | Val Loss: 4.4073 | Val PCC: -0.0035
#    ---> Improved! Saved new best model checkpoint to 'best_spatiotemporal_physnet.pt' (Val Loss: 4.4073)
# Epoch 13/150 | LR: 0.000206 | Train Loss: 4.3630 | Val Loss: 4.3959 | Val PCC: -0.0034
#    ---> Improved! Saved new best model checkpoint to 'best_spatiotemporal_physnet.pt' (Val Loss: 4.3959)
# Epoch 14/150 | LR: 0.000219 | Train Loss: 4.3523 | Val Loss: 4.3927 | Val PCC: -0.0030
#    ---> Improved! Saved new best model checkpoint to 'best_spatiotemporal_physnet.pt' (Val Loss: 4.3927)
# Epoch 15/150 | LR: 0.000233 | Train Loss: 4.3436 | Val Loss: 4.3775 | Val PCC: -0.0033
#    ---> Improved! Saved new best model checkpoint to 'best_spatiotemporal_physnet.pt' (Val Loss: 4.3775)
# Epoch 16/150 | LR: 0.000246 | Train Loss: 4.3321 | Val Loss: 4.3779 | Val PCC: -0.0036
#    ---> No improvement in validation loss for 1/15 epochs.
# Epoch 17/150 | LR: 0.000260 | Train Loss: 4.3215 | Val Loss: 4.3501 | Val PCC: -0.0033
#    ---> Improved! Saved new best model checkpoint to 'best_spatiotemporal_physnet.pt' (Val Loss: 4.3501)
# Epoch 18/150 | LR: 0.000273 | Train Loss: 4.3093 | Val Loss: 4.3694 | Val PCC: -0.0031
#    ---> No improvement in validation loss for 1/15 epochs.
# Epoch 19/150 | LR: 0.000287 | Train Loss: 4.2982 | Val Loss: 4.3598 | Val PCC: -0.0020
#    ---> No improvement in validation loss for 2/15 epochs.
# /home/cristic/anaconda3/envs/rppg/lib/python3.11/site-packages/torch/optim/lr_scheduler.py:243: UserWarning: The epoch parameter in `scheduler.step()` was not necessary and is being deprecated where possible. Please use `scheduler.step()` to step the scheduler. During the deprecation, if epoch is different from None, the closed form is used instead of the new chainable form, where available. Please open an issue if you are unable to replicate your use case: https://github.com/pytorch/pytorch/issues/new/choose.
#   warnings.warn(EPOCH_DEPRECATION_WARNING, UserWarning)
# Epoch 20/150 | LR: 0.000300 | Train Loss: 4.2844 | Val Loss: 4.3297 | Val PCC: -0.0026
#    ---> Improved! Saved new best model checkpoint to 'best_spatiotemporal_physnet.pt' (Val Loss: 4.3297)
# Epoch 21/150 | LR: 0.000300 | Train Loss: 4.2739 | Val Loss: 4.3334 | Val PCC: -0.0029
#    ---> No improvement in validation loss for 1/15 epochs.
# Epoch 22/150 | LR: 0.000300 | Train Loss: 4.0039 | Val Loss: 4.0189 | Val PCC: -0.0010
#    ---> Improved! Saved new best model checkpoint to 'best_spatiotemporal_physnet.pt' (Val Loss: 4.0189)
# Epoch 23/150 | LR: 0.000300 | Train Loss: 3.9999 | Val Loss: 4.0177 | Val PCC: -0.0016
#    ---> Improved! Saved new best model checkpoint to 'best_spatiotemporal_physnet.pt' (Val Loss: 4.0177)
# Epoch 24/150 | LR: 0.000299 | Train Loss: 3.9961 | Val Loss: 4.0140 | Val PCC: -0.0010
#    ---> Improved! Saved new best model checkpoint to 'best_spatiotemporal_physnet.pt' (Val Loss: 4.0140)
# Epoch 25/150 | LR: 0.000299 | Train Loss: 3.9953 | Val Loss: 4.0213 | Val PCC: -0.0001
#    ---> No improvement in validation loss for 1/15 epochs.
# Epoch 26/150 | LR: 0.000298 | Train Loss: 3.9928 | Val Loss: 4.0205 | Val PCC: -0.0007
#    ---> No improvement in validation loss for 2/15 epochs.
# Epoch 27/150 | LR: 0.000298 | Train Loss: 3.9880 | Val Loss: 4.0136 | Val PCC: +0.0020
#    ---> Improved! Saved new best model checkpoint to 'best_spatiotemporal_physnet.pt' (Val Loss: 4.0136)
# Epoch 28/150 | LR: 0.000297 | Train Loss: 3.9850 | Val Loss: 4.0154 | Val PCC: +0.0013
#    ---> No improvement in validation loss for 1/15 epochs.
# Epoch 29/150 | LR: 0.000296 | Train Loss: 3.9808 | Val Loss: 4.0187 | Val PCC: +0.0009
#    ---> No improvement in validation loss for 2/15 epochs.
# Epoch 30/150 | LR: 0.000296 | Train Loss: 3.9769 | Val Loss: 4.0155 | Val PCC: +0.0021
#    ---> No improvement in validation loss for 3/15 epochs.
# Epoch 31/150 | LR: 0.000295 | Train Loss: 3.9714 | Val Loss: 4.0065 | Val PCC: +0.0040
#    ---> Improved! Saved new best model checkpoint to 'best_spatiotemporal_physnet.pt' (Val Loss: 4.0065)
# Epoch 32/150 | LR: 0.000294 | Train Loss: 3.9675 | Val Loss: 3.9975 | Val PCC: +0.0072
#    ---> Improved! Saved new best model checkpoint to 'best_spatiotemporal_physnet.pt' (Val Loss: 3.9975)
# Epoch 33/150 | LR: 0.000293 | Train Loss: 3.9637 | Val Loss: 4.0030 | Val PCC: +0.0073
#    ---> No improvement in validation loss for 1/15 epochs.
# Epoch 34/150 | LR: 0.000292 | Train Loss: 3.9581 | Val Loss: 4.0089 | Val PCC: +0.0041
#    ---> No improvement in validation loss for 2/15 epochs.
# Epoch 35/150 | LR: 0.000290 | Train Loss: 3.9543 | Val Loss: 3.9947 | Val PCC: +0.0084
#    ---> Improved! Saved new best model checkpoint to 'best_spatiotemporal_physnet.pt' (Val Loss: 3.9947)
# Epoch 36/150 | LR: 0.000289 | Train Loss: 3.9502 | Val Loss: 3.9930 | Val PCC: +0.0085
#    ---> Improved! Saved new best model checkpoint to 'best_spatiotemporal_physnet.pt' (Val Loss: 3.9930)
# Epoch 37/150 | LR: 0.000288 | Train Loss: 3.9468 | Val Loss: 3.9942 | Val PCC: +0.0075
#    ---> No improvement in validation loss for 1/15 epochs.
# Epoch 38/150 | LR: 0.000286 | Train Loss: 3.9431 | Val Loss: 3.9950 | Val PCC: +0.0075
#    ---> No improvement in validation loss for 2/15 epochs.
# Epoch 39/150 | LR: 0.000285 | Train Loss: 3.9382 | Val Loss: 3.9868 | Val PCC: +0.0088
#    ---> Improved! Saved new best model checkpoint to 'best_spatiotemporal_physnet.pt' (Val Loss: 3.9868)
# Epoch 40/150 | LR: 0.000283 | Train Loss: 3.9342 | Val Loss: 3.9853 | Val PCC: +0.0091
#    ---> Improved! Saved new best model checkpoint to 'best_spatiotemporal_physnet.pt' (Val Loss: 3.9853)
# Epoch 41/150 | LR: 0.000281 | Train Loss: 3.9304 | Val Loss: 3.9897 | Val PCC: +0.0094
#    ---> No improvement in validation loss for 1/15 epochs.
# Epoch 42/150 | LR: 0.000279 | Train Loss: 3.9278 | Val Loss: 3.9841 | Val PCC: +0.0099
#    ---> Improved! Saved new best model checkpoint to 'best_spatiotemporal_physnet.pt' (Val Loss: 3.9841)
# Epoch 43/150 | LR: 0.000277 | Train Loss: 3.9251 | Val Loss: 3.9931 | Val PCC: +0.0090
#    ---> No improvement in validation loss for 1/15 epochs.
# Epoch 44/150 | LR: 0.000276 | Train Loss: 3.9222 | Val Loss: 3.9831 | Val PCC: +0.0122
#    ---> Improved! Saved new best model checkpoint to 'best_spatiotemporal_physnet.pt' (Val Loss: 3.9831)
# Epoch 45/150 | LR: 0.000274 | Train Loss: 3.9184 | Val Loss: 3.9768 | Val PCC: +0.0115
#    ---> Improved! Saved new best model checkpoint to 'best_spatiotemporal_physnet.pt' (Val Loss: 3.9768)
# Epoch 46/150 | LR: 0.000271 | Train Loss: 3.9142 | Val Loss: 3.9831 | Val PCC: +0.0111
#    ---> No improvement in validation loss for 1/15 epochs.
# Epoch 47/150 | LR: 0.000269 | Train Loss: 3.9116 | Val Loss: 3.9731 | Val PCC: +0.0125
#    ---> Improved! Saved new best model checkpoint to 'best_spatiotemporal_physnet.pt' (Val Loss: 3.9731)
# Epoch 48/150 | LR: 0.000267 | Train Loss: 3.9082 | Val Loss: 3.9682 | Val PCC: +0.0142
#    ---> Improved! Saved new best model checkpoint to 'best_spatiotemporal_physnet.pt' (Val Loss: 3.9682)
# Epoch 49/150 | LR: 0.000265 | Train Loss: 3.9045 | Val Loss: 3.9735 | Val PCC: +0.0117
#    ---> No improvement in validation loss for 1/15 epochs.
# Epoch 50/150 | LR: 0.000262 | Train Loss: 3.9009 | Val Loss: 3.9712 | Val PCC: +0.0114
#    ---> No improvement in validation loss for 2/15 epochs.
# Epoch 51/150 | LR: 0.000260 | Train Loss: 3.8993 | Val Loss: 3.9714 | Val PCC: +0.0127
#    ---> No improvement in validation loss for 3/15 epochs.
# Epoch 52/150 | LR: 0.000257 | Train Loss: 3.8961 | Val Loss: 3.9720 | Val PCC: +0.0122
#    ---> No improvement in validation loss for 4/15 epochs.
# Epoch 53/150 | LR: 0.000255 | Train Loss: 3.8919 | Val Loss: 3.9671 | Val PCC: +0.0127
#    ---> Improved! Saved new best model checkpoint to 'best_spatiotemporal_physnet.pt' (Val Loss: 3.9671)
# Epoch 54/150 | LR: 0.000252 | Train Loss: 3.8903 | Val Loss: 3.9700 | Val PCC: +0.0129
#    ---> No improvement in validation loss for 1/15 epochs.
# Epoch 55/150 | LR: 0.000250 | Train Loss: 3.8875 | Val Loss: 3.9636 | Val PCC: +0.0128
#    ---> Improved! Saved new best model checkpoint to 'best_spatiotemporal_physnet.pt' (Val Loss: 3.9636)
# Epoch 56/150 | LR: 0.000247 | Train Loss: 3.8839 | Val Loss: 3.9644 | Val PCC: +0.0130
#    ---> No improvement in validation loss for 1/15 epochs.
# Epoch 57/150 | LR: 0.000244 | Train Loss: 3.8806 | Val Loss: 3.9685 | Val PCC: +0.0119
#    ---> No improvement in validation loss for 2/15 epochs.
# Epoch 58/150 | LR: 0.000241 | Train Loss: 3.8803 | Val Loss: 3.9615 | Val PCC: +0.0139
#    ---> Improved! Saved new best model checkpoint to 'best_spatiotemporal_physnet.pt' (Val Loss: 3.9615)
# Epoch 59/150 | LR: 0.000238 | Train Loss: 3.8781 | Val Loss: 3.9772 | Val PCC: +0.0100
#    ---> No improvement in validation loss for 1/15 epochs.
# Epoch 60/150 | LR: 0.000235 | Train Loss: 3.8747 | Val Loss: 3.9657 | Val PCC: +0.0114
#    ---> No improvement in validation loss for 2/15 epochs.
# Epoch 61/150 | LR: 0.000232 | Train Loss: 3.8712 | Val Loss: 3.9659 | Val PCC: +0.0115
#    ---> No improvement in validation loss for 3/15 epochs.
# Epoch 62/150 | LR: 0.000229 | Train Loss: 3.8705 | Val Loss: 3.9603 | Val PCC: +0.0126
#    ---> Improved! Saved new best model checkpoint to 'best_spatiotemporal_physnet.pt' (Val Loss: 3.9603)
# Epoch 63/150 | LR: 0.000226 | Train Loss: 3.8670 | Val Loss: 3.9620 | Val PCC: +0.0129
#    ---> No improvement in validation loss for 1/15 epochs.
# Epoch 64/150 | LR: 0.000223 | Train Loss: 3.8659 | Val Loss: 3.9605 | Val PCC: +0.0136
#    ---> No improvement in validation loss for 2/15 epochs.
# Epoch 65/150 | LR: 0.000220 | Train Loss: 3.8634 | Val Loss: 3.9554 | Val PCC: +0.0138
#    ---> Improved! Saved new best model checkpoint to 'best_spatiotemporal_physnet.pt' (Val Loss: 3.9554)
# Epoch 66/150 | LR: 0.000217 | Train Loss: 3.8624 | Val Loss: 3.9586 | Val PCC: +0.0122
#    ---> No improvement in validation loss for 1/15 epochs.
# Epoch 67/150 | LR: 0.000213 | Train Loss: 3.8596 | Val Loss: 3.9595 | Val PCC: +0.0121
#    ---> No improvement in validation loss for 2/15 epochs.
# Epoch 68/150 | LR: 0.000210 | Train Loss: 3.8567 | Val Loss: 3.9564 | Val PCC: +0.0140
#    ---> No improvement in validation loss for 3/15 epochs.
# Epoch 69/150 | LR: 0.000207 | Train Loss: 3.8550 | Val Loss: 3.9544 | Val PCC: +0.0123
#    ---> Improved! Saved new best model checkpoint to 'best_spatiotemporal_physnet.pt' (Val Loss: 3.9544)
# Epoch 70/150 | LR: 0.000204 | Train Loss: 3.8530 | Val Loss: 3.9568 | Val PCC: +0.0120
#    ---> No improvement in validation loss for 1/15 epochs.
# Epoch 71/150 | LR: 0.000200 | Train Loss: 3.8497 | Val Loss: 3.9575 | Val PCC: +0.0120
#    ---> No improvement in validation loss for 2/15 epochs.
# Epoch 72/150 | LR: 0.000197 | Train Loss: 3.8489 | Val Loss: 3.9535 | Val PCC: +0.0136
#    ---> Improved! Saved new best model checkpoint to 'best_spatiotemporal_physnet.pt' (Val Loss: 3.9535)
# Epoch 73/150 | LR: 0.000193 | Train Loss: 3.8473 | Val Loss: 3.9498 | Val PCC: +0.0132
#    ---> Improved! Saved new best model checkpoint to 'best_spatiotemporal_physnet.pt' (Val Loss: 3.9498)
# Epoch 74/150 | LR: 0.000190 | Train Loss: 3.8447 | Val Loss: 3.9557 | Val PCC: +0.0128
#    ---> No improvement in validation loss for 1/15 epochs.
# Epoch 75/150 | LR: 0.000186 | Train Loss: 3.8440 | Val Loss: 3.9577 | Val PCC: +0.0111
#    ---> No improvement in validation loss for 2/15 epochs.
# Epoch 76/150 | LR: 0.000183 | Train Loss: 3.8424 | Val Loss: 3.9523 | Val PCC: +0.0126
#    ---> No improvement in validation loss for 3/15 epochs.
# Epoch 77/150 | LR: 0.000179 | Train Loss: 3.8397 | Val Loss: 3.9500 | Val PCC: +0.0120
#    ---> No improvement in validation loss for 4/15 epochs.
# Epoch 78/150 | LR: 0.000176 | Train Loss: 3.8388 | Val Loss: 3.9542 | Val PCC: +0.0112
#    ---> No improvement in validation loss for 5/15 epochs.
# Epoch 79/150 | LR: 0.000172 | Train Loss: 3.8363 | Val Loss: 3.9499 | Val PCC: +0.0126
#    ---> No improvement in validation loss for 6/15 epochs.
# Epoch 80/150 | LR: 0.000169 | Train Loss: 3.8351 | Val Loss: 3.9513 | Val PCC: +0.0109
#    ---> No improvement in validation loss for 7/15 epochs.
# Epoch 81/150 | LR: 0.000165 | Train Loss: 3.8327 | Val Loss: 3.9482 | Val PCC: +0.0123
#    ---> Improved! Saved new best model checkpoint to 'best_spatiotemporal_physnet.pt' (Val Loss: 3.9482)
# Epoch 82/150 | LR: 0.000161 | Train Loss: 3.8303 | Val Loss: 3.9484 | Val PCC: +0.0122
#    ---> No improvement in validation loss for 1/15 epochs.
# Epoch 83/150 | LR: 0.000158 | Train Loss: 3.8291 | Val Loss: 3.9460 | Val PCC: +0.0131
#    ---> Improved! Saved new best model checkpoint to 'best_spatiotemporal_physnet.pt' (Val Loss: 3.9460)
# Epoch 84/150 | LR: 0.000154 | Train Loss: 3.8269 | Val Loss: 3.9482 | Val PCC: +0.0119
#    ---> No improvement in validation loss for 1/15 epochs.
# Epoch 85/150 | LR: 0.000151 | Train Loss: 3.8264 | Val Loss: 3.9495 | Val PCC: +0.0119
#    ---> No improvement in validation loss for 2/15 epochs.
# Epoch 86/150 | LR: 0.000147 | Train Loss: 3.8233 | Val Loss: 3.9509 | Val PCC: +0.0118
#    ---> No improvement in validation loss for 3/15 epochs.
# Epoch 87/150 | LR: 0.000143 | Train Loss: 3.8238 | Val Loss: 3.9449 | Val PCC: +0.0124
#    ---> Improved! Saved new best model checkpoint to 'best_spatiotemporal_physnet.pt' (Val Loss: 3.9449)
# Epoch 88/150 | LR: 0.000140 | Train Loss: 3.8212 | Val Loss: 3.9464 | Val PCC: +0.0124
#    ---> No improvement in validation loss for 1/15 epochs.
# Epoch 89/150 | LR: 0.000136 | Train Loss: 3.8186 | Val Loss: 3.9452 | Val PCC: +0.0114
#    ---> No improvement in validation loss for 2/15 epochs.
# Epoch 90/150 | LR: 0.000132 | Train Loss: 3.8184 | Val Loss: 3.9486 | Val PCC: +0.0117
#    ---> No improvement in validation loss for 3/15 epochs.
# Epoch 91/150 | LR: 0.000129 | Train Loss: 3.8162 | Val Loss: 3.9421 | Val PCC: +0.0125
#    ---> Improved! Saved new best model checkpoint to 'best_spatiotemporal_physnet.pt' (Val Loss: 3.9421)
# Epoch 92/150 | LR: 0.000125 | Train Loss: 3.8150 | Val Loss: 3.9474 | Val PCC: +0.0104
#    ---> No improvement in validation loss for 1/15 epochs.
# Epoch 93/150 | LR: 0.000122 | Train Loss: 3.8141 | Val Loss: 3.9387 | Val PCC: +0.0129
#    ---> Improved! Saved new best model checkpoint to 'best_spatiotemporal_physnet.pt' (Val Loss: 3.9387)
# Epoch 94/150 | LR: 0.000118 | Train Loss: 3.8110 | Val Loss: 3.9413 | Val PCC: +0.0122
#    ---> No improvement in validation loss for 1/15 epochs.
# Epoch 95/150 | LR: 0.000115 | Train Loss: 3.8098 | Val Loss: 3.9425 | Val PCC: +0.0120
#    ---> No improvement in validation loss for 2/15 epochs.
# Epoch 96/150 | LR: 0.000111 | Train Loss: 3.8085 | Val Loss: 3.9444 | Val PCC: +0.0109
#    ---> No improvement in validation loss for 3/15 epochs.
# Epoch 97/150 | LR: 0.000108 | Train Loss: 3.8074 | Val Loss: 3.9490 | Val PCC: +0.0103
#    ---> No improvement in validation loss for 4/15 epochs.
# Epoch 98/150 | LR: 0.000104 | Train Loss: 3.8064 | Val Loss: 3.9416 | Val PCC: +0.0109
#    ---> No improvement in validation loss for 5/15 epochs.
# Epoch 99/150 | LR: 0.000101 | Train Loss: 3.8046 | Val Loss: 3.9398 | Val PCC: +0.0115
#    ---> No improvement in validation loss for 6/15 epochs.
# Epoch 100/150 | LR: 0.000097 | Train Loss: 3.8037 | Val Loss: 3.9378 | Val PCC: +0.0120
#    ---> Improved! Saved new best model checkpoint to 'best_spatiotemporal_physnet.pt' (Val Loss: 3.9378)
# Epoch 101/150 | LR: 0.000094 | Train Loss: 3.8020 | Val Loss: 3.9394 | Val PCC: +0.0113
#    ---> No improvement in validation loss for 1/15 epochs.
# Epoch 102/150 | LR: 0.000091 | Train Loss: 3.8004 | Val Loss: 3.9387 | Val PCC: +0.0114
#    ---> No improvement in validation loss for 2/15 epochs.
# Epoch 103/150 | LR: 0.000088 | Train Loss: 3.7999 | Val Loss: 3.9382 | Val PCC: +0.0124
#    ---> No improvement in validation loss for 3/15 epochs.
# Epoch 104/150 | LR: 0.000084 | Train Loss: 3.7974 | Val Loss: 3.9404 | Val PCC: +0.0116
#    ---> No improvement in validation loss for 4/15 epochs.
# Epoch 105/150 | LR: 0.000081 | Train Loss: 3.7970 | Val Loss: 3.9374 | Val PCC: +0.0115
#    ---> Improved! Saved new best model checkpoint to 'best_spatiotemporal_physnet.pt' (Val Loss: 3.9374)
# Epoch 106/150 | LR: 0.000078 | Train Loss: 3.7963 | Val Loss: 3.9376 | Val PCC: +0.0113
#    ---> No improvement in validation loss for 1/15 epochs.
# Epoch 107/150 | LR: 0.000075 | Train Loss: 3.7952 | Val Loss: 3.9374 | Val PCC: +0.0118
#    ---> No improvement in validation loss for 2/15 epochs.
# Epoch 108/150 | LR: 0.000072 | Train Loss: 3.7934 | Val Loss: 3.9382 | Val PCC: +0.0113
#    ---> No improvement in validation loss for 3/15 epochs.
# Epoch 109/150 | LR: 0.000069 | Train Loss: 3.7920 | Val Loss: 3.9375 | Val PCC: +0.0108
#    ---> No improvement in validation loss for 4/15 epochs.
# Epoch 110/150 | LR: 0.000066 | Train Loss: 3.7906 | Val Loss: 3.9373 | Val PCC: +0.0110
#    ---> Improved! Saved new best model checkpoint to 'best_spatiotemporal_physnet.pt' (Val Loss: 3.9373)
# Epoch 111/150 | LR: 0.000063 | Train Loss: 3.7904 | Val Loss: 3.9366 | Val PCC: +0.0110
#    ---> Improved! Saved new best model checkpoint to 'best_spatiotemporal_physnet.pt' (Val Loss: 3.9366)
# Epoch 112/150 | LR: 0.000060 | Train Loss: 3.7888 | Val Loss: 3.9343 | Val PCC: +0.0121
#    ---> Improved! Saved new best model checkpoint to 'best_spatiotemporal_physnet.pt' (Val Loss: 3.9343)
# Epoch 113/150 | LR: 0.000057 | Train Loss: 3.7885 | Val Loss: 3.9379 | Val PCC: +0.0106
#    ---> No improvement in validation loss for 1/15 epochs.
# Epoch 114/150 | LR: 0.000054 | Train Loss: 3.7869 | Val Loss: 3.9333 | Val PCC: +0.0114
#    ---> Improved! Saved new best model checkpoint to 'best_spatiotemporal_physnet.pt' (Val Loss: 3.9333)
# Epoch 115/150 | LR: 0.000051 | Train Loss: 3.7858 | Val Loss: 3.9353 | Val PCC: +0.0111
#    ---> No improvement in validation loss for 1/15 epochs.
# Epoch 116/150 | LR: 0.000049 | Train Loss: 3.7849 | Val Loss: 3.9355 | Val PCC: +0.0113
#    ---> No improvement in validation loss for 2/15 epochs.
# Epoch 117/150 | LR: 0.000046 | Train Loss: 3.7839 | Val Loss: 3.9352 | Val PCC: +0.0112
#    ---> No improvement in validation loss for 3/15 epochs.
# Epoch 118/150 | LR: 0.000044 | Train Loss: 3.7831 | Val Loss: 3.9351 | Val PCC: +0.0109
#    ---> No improvement in validation loss for 4/15 epochs.
# Epoch 119/150 | LR: 0.000041 | Train Loss: 3.7828 | Val Loss: 3.9328 | Val PCC: +0.0115
#    ---> Improved! Saved new best model checkpoint to 'best_spatiotemporal_physnet.pt' (Val Loss: 3.9328)
# Epoch 120/150 | LR: 0.000039 | Train Loss: 3.7810 | Val Loss: 3.9342 | Val PCC: +0.0106
#    ---> No improvement in validation loss for 1/15 epochs.
# Epoch 121/150 | LR: 0.000036 | Train Loss: 3.7805 | Val Loss: 3.9330 | Val PCC: +0.0110
#    ---> No improvement in validation loss for 2/15 epochs.
# Epoch 122/150 | LR: 0.000034 | Train Loss: 3.7794 | Val Loss: 3.9326 | Val PCC: +0.0111
#    ---> Improved! Saved new best model checkpoint to 'best_spatiotemporal_physnet.pt' (Val Loss: 3.9326)
# Epoch 123/150 | LR: 0.000032 | Train Loss: 3.7783 | Val Loss: 3.9328 | Val PCC: +0.0108
#    ---> No improvement in validation loss for 1/15 epochs.
# Epoch 124/150 | LR: 0.000030 | Train Loss: 3.7792 | Val Loss: 3.9337 | Val PCC: +0.0108
#    ---> No improvement in validation loss for 2/15 epochs.
# Epoch 125/150 | LR: 0.000027 | Train Loss: 3.7780 | Val Loss: 3.9307 | Val PCC: +0.0115
#    ---> Improved! Saved new best model checkpoint to 'best_spatiotemporal_physnet.pt' (Val Loss: 3.9307)
# Epoch 126/150 | LR: 0.000025 | Train Loss: 3.7770 | Val Loss: 3.9325 | Val PCC: +0.0112
#    ---> No improvement in validation loss for 1/15 epochs.
# Epoch 127/150 | LR: 0.000024 | Train Loss: 3.7762 | Val Loss: 3.9324 | Val PCC: +0.0109
#    ---> No improvement in validation loss for 2/15 epochs.
# Epoch 128/150 | LR: 0.000022 | Train Loss: 3.7757 | Val Loss: 3.9321 | Val PCC: +0.0110
#    ---> No improvement in validation loss for 3/15 epochs.
# Epoch 129/150 | LR: 0.000020 | Train Loss: 3.7745 | Val Loss: 3.9316 | Val PCC: +0.0111
#    ---> No improvement in validation loss for 4/15 epochs.
# Epoch 130/150 | LR: 0.000018 | Train Loss: 3.7743 | Val Loss: 3.9317 | Val PCC: +0.0110
#    ---> No improvement in validation loss for 5/15 epochs.
# Epoch 131/150 | LR: 0.000016 | Train Loss: 3.7733 | Val Loss: 3.9329 | Val PCC: +0.0107
#    ---> No improvement in validation loss for 6/15 epochs.
# Epoch 132/150 | LR: 0.000015 | Train Loss: 3.7726 | Val Loss: 3.9331 | Val PCC: +0.0103
#    ---> No improvement in validation loss for 7/15 epochs.
# Epoch 133/150 | LR: 0.000013 | Train Loss: 3.7720 | Val Loss: 3.9323 | Val PCC: +0.0107
#    ---> No improvement in validation loss for 8/15 epochs.
# Epoch 134/150 | LR: 0.000012 | Train Loss: 3.7724 | Val Loss: 3.9300 | Val PCC: +0.0113
#    ---> Improved! Saved new best model checkpoint to 'best_spatiotemporal_physnet.pt' (Val Loss: 3.9300)
# Epoch 135/150 | LR: 0.000011 | Train Loss: 3.7714 | Val Loss: 3.9311 | Val PCC: +0.0109
#    ---> No improvement in validation loss for 1/15 epochs.
# Epoch 136/150 | LR: 0.000009 | Train Loss: 3.7706 | Val Loss: 3.9295 | Val PCC: +0.0112
#    ---> Improved! Saved new best model checkpoint to 'best_spatiotemporal_physnet.pt' (Val Loss: 3.9295)
# Epoch 137/150 | LR: 0.000008 | Train Loss: 3.7701 | Val Loss: 3.9315 | Val PCC: +0.0107
#    ---> No improvement in validation loss for 1/15 epochs.
# Epoch 138/150 | LR: 0.000007 | Train Loss: 3.7691 | Val Loss: 3.9295 | Val PCC: +0.0112
#    ---> Improved! Saved new best model checkpoint to 'best_spatiotemporal_physnet.pt' (Val Loss: 3.9295)
# Epoch 139/150 | LR: 0.000006 | Train Loss: 3.7689 | Val Loss: 3.9307 | Val PCC: +0.0111
#    ---> No improvement in validation loss for 1/15 epochs.
# Epoch 140/150 | LR: 0.000005 | Train Loss: 3.7692 | Val Loss: 3.9301 | Val PCC: +0.0111
#    ---> No improvement in validation loss for 2/15 epochs.
# Epoch 141/150 | LR: 0.000005 | Train Loss: 3.7687 | Val Loss: 3.9309 | Val PCC: +0.0109
#    ---> No improvement in validation loss for 3/15 epochs.
# Epoch 142/150 | LR: 0.000004 | Train Loss: 3.7681 | Val Loss: 3.9307 | Val PCC: +0.0112
#    ---> No improvement in validation loss for 4/15 epochs.
# Epoch 143/150 | LR: 0.000003 | Train Loss: 3.7682 | Val Loss: 3.9308 | Val PCC: +0.0110
#    ---> No improvement in validation loss for 5/15 epochs.
# Epoch 144/150 | LR: 0.000003 | Train Loss: 3.7687 | Val Loss: 3.9298 | Val PCC: +0.0112
#    ---> No improvement in validation loss for 6/15 epochs.
# Epoch 145/150 | LR: 0.000002 | Train Loss: 3.7678 | Val Loss: 3.9310 | Val PCC: +0.0110
#    ---> No improvement in validation loss for 7/15 epochs.
# Epoch 146/150 | LR: 0.000002 | Train Loss: 3.7683 | Val Loss: 3.9300 | Val PCC: +0.0110
#    ---> No improvement in validation loss for 8/15 epochs.
# Epoch 147/150 | LR: 0.000001 | Train Loss: 3.7678 | Val Loss: 3.9301 | Val PCC: +0.0110
#    ---> No improvement in validation loss for 9/15 epochs.
# Epoch 148/150 | LR: 0.000001 | Train Loss: 3.7674 | Val Loss: 3.9304 | Val PCC: +0.0108
#    ---> No improvement in validation loss for 10/15 epochs.
# Epoch 149/150 | LR: 0.000001 | Train Loss: 3.7665 | Val Loss: 3.9293 | Val PCC: +0.0114
#    ---> Improved! Saved new best model checkpoint to 'best_spatiotemporal_physnet.pt' (Val Loss: 3.9293)
# Epoch 150/150 | LR: 0.000001 | Train Loss: 3.7669 | Val Loss: 3.9302 | Val PCC: +0.0110
#    ---> No improvement in validation loss for 1/15 epochs.
#
# Loading best model state dict from memory (Best Val Loss: 3.9293)...
#
# ==================================================
#              EVALUATION SET METRICS RESULTS
# ==================================================
#   Pearson Correlation Coefficient (PCC) : 0.0077
#   Mean Absolute Error (MAE)            : 6.73 BPM
#   Root Mean Squared Error (RMSE)       : 12.04 BPM
#   Signal-to-Noise Ratio (SNR)          : -1.59 dB
# ==================================================
#
# Model checkpoint successfully saved to: spatiotemporal_physnet_best_shuffle.pth
#
# ======================================================================
#                 DATASET SPLIT & SAMPLE SUMMARY TABLE
# ======================================================================
# Split Set       | NPZ Files  | 450-Frame Windows    | Batches    | Ratio
# ----------------------------------------------------------------------
# Train           | 18425      | 17333                | 1084       | 70.1%
# Validation      | 3948       | 3686                 | 231        | 14.9%
# Evaluation      | 3949       | 3721                 | 233        | 15.0%
# ----------------------------------------------------------------------
# TOTAL           | 26322      | 24740                | 1548       | 100.0%
# ======================================================================

# %%
def run_inference_on_sample(npz_file_path, trained_model, sequence_length=450, fs=30.0):
    """Execute inference on a single NPZ validation sample sequence."""
    print(f"--- INFERENCE RUN ON: {os.path.basename(npz_file_path)} ---")
    data = load_npz_file(npz_file_path)
    if data is None:
        return None
    
    ppg_key = 'ppg_values' if 'ppg_values' in data else 'ppg'
    if len(data[ppg_key]) < sequence_length:
        print("Error: Input file length is shorter than the sequence length.")
        return None
        
    target_ppg = data[ppg_key][:sequence_length]
    target_ppg = butter_bandpass_filter(target_ppg, fs=fs)
    target_norm = (target_ppg - np.mean(target_ppg)) / (np.std(target_ppg) + 1e-8)
    
    roi_inputs = []
    for roi_name in ROI_ORDER:
        actual_key = next((k for k in data.files if roi_name == k), None)
        if actual_key is not None:
            roi_data = data[actual_key][:sequence_length]
        else:
            roi_data = np.zeros((sequence_length, 24, 24, 3), dtype=np.uint8)
        roi_inputs.append(roi_data.astype(np.float32) / 255.0)
        
    stacked_rois = np.stack(roi_inputs, axis=0)
    stacked_rois = np.transpose(stacked_rois, (0, 4, 1, 2, 3))
    stacked_rois = np.reshape(stacked_rois, (30, sequence_length, 24, 24))
    
    input_tensor = torch.tensor(stacked_rois, dtype=torch.float32).unsqueeze(0).to(DEVICE)
    
    trained_model.eval()
    with torch.no_grad():
        output_signal = trained_model(input_tensor).cpu().numpy()[0]
        
    filtered_pred = butter_bandpass_filter(output_signal, fs=fs)
    filtered_pred = (filtered_pred - np.mean(filtered_pred)) / (np.std(filtered_pred) + 1e-8)
    
    hr_pred = calculate_bpm_from_fft(filtered_pred, fs=fs)
    hr_true = calculate_bpm_from_fft(target_norm, fs=fs)
    
    print(f"  Predicted HR : {hr_pred:.2f} BPM")
    print(f"  Ground-Truth : {hr_true:.2f} BPM")
    print(f"  Absolute Error: {abs(hr_pred - hr_true):.2f} BPM")
    print("----------------------------------------------------\n")
    return filtered_pred, target_norm

sample_val_file = val_split[1]
inference_pred, inference_gt = run_inference_on_sample(sample_val_file, model)

fig, axs = plt.subplots(2, 2, figsize=(14, 10))

axs[0, 0].plot(train_losses, label='Train Loss', color='#1f77b4', linewidth=2.5, marker='o')
axs[0, 0].plot(val_losses, label='Val Loss', color='#ff7f0e', linewidth=2.5, marker='s')
axs[0, 0].set_title('Spatio-Temporal Model Loss Convergence')
axs[0, 0].set_xlabel('Training Epochs')
axs[0, 0].set_ylabel('Dual-Objective Loss Value')
axs[0, 0].legend()

if inference_pred is not None:
    axs[0, 1].plot(inference_gt, label='GT PPG (BVP)', color='#7f7f7f', alpha=0.75, linewidth=2)
    axs[0, 1].plot(inference_pred, label='10-ROI Predicted rPPG', color='#2ca02c', linewidth=2.5)
    axs[0, 1].set_title('Signal Waveform Comparison (Inference Showcase)')
    axs[0, 1].set_xlabel('Frames Timeline')
    axs[0, 1].set_ylabel('Normalized Amplitude')
    axs[0, 1].legend()

if inference_pred is not None:
    pred_det = inference_pred - np.mean(inference_pred)
    true_det = inference_gt - np.mean(inference_gt)
    
    freqs_p, psd_p = welch(pred_det, fs=30.0, nperseg=len(pred_det))
    freqs_t, psd_t = welch(true_det, fs=30.0, nperseg=len(true_det))
    
    axs[1, 0].plot(freqs_t * 60.0, psd_t, label='GT Spectrum', color='#7f7f7f', alpha=0.75, linewidth=2)
    axs[1, 0].plot(freqs_p * 60.0, psd_p, label='Pred Spectrum', color='#d62728', linewidth=2.5)
    axs[1, 0].set_xlim(45, 150)
    axs[1, 0].set_title('Power Spectral Density (PSD) Comparison')
    axs[1, 0].set_xlabel('Heart Rate (BPM)')
    axs[1, 0].set_ylabel('Spectral Magnitude')
    axs[1, 0].legend()

axs[1, 1].axis('off')
metric_summary_card = (
    "10-ROI Spatio-Temporal Evaluation Summary\n\n"
    f"• Pearson Correlation Coefficient (PCC): {metrics['PCC']:.4f}\n"
    f"• MAE: {metrics['MAE']:.2f} BPM\n"
    f"• RMSE: {metrics['RMSE']:.2f} BPM\n"
    f"• Signal-to-Noise Ratio (SNR): {metrics['SNR']:.2f} dB\n\n"
    f"Configuration Info:\n"
    f"• Spatio-Temporal Model input channels: 30 (10 ROIs × 3 RGB)\n"
    f"• Sequence segment window: 128 frames\n"
    f"• Aligned to 'ppg_values' and raw NPZ skin zones\n"
    f"• Optimization: Vectorised augmentations (Spatial & Brightness)"
)
axs[1, 1].text(0.05, 0.2, metric_summary_card, fontsize=11, 
              bbox=dict(boxstyle='round,pad=1.2', facecolor='#f8f9fa', edgecolor='#dee2e6'))

plt.tight_layout()
plt.show()
# Out:
# --- INFERENCE RUN ON: 3326_USBVideo_after_chunk6.npz ---
#   Predicted HR : 72.00 BPM
#   Ground-Truth : 76.00 BPM
#   Absolute Error: 4.00 BPM
# ----------------------------------------------------

# %%
import os
import torch
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import welch

def run_inference_on_sample(npz_file_path, model, sequence_length=450, fs=30.0):
    """Execute inference on a single NPZ validation sample sequence."""
    print(f"--- INFERENCE RUN ON: {os.path.basename(npz_file_path)} ---")
    data = load_npz_file(npz_file_path)
    if data is None:
        return None, None
    
    ppg_key = 'ppg_values' if 'ppg_values' in data else 'ppg'
    if len(data[ppg_key]) < sequence_length:
        print("Error: Input file length is shorter than the sequence length.")
        return None, None
        
    target_ppg = data[ppg_key][:sequence_length]
    target_ppg = butter_bandpass_filter(target_ppg, fs=fs)
    target_norm = (target_ppg - np.mean(target_ppg)) / (np.std(target_ppg) + 1e-8)
    
    roi_inputs = []
    for roi_name in ROI_ORDER:
        actual_key = next((k for k in data.files if roi_name == k), None)
        if actual_key is not None:
            roi_data = data[actual_key][:sequence_length]
        else:
            roi_data = np.zeros((sequence_length, 24, 24, 3), dtype=np.uint8)
        roi_inputs.append(roi_data.astype(np.float32) / 255.0)
        
    stacked_rois = np.stack(roi_inputs, axis=0)
    stacked_rois = np.transpose(stacked_rois, (0, 4, 1, 2, 3))
    stacked_rois = np.reshape(stacked_rois, (30, sequence_length, 24, 24))
    
    input_tensor = torch.tensor(stacked_rois, dtype=torch.float32).unsqueeze(0).to(DEVICE)
    
    model.eval()
    with torch.no_grad():
        output_signal = model(input_tensor).cpu().numpy()[0]
        
    filtered_pred = butter_bandpass_filter(output_signal, fs=fs)
    filtered_pred = (filtered_pred - np.mean(filtered_pred)) / (np.std(filtered_pred) + 1e-8)
    
    hr_pred = calculate_bpm_from_fft(filtered_pred, fs=fs)
    hr_true = calculate_bpm_from_fft(target_norm, fs=fs)
    
    print(f"  Predicted HR  : {hr_pred:.2f} BPM")
    print(f"  Ground-Truth  : {hr_true:.2f} BPM")
    print(f"  Absolute Error: {abs(hr_pred - hr_true):.2f} BPM")
    print("----------------------------------------------------\n")
    return filtered_pred, target_norm

# Execute inference on a validation sample
sample_val_file = val_split[0] if len(val_split) > 0 else npz_files[0]
inference_pred, inference_gt = run_inference_on_sample(sample_val_file, model)

# Create Plotting Dashboard
fig, axs = plt.subplots(2, 2, figsize=(14, 10))

# Subplot 1: Convergence History
epochs_range = range(1, len(train_losses) + 1)
axs[0, 0].plot(epochs_range, train_losses, label='Train Loss', color='#1f77b4', linewidth=2.5, marker='o', markersize=4)
axs[0, 0].plot(epochs_range, val_losses, label='Val Loss', color='#ff7f0e', linewidth=2.5, marker='s', markersize=4)
axs[0, 0].set_title('Spatio-Temporal Model Loss Convergence')
axs[0, 0].set_xlabel('Training Epochs')
axs[0, 0].set_ylabel('Tri-Objective Loss (Pearson + MSE + PSD)')
axs[0, 0].legend()

# Subplot 2: Waveform Signal Comparison
if inference_pred is not None:
    axs[0, 1].plot(inference_gt, label='GT PPG (BVP)', color='#7f7f7f', alpha=0.75, linewidth=2)
    axs[0, 1].plot(inference_pred, label='10-ROI Predicted rPPG', color='#2ca02c', linewidth=2.5)
    axs[0, 1].set_title('Signal Waveform Comparison (Inference Showcase)')
    axs[0, 1].set_xlabel('Frames Timeline')
    axs[0, 1].set_ylabel('Normalized Amplitude')
    axs[0, 1].legend()

# Subplot 3: Power Spectral Density (PSD)
if inference_pred is not None:
    pred_det = inference_pred - np.mean(inference_pred)
    true_det = inference_gt - np.mean(inference_gt)
    
    freqs_p, psd_p = welch(pred_det, fs=30.0, nperseg=len(pred_det))
    freqs_t, psd_t = welch(true_det, fs=30.0, nperseg=len(true_det))
    
    axs[1, 0].plot(freqs_t * 60.0, psd_t, label='GT Spectrum', color='#7f7f7f', alpha=0.75, linewidth=2)
    axs[1, 0].plot(freqs_p * 60.0, psd_p, label='Pred Spectrum', color='#d62728', linewidth=2.5)
    axs[1, 0].set_xlim(40, 180)
    axs[1, 0].set_title('Power Spectral Density (PSD) Comparison')
    axs[1, 0].set_xlabel('Heart Rate (BPM)')
    axs[1, 0].set_ylabel('Spectral Magnitude')
    axs[1, 0].legend()

# Subplot 4: Summary Card Metrics
axs[1, 1].axis('off')
metric_summary_card = (
    "10-ROI Spatio-Temporal Evaluation Summary\n\n"
    f"• Pearson Correlation Coefficient (PCC): {metrics['PCC']:.4f}\n"
    f"• MAE: {metrics['MAE']:.2f} BPM\n"
    f"• RMSE: {metrics['RMSE']:.2f} BPM\n"
    f"• Signal-to-Noise Ratio (SNR): {metrics['SNR']:.2f} dB\n\n"
    f"Configuration Info:\n"
    f"• Spatio-Temporal Model channels: 30 (10 ROIs × 3 RGB)\n"
    f"• Sequence segment window: 450 frames (15.0s @ 30 FPS)\n"
    f"• Standard temporal normalization & zero-mean target scaling\n"
    f"• Loss: Pearson + 0.3×MSE + 1.0×PSD KL-Divergence"
)
axs[1, 1].text(0.05, 0.15, metric_summary_card, fontsize=11, 
              bbox=dict(boxstyle='round,pad=1.2', facecolor='#f8f9fa', edgecolor='#dee2e6'))

plt.tight_layout()
plt.show()
# Out:
# --- INFERENCE RUN ON: 4902_USBVideo_before_chunk9.npz ---
#   Predicted HR  : 80.00 BPM
#   Ground-Truth  : 80.00 BPM
#   Absolute Error: 0.00 BPM
# ----------------------------------------------------

# %%
import os
import torch
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import welch

# def run_inference_on_sample(npz_file_path, model, sequence_length=450, fs=30.0):
#     """
#     Execute inference on a single NPZ validation sequence with strict edge-transient 
#     suppression and explicit Z-score standardization on both GT and Prediction.
#     """
#     print(f"--- INFERENCE RUN ON: {os.path.basename(npz_file_path)} ---")
#     data = load_npz_file(npz_file_path)
#     if data is None:
#         return None, None
    
#     ppg_key = 'ppg_values' if 'ppg_values' in data else 'ppg'
#     if len(data[ppg_key]) < sequence_length:
#         print("Error: Input file length is shorter than the required sequence length.")
#         return None, None
        
#     # 1. Ground Truth Pipeline: Detrend -> Bandpass Filter -> Z-Score Normalization
#     raw_target_ppg = data[ppg_key][:sequence_length].copy()
#     raw_target_detrend = raw_target_ppg - np.mean(raw_target_ppg)  # Prevent filter edge distortion
#     filtered_gt = butter_bandpass_filter(raw_target_detrend, fs=fs)
#     gt_norm = (filtered_gt - np.mean(filtered_gt)) / (np.std(filtered_gt) + 1e-8)
    
#     # 2. Extract & Format Multi-ROI Inputs
#     roi_inputs = []
#     for roi_name in ROI_ORDER:
#         actual_key = next((k for k in data.files if roi_name == k), None)
#         if actual_key is not None:
#             roi_data = data[actual_key][:sequence_length]
#         else:
#             roi_data = np.zeros((sequence_length, 24, 24, 3), dtype=np.uint8)
#         roi_inputs.append(roi_data.astype(np.float32) / 255.0)
        
#     stacked_rois = np.stack(roi_inputs, axis=0)
#     stacked_rois = np.transpose(stacked_rois, (0, 4, 1, 2, 3))
#     stacked_rois = np.reshape(stacked_rois, (30, sequence_length, 24, 24))
    
#     input_tensor = torch.tensor(stacked_rois, dtype=torch.float32).unsqueeze(0).to(DEVICE)
    
#     # 3. Network Inference Pass
#     model.eval()
#     with torch.no_grad():
#         output_signal = model(input_tensor).cpu().numpy()[0]
        
#     # 4. Prediction Pipeline: Detrend -> Bandpass Filter -> Z-Score Normalization
#     output_signal_detrend = output_signal - np.mean(output_signal)  # Prevent filter edge spikes
#     filtered_pred = butter_bandpass_filter(output_signal_detrend, fs=fs)
#     pred_norm = (filtered_pred - np.mean(filtered_pred)) / (np.std(filtered_pred) + 1e-8)
    
#     # 5. Heart Rate Metrics Calculation
#     hr_pred = calculate_bpm_from_fft(pred_norm, fs=fs)
#     hr_true = calculate_bpm_from_fft(gt_norm, fs=fs)
    
#     print(f"  Predicted HR  : {hr_pred:.2f} BPM")
#     print(f"  Ground-Truth  : {hr_true:.2f} BPM")
#     print(f"  Absolute Error: {abs(hr_pred - hr_true):.2f} BPM")
#     print("----------------------------------------------------\n")
#     return pred_norm, gt_norm

def run_inference_on_sample(npz_file_path, model, sequence_length=450, fs=30.0, pad_margin=30):
    """
    Execute inference on an NPZ sample, applying reflection padding prior to 
    bandpass filtering to completely suppress convolution boundary ringing at frame 0.
    """
    print(f"--- INFERENCE RUN ON: {os.path.basename(npz_file_path)} ---")
    data = load_npz_file(npz_file_path)
    if data is None:
        return None, None
    
    ppg_key = 'ppg_values' if 'ppg_values' in data else 'ppg'
    if len(data[ppg_key]) < sequence_length:
        print("Error: Input file length is shorter than required sequence length.")
        return None, None
        
    # 1. Ground Truth Pipeline (Padded filtering to prevent edge artifacts)
    raw_target_ppg = data[ppg_key][:sequence_length].copy()
    gt_padded = np.pad(raw_target_ppg, pad_margin, mode='reflect')
    gt_filtered = butter_bandpass_filter(gt_padded - np.mean(gt_padded), fs=fs)
    gt_cropped = gt_filtered[pad_margin:-pad_margin]
    gt_norm = (gt_cropped - np.mean(gt_cropped)) / (np.std(gt_cropped) + 1e-8)
    
    # 2. Multi-ROI Input Tensor Preparation
    roi_inputs = []
    for roi_name in ROI_ORDER:
        actual_key = next((k for k in data.files if roi_name == k), None)
        if actual_key is not None:
            roi_data = data[actual_key][:sequence_length]
        else:
            roi_data = np.zeros((sequence_length, 24, 24, 3), dtype=np.uint8)
        roi_inputs.append(roi_data.astype(np.float32) / 255.0)
        
    stacked_rois = np.stack(roi_inputs, axis=0)
    stacked_rois = np.transpose(stacked_rois, (0, 4, 1, 2, 3))
    stacked_rois = np.reshape(stacked_rois, (30, sequence_length, 24, 24))
    
    input_tensor = torch.tensor(stacked_rois, dtype=torch.float32).unsqueeze(0).to(DEVICE)
    
    # 3. Network Forward Pass
    model.eval()
    with torch.no_grad():
        output_signal = model(input_tensor).cpu().numpy()[0]
        
    # 4. Prediction Pipeline: Pad -> Filter -> Crop -> Z-Score Normalize
    pred_padded = np.pad(output_signal, pad_margin, mode='reflect')
    pred_filtered = butter_bandpass_filter(pred_padded - np.mean(pred_padded), fs=fs)
    pred_cropped = pred_filtered[pad_margin:-pad_margin]
    pred_norm = (pred_cropped - np.mean(pred_cropped)) / (np.std(pred_cropped) + 1e-8)
    
    # 5. Heart Rate Metrics Calculation
    hr_pred = calculate_bpm_from_fft(pred_norm, fs=fs)
    hr_true = calculate_bpm_from_fft(gt_norm, fs=fs)
    
    print(f"  Predicted HR  : {hr_pred:.2f} BPM")
    print(f"  Ground-Truth  : {hr_true:.2f} BPM")
    print(f"  Absolute Error: {abs(hr_pred - hr_true):.2f} BPM")
    print("----------------------------------------------------\n")
    return pred_norm, gt_norm
# ============================================================================
# EXECUTION & DASHBOARD PLOTTING CELL
# ============================================================================

# Select sample file from validation split
sample_val_file = val_split[0] if len(val_split) > 0 else npz_files[0]
inference_pred, inference_gt = run_inference_on_sample(sample_val_file, model)

# Create 2x2 Visualization Dashboard
fig, axs = plt.subplots(2, 2, figsize=(14, 10))

# --- Subplot 1: Convergence Curves ---
epochs_range = range(1, len(train_losses) + 1)
axs[0, 0].plot(epochs_range, train_losses, label='Train Loss', color='#1f77b4', linewidth=2.5, marker='o', markersize=3)
axs[0, 0].plot(epochs_range, val_losses, label='Val Loss', color='#ff7f0e', linewidth=2.5, marker='s', markersize=3)
axs[0, 0].set_title('Spatio-Temporal Model Loss Convergence')
axs[0, 0].set_xlabel('Training Epochs')
axs[0, 0].set_ylabel('Tri-Objective Loss (Pearson + MSE + PSD)')
axs[0, 0].legend()

# --- Subplot 2: Standardized Waveform Alignment ---
if inference_pred is not None and inference_gt is not None:
    axs[0, 1].plot(inference_gt, label='GT PPG (Normalized μ=0, σ=1)', color='#7f7f7f', alpha=0.85, linewidth=2)
    axs[0, 1].plot(inference_pred, label='10-ROI Predicted rPPG', color='#2ca02c', linewidth=2.2)
    axs[0, 1].set_title('Signal Waveform Comparison (Normalized Scale)')
    axs[0, 1].set_xlabel('Frames Timeline')
    axs[0, 1].set_ylabel('Normalized Amplitude (Z-Score)')
    axs[0, 1].set_ylim(-3.5, 3.5)  # Constrain y-axis to valid standardized bounds
    axs[0, 1].legend()

# --- Subplot 3: Spectral Density Alignment ---
if inference_pred is not None and inference_gt is not None:
    freqs_p, psd_p = welch(inference_pred, fs=30.0, nperseg=len(inference_pred))
    freqs_t, psd_t = welch(inference_gt, fs=30.0, nperseg=len(inference_gt))
    
    axs[1, 0].plot(freqs_t * 60.0, psd_t, label='GT Spectrum', color='#7f7f7f', alpha=0.85, linewidth=2)
    axs[1, 0].plot(freqs_p * 60.0, psd_p, label='Pred Spectrum', color='#d62728', linewidth=2.2)
    axs[1, 0].set_xlim(40, 180)
    axs[1, 0].set_title('Power Spectral Density (PSD) Comparison')
    axs[1, 0].set_xlabel('Heart Rate (BPM)')
    axs[1, 0].set_ylabel('Spectral Magnitude')
    axs[1, 0].legend()

# --- Subplot 4: Summary Card ---
axs[1, 1].axis('off')
metric_summary_card = (
    "10-ROI Spatio-Temporal Evaluation Summary\n\n"
    f"• Pearson Correlation Coefficient (PCC): {metrics['PCC']:.4f}\n"
    f"• MAE: {metrics['MAE']:.2f} BPM\n"
    f"• RMSE: {metrics['RMSE']:.2f} BPM\n"
    f"• Signal-to-Noise Ratio (SNR): {metrics['SNR']:.2f} dB\n\n"
    f"Configuration Info:\n"
    f"• Spatio-Temporal Model channels: 30 (10 ROIs × 3 RGB)\n"
    f"• Sequence segment window: 450 frames (15.0s @ 30 FPS)\n"
    f"• Standardized GT and Pred normalization (μ=0, σ=1)\n"
    f"• Loss: Pearson + 0.3×MSE + 1.0×PSD KL-Divergence"
)
axs[1, 1].text(0.05, 0.15, metric_summary_card, fontsize=11, 
              bbox=dict(boxstyle='round,pad=1.2', facecolor='#f8f9fa', edgecolor='#dee2e6'))

plt.tight_layout()
plt.show()
# Out:
# --- INFERENCE RUN ON: 4902_USBVideo_before_chunk9.npz ---
#   Predicted HR  : 80.00 BPM
#   Ground-Truth  : 80.00 BPM
#   Absolute Error: 0.00 BPM
# ----------------------------------------------------

# %% [markdown]
# Negative pearson correlation

# %%
Evaluation dataset

# %%
import os
import torch
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import welch

# def run_inference_on_sample(npz_file_path, model, sequence_length=450, fs=30.0):
#     """
#     Execute inference on a single NPZ validation sequence with strict edge-transient 
#     suppression and explicit Z-score standardization on both GT and Prediction.
#     """
#     print(f"--- INFERENCE RUN ON: {os.path.basename(npz_file_path)} ---")
#     data = load_npz_file(npz_file_path)
#     if data is None:
#         return None, None
    
#     ppg_key = 'ppg_values' if 'ppg_values' in data else 'ppg'
#     if len(data[ppg_key]) < sequence_length:
#         print("Error: Input file length is shorter than the required sequence length.")
#         return None, None
        
#     # 1. Ground Truth Pipeline: Detrend -> Bandpass Filter -> Z-Score Normalization
#     raw_target_ppg = data[ppg_key][:sequence_length].copy()
#     raw_target_detrend = raw_target_ppg - np.mean(raw_target_ppg)  # Prevent filter edge distortion
#     filtered_gt = butter_bandpass_filter(raw_target_detrend, fs=fs)
#     gt_norm = (filtered_gt - np.mean(filtered_gt)) / (np.std(filtered_gt) + 1e-8)
    
#     # 2. Extract & Format Multi-ROI Inputs
#     roi_inputs = []
#     for roi_name in ROI_ORDER:
#         actual_key = next((k for k in data.files if roi_name == k), None)
#         if actual_key is not None:
#             roi_data = data[actual_key][:sequence_length]
#         else:
#             roi_data = np.zeros((sequence_length, 24, 24, 3), dtype=np.uint8)
#         roi_inputs.append(roi_data.astype(np.float32) / 255.0)
        
#     stacked_rois = np.stack(roi_inputs, axis=0)
#     stacked_rois = np.transpose(stacked_rois, (0, 4, 1, 2, 3))
#     stacked_rois = np.reshape(stacked_rois, (30, sequence_length, 24, 24))
    
#     input_tensor = torch.tensor(stacked_rois, dtype=torch.float32).unsqueeze(0).to(DEVICE)
    
#     # 3. Network Inference Pass
#     model.eval()
#     with torch.no_grad():
#         output_signal = model(input_tensor).cpu().numpy()[0]
        
#     # 4. Prediction Pipeline: Detrend -> Bandpass Filter -> Z-Score Normalization
#     output_signal_detrend = output_signal - np.mean(output_signal)  # Prevent filter edge spikes
#     filtered_pred = butter_bandpass_filter(output_signal_detrend, fs=fs)
#     pred_norm = (filtered_pred - np.mean(filtered_pred)) / (np.std(filtered_pred) + 1e-8)
    
#     # 5. Heart Rate Metrics Calculation
#     hr_pred = calculate_bpm_from_fft(pred_norm, fs=fs)
#     hr_true = calculate_bpm_from_fft(gt_norm, fs=fs)
    
#     print(f"  Predicted HR  : {hr_pred:.2f} BPM")
#     print(f"  Ground-Truth  : {hr_true:.2f} BPM")
#     print(f"  Absolute Error: {abs(hr_pred - hr_true):.2f} BPM")
#     print("----------------------------------------------------\n")
#     return pred_norm, gt_norm

def run_inference_on_sample(npz_file_path, model, sequence_length=450, fs=30.0, pad_margin=30):
    """
    Execute inference on an NPZ sample, applying reflection padding prior to 
    bandpass filtering to completely suppress convolution boundary ringing at frame 0.
    """
    print(f"--- INFERENCE RUN ON: {os.path.basename(npz_file_path)} ---")
    data = load_npz_file(npz_file_path)
    if data is None:
        return None, None
    
    ppg_key = 'ppg_values' if 'ppg_values' in data else 'ppg'
    if len(data[ppg_key]) < sequence_length:
        print("Error: Input file length is shorter than required sequence length.")
        return None, None
        
    # 1. Ground Truth Pipeline (Padded filtering to prevent edge artifacts)
    raw_target_ppg = data[ppg_key][:sequence_length].copy()
    gt_padded = np.pad(raw_target_ppg, pad_margin, mode='reflect')
    gt_filtered = butter_bandpass_filter(gt_padded - np.mean(gt_padded), fs=fs)
    gt_cropped = gt_filtered[pad_margin:-pad_margin]
    gt_norm = (gt_cropped - np.mean(gt_cropped)) / (np.std(gt_cropped) + 1e-8)
    
    # 2. Multi-ROI Input Tensor Preparation
    roi_inputs = []
    for roi_name in ROI_ORDER:
        actual_key = next((k for k in data.files if roi_name == k), None)
        if actual_key is not None:
            roi_data = data[actual_key][:sequence_length]
        else:
            roi_data = np.zeros((sequence_length, 24, 24, 3), dtype=np.uint8)
        roi_inputs.append(roi_data.astype(np.float32) / 255.0)
        
    stacked_rois = np.stack(roi_inputs, axis=0)
    stacked_rois = np.transpose(stacked_rois, (0, 4, 1, 2, 3))
    stacked_rois = np.reshape(stacked_rois, (30, sequence_length, 24, 24))
    
    input_tensor = torch.tensor(stacked_rois, dtype=torch.float32).unsqueeze(0).to(DEVICE)
    
    # 3. Network Forward Pass
    model.eval()
    with torch.no_grad():
        output_signal = model(input_tensor).cpu().numpy()[0]
        
    # 4. Prediction Pipeline: Pad -> Filter -> Crop -> Z-Score Normalize
    pred_padded = np.pad(output_signal, pad_margin, mode='reflect')
    pred_filtered = butter_bandpass_filter(pred_padded - np.mean(pred_padded), fs=fs)
    pred_cropped = pred_filtered[pad_margin:-pad_margin]
    pred_norm = (pred_cropped - np.mean(pred_cropped)) / (np.std(pred_cropped) + 1e-8)
    
    # 5. Heart Rate Metrics Calculation
    hr_pred = calculate_bpm_from_fft(pred_norm, fs=fs)
    hr_true = calculate_bpm_from_fft(gt_norm, fs=fs)
    
    print(f"  Predicted HR  : {hr_pred:.2f} BPM")
    print(f"  Ground-Truth  : {hr_true:.2f} BPM")
    print(f"  Absolute Error: {abs(hr_pred - hr_true):.2f} BPM")
    print("----------------------------------------------------\n")
    return pred_norm, gt_norm
# ============================================================================
# EXECUTION & DASHBOARD PLOTTING CELL
# ============================================================================

# Select sample file from validation split
sample_val_file = val_split[0] if len(val_split) > 0 else npz_files[0]
inference_pred, inference_gt = run_inference_on_sample(sample_val_file, model)

# Create 2x2 Visualization Dashboard
fig, axs = plt.subplots(2, 2, figsize=(14, 10))

# --- Subplot 1: Convergence Curves ---
epochs_range = range(1, len(train_losses) + 1)
axs[0, 0].plot(epochs_range, train_losses, label='Train Loss', color='#1f77b4', linewidth=2.5, marker='o', markersize=3)
axs[0, 0].plot(epochs_range, val_losses, label='Val Loss', color='#ff7f0e', linewidth=2.5, marker='s', markersize=3)
axs[0, 0].set_title('Spatio-Temporal Model Loss Convergence')
axs[0, 0].set_xlabel('Training Epochs')
axs[0, 0].set_ylabel('Tri-Objective Loss (Pearson + MSE + PSD)')
axs[0, 0].legend()

# --- Subplot 2: Standardized Waveform Alignment ---
if inference_pred is not None and inference_gt is not None:
    axs[0, 1].plot(inference_gt, label='GT PPG (Normalized μ=0, σ=1)', color='#7f7f7f', alpha=0.85, linewidth=2)
    axs[0, 1].plot(inference_pred, label='10-ROI Predicted rPPG', color='#2ca02c', linewidth=2.2)
    axs[0, 1].set_title('Signal Waveform Comparison (Normalized Scale)')
    axs[0, 1].set_xlabel('Frames Timeline')
    axs[0, 1].set_ylabel('Normalized Amplitude (Z-Score)')
    axs[0, 1].set_ylim(-3.5, 3.5)  # Constrain y-axis to valid standardized bounds
    axs[0, 1].legend()

# --- Subplot 3: Spectral Density Alignment ---
if inference_pred is not None and inference_gt is not None:
    freqs_p, psd_p = welch(inference_pred, fs=30.0, nperseg=len(inference_pred))
    freqs_t, psd_t = welch(inference_gt, fs=30.0, nperseg=len(inference_gt))
    
    axs[1, 0].plot(freqs_t * 60.0, psd_t, label='GT Spectrum', color='#7f7f7f', alpha=0.85, linewidth=2)
    axs[1, 0].plot(freqs_p * 60.0, psd_p, label='Pred Spectrum', color='#d62728', linewidth=2.2)
    axs[1, 0].set_xlim(40, 180)
    axs[1, 0].set_title('Power Spectral Density (PSD) Comparison')
    axs[1, 0].set_xlabel('Heart Rate (BPM)')
    axs[1, 0].set_ylabel('Spectral Magnitude')
    axs[1, 0].legend()

# --- Subplot 4: Summary Card ---
axs[1, 1].axis('off')
metric_summary_card = (
    "10-ROI Spatio-Temporal Evaluation Summary\n\n"
    f"• Pearson Correlation Coefficient (PCC): {metrics['PCC']:.4f}\n"
    f"• MAE: {metrics['MAE']:.2f} BPM\n"
    f"• RMSE: {metrics['RMSE']:.2f} BPM\n"
    f"• Signal-to-Noise Ratio (SNR): {metrics['SNR']:.2f} dB\n\n"
    f"Configuration Info:\n"
    f"• Spatio-Temporal Model channels: 30 (10 ROIs × 3 RGB)\n"
    f"• Sequence segment window: 450 frames (15.0s @ 30 FPS)\n"
    f"• Standardized GT and Pred normalization (μ=0, σ=1)\n"
    f"• Loss: Pearson + 0.3×MSE + 1.0×PSD KL-Divergence"
)
axs[1, 1].text(0.05, 0.15, metric_summary_card, fontsize=11, 
              bbox=dict(boxstyle='round,pad=1.2', facecolor='#f8f9fa', edgecolor='#dee2e6'))

plt.tight_layout()
plt.show()
# Out:
# --- INFERENCE RUN ON: 4902_USBVideo_before_chunk9.npz ---
#   Predicted HR  : 80.00 BPM
#   Ground-Truth  : 80.00 BPM
#   Absolute Error: 0.00 BPM
# ----------------------------------------------------

# %% [markdown]
# Temporar EWnconder changed

# %%
import os
import json
import math
import copy
import random
from pathlib import Path
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.signal import butter, filtfilt, welch
from torch.optim.lr_scheduler import LinearLR, CosineAnnealingLR, SequentialLR

# Configure high-quality visualization styles
plt.style.use('seaborn-v0_8-whitegrid' if 'seaborn-v0_8-whitegrid' in plt.style.available else 'default')
sns.set_palette("muted")

# Setup default configurations
PREPROCESSED_DATA_PATH = Path('/home/cristic/preprocessed_data/')
CACHE_FILES = ["valid_files.txt", "train_files_cache.txt", "val_files_cache.txt"]
gpu_id = 1 
DEVICE = torch.device(f'cuda:{gpu_id}' if torch.cuda.is_available() else 'cpu')
MODEL_SAVE_PATH = Path("spatiotemporal_physnet_best_shuffle_v2.pth")

# Clean existing cache files before starting run
for cache in CACHE_FILES:
    if os.path.exists(cache):
        try:
            os.remove(cache)
            print(f"Removed old cache: {cache}")
        except Exception as e:
            print(f"Error removing cache {cache}: {e}")

# Strict order representing the 9 sub-ROIs + full face boundary configurations
ROI_ORDER = [
    'roi_forehead',
    'roi_left_cheek_280',
    'roi_right_cheek_50',
    'roi_nose',
    'roi_chin',
    'roi_chin_199',
    'roi_left_eye',
    'roi_right_eye',
    'roi_mouth',
    'roi_full_face'
]

def inspect_npz_color_space(npz_path, roi_key='roi_forehead'):
    """
    Diagnose NPZ color-space representations and plot channel intensities.
    Ensures RGB channels align with spatial tracking configurations.
    """
    print(f"\nEvaluating color space for path: {npz_path}")
    if not os.path.exists(npz_path):
        print(f"Color Space Inspector Notice: Sample {npz_path} does not exist yet.")
        return

    with np.load(npz_path) as data:
        if roi_key not in data:
            available = [k for k in data.keys() if k.startswith('roi_')]
            if not available:
                print("No ROIs found in file keys.")
                return
            print(f"Key '{roi_key}' not found. Available ROIs: {available}")
            roi_key = available[0]
            
        roi_data = data[roi_key]
        
    print(f"Loaded '{roi_key}' with shape: {roi_data.shape} and dtype: {roi_data.dtype}")
    
    first_frame = roi_data[0].copy()
    
    if first_frame.max() > 1.0:
        first_frame_norm = first_frame.astype(np.float32) / 255.0
    else:
        first_frame_norm = first_frame.astype(np.float32)
        
    c0 = first_frame_norm[:, :, 0]
    c1 = first_frame_norm[:, :, 1]
    c2 = first_frame_norm[:, :, 2]
    
    mean_c0, mean_c1, mean_c2 = c0.mean(), c1.mean(), c2.mean()
    
    print("\n--- Channel Intensity Statistics ---")
    print(f"Channel 0 Mean: {mean_c0:.4f}")
    print(f"Channel 1 Mean: {mean_c1:.4f}")
    print(f"Channel 2 Mean: {mean_c2:.4f}")
    print("------------------------------------\n")
    
    fig, axes = plt.subplots(1, 4, figsize=(16, 4))
    
    axes[0].imshow(first_frame_norm)
    axes[0].set_title("Direct Render (Assumes RGB)")
    axes[0].axis('off')
    
    im0 = axes[1].imshow(c0, cmap='gray', vmin=0, vmax=1)
    axes[1].set_title(f"Channel 0\n(Mean: {mean_c0:.3f})")
    axes[1].axis('off')
    plt.colorbar(im0, ax=axes[1], fraction=0.046, pad=0.04)
    
    im1 = axes[2].imshow(c1, cmap='gray', vmin=0, vmax=1)
    axes[2].set_title(f"Channel 1\n(Mean: {mean_c1:.3f})")
    axes[2].axis('off')
    plt.colorbar(im1, ax=axes[2], fraction=0.046, pad=0.04)
    
    im2 = axes[3].imshow(c2, cmap='gray', vmin=0, vmax=1)
    axes[3].set_title(f"Channel 2\n(Mean: {mean_c2:.3f})")
    axes[3].axis('off')
    plt.colorbar(im2, ax=axes[3], fraction=0.046, pad=0.04)
    
    plt.tight_layout()
    plt.show()

def butter_bandpass_filter(data, lowcut=0.75, highcut=2.5, fs=30.0, order=4):
    """Apply zero-phase Butterworth bandpass filter to capture human heart rate (45-150 BPM)."""
    nyq = 0.5 * fs
    low = lowcut / nyq
    high = highcut / nyq
    b, a = butter(order, [low, high], btype='band')
    return filtfilt(b, a, data)

def calculate_bpm_from_fft(signal_1d, fs=30.0, lowcut=0.75, highcut=2.5):
    """Extract heart rate (BPM) from the dominant peak of the Power Spectral Density."""
    signal_cleaned = signal_1d - np.mean(signal_1d)
    freqs, psd = welch(signal_cleaned, fs=fs, nperseg=len(signal_cleaned))
    
    valid_idx = np.where((freqs >= lowcut) & (freqs <= highcut))[0]
    if len(valid_idx) == 0:
        return 75.0
    
    peak_freq = freqs[valid_idx[np.argmax(psd[valid_idx])]]
    return peak_freq * 60.0

def load_npz_file(file_path):
    """Securely load and parse an NPZ file."""
    try:
        data = np.load(file_path, allow_pickle=True)
        return data
    except Exception as e:
        print(f"Error loading {file_path}: {e}")
        return None

def analyze_npz_structure(data):
    """Analyze and print the metadata keys and array dimensions of loaded files."""
    if data is None:
        print("NPZ Analysis Error: Provided data object is None.")
        return
    print("\n" + "=" * 75)
    print("               NPZ FILE STRUCTURE SHOWCASE (9-ROI + Face Configuration)")
    print("=" * 75)
    for key in sorted(data.files):
        item = data[key]
        if hasattr(item, 'shape'):
            print(f"  {key:<27} : Shape {str(item.shape):<20} | Dtype {item.dtype}")
        else:
            print(f"  {key:<27} : Metadata / Scalar Object")
    print("=" * 75 + "\n")

def create_synthetic_dataset(target_dir, num_files=12, num_frames=450):
    """Generate mock datasets matching strict multi-ROI formatting standards."""
    target_dir.mkdir(parents=True, exist_ok=True)
    print(f"\nTarget dataset directory '{target_dir}' is empty or missing.")
    print("Generating synthetic 9-ROI + face NPZ dataset mimicking real schemas...")
    
    fs = 30.0
    t = np.arange(num_frames) / fs
    
    for i in range(num_files):
        hr_hz = np.random.uniform(1.0, 1.5)
        bvp = np.sin(2 * np.pi * hr_hz * t) + 0.35 * np.sin(2 * np.pi * (hr_hz * 2) * t)
        bvp += 0.2 * np.sin(2 * np.pi * 0.2 * t)
        bvp = (bvp - np.mean(bvp)) / (np.std(bvp) + 1e-8)
        
        data_dict = {
            'time_deltas': (t * 1000.0).astype(np.float64),
            'ppg_values': bvp.astype(np.float64)
        }
        
        for roi in ROI_ORDER:
            base_skin = np.array([185.0, 125.0, 105.0]) if "eye" not in roi else np.array([210.0, 190.0, 180.0])
            pixel_noise = np.random.normal(0, 1.2, size=(num_frames, 24, 24, 3))
            
            pulse_modulator = np.zeros((num_frames, 24, 24, 3))
            pulse_modulator[..., 0] = bvp[:, None, None] * 0.15
            pulse_modulator[..., 1] = bvp[:, None, None] * 0.55
            pulse_modulator[..., 2] = bvp[:, None, None] * 0.05
            
            roi_frames = (base_skin + pulse_modulator + pixel_noise).clip(0, 255).astype(np.uint8)
            data_dict[roi] = roi_frames
            
        np.savez(target_dir / f"subject_{i+1:02d}_session_01.npz", **data_dict)
    print("Synthetic dataset successfully created!\n")

class PPGMultiROIDataset(Dataset):
    """Optimized Dataset class with inline spatial and temporal sequence augmentations."""
    def __init__(self, file_paths, sequence_length=450, fs=30.0, augment=False):
        self.file_paths = file_paths
        self.sequence_length = sequence_length
        self.fs = fs
        self.augment = augment
        self.samples = []
        
        self._prepare_samples()

    def _prepare_samples(self):
        """Pre-segment matching timelines into sequence lengths."""
        for path in self.file_paths:
            data = load_npz_file(path)
            if data is None:
                continue
            
            ppg_key = 'ppg_values' if 'ppg_values' in data else 'ppg'
            length = len(data[ppg_key])
            num_windows = length // self.sequence_length
            
            for w in range(num_windows):
                start_idx = w * self.sequence_length
                end_idx = start_idx + self.sequence_length
                self.samples.append((path, start_idx, end_idx))

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        file_path, start, end = self.samples[idx]
        data = load_npz_file(file_path)
        
        ppg_key = 'ppg_values' if 'ppg_values' in data else 'ppg'
        ppg_segment = data[ppg_key][start:end]
        ppg_segment = butter_bandpass_filter(ppg_segment, fs=self.fs)
        
        ppg_normalized = (ppg_segment - np.mean(ppg_segment)) / (np.std(ppg_segment) + 1e-8)
        
        roi_inputs = []
        for roi_name in ROI_ORDER:
            actual_key = next((k for k in data.files if roi_name == k), None)
            
            if actual_key is not None:
                roi_data = data[actual_key][start:end]
            else:
                roi_data = np.zeros((self.sequence_length, 24, 24, 3), dtype=np.uint8)
                
            roi_data = roi_data.astype(np.float32) / 255.0
            roi_inputs.append(roi_data)
            
        if self.augment:
            if np.random.rand() > 0.5:
                roi_inputs = [np.flip(roi, axis=2) for roi in roi_inputs]
                
            if np.random.rand() > 0.5:
                roi_inputs = [np.flip(roi, axis=1) for roi in roi_inputs]
                
            if np.random.rand() > 0.5:
                brightness_factor = np.random.uniform(0.9, 1.1)
                roi_inputs = [np.clip(roi * brightness_factor, 0.0, 1.0) for roi in roi_inputs]
                
        stacked_rois = np.stack(roi_inputs, axis=0)
        stacked_rois = np.transpose(stacked_rois, (0, 4, 1, 2, 3))
        stacked_rois = np.reshape(stacked_rois, (10 * 3, self.sequence_length, 24, 24))
        
        return torch.tensor(stacked_rois, dtype=torch.float32), torch.tensor(ppg_normalized, dtype=torch.float32)

class SpatioTemporalPhysNet(nn.Module):
    """
    Spatio-Temporal convolutional network engineered to extract micro-color variations
    harmoniously across 10 face zones (30 raw input channels).
    """
    # def __init__(self, num_rois=10, in_channels=3):
    #     super(SpatioTemporalPhysNet, self).__init__()
    #     self.num_rois = num_rois
    #     self.total_channels = num_rois * in_channels
        
    #     self.spatial_conv = nn.Sequential(
    #         nn.Conv3d(self.total_channels, 64, kernel_size=(1, 3, 3), padding=(0, 1, 1)),
    #         nn.BatchNorm3d(64),
    #         nn.ELU(),
    #         nn.AdaptiveAvgPool3d((None, 1, 1))
    #     )
        
    #     self.temporal_encoder = nn.Sequential(
    #         nn.Conv1d(64, 32, kernel_size=15, padding=7), 
    #         nn.BatchNorm1d(32),
    #         nn.ELU(),
    #         nn.Conv1d(32, 16, kernel_size=15, padding=7),
    #         nn.BatchNorm1d(16),
    #         nn.ELU(),
    #         nn.Conv1d(16, 1, kernel_size=1)
    #     )
    def __init__(self, num_rois=10, in_channels=3):
        super(SpatioTemporalPhysNet, self).__init__()
        self.num_rois = num_rois
        self.total_channels = num_rois * in_channels
        
        # A lightweight 2-block spatial extractor (Fast but effective)
        self.spatial_conv = nn.Sequential(
            nn.Conv3d(self.total_channels, 32, kernel_size=(1, 5, 5), padding=(0, 2, 2)),
            nn.BatchNorm3d(32),
            nn.ELU(),
            nn.AvgPool3d(kernel_size=(1, 2, 2)), # Safely shrink image first
            
            nn.Conv3d(32, 64, kernel_size=(1, 3, 3), padding=(0, 1, 1)),
            nn.BatchNorm3d(64),
            nn.ELU(),
            nn.AdaptiveAvgPool3d((None, 1, 1))   # Now collapse to 1D safely
        )
        
        # Temporal encoder with the wide Receptive Field (Kernel 15)
        self.temporal_encoder = nn.Sequential(
            nn.Conv1d(64, 32, kernel_size=15, padding=7),
            nn.BatchNorm1d(32),
            nn.ELU(),
            nn.Conv1d(32, 16, kernel_size=15, padding=7),
            nn.BatchNorm1d(16),
            nn.ELU(),
            nn.Conv1d(16, 1, kernel_size=1)
        )

    def forward(self, x):
        mean = x.mean(dim=2, keepdim=True)
        x = (x - mean) / (mean + 1e-8) 
        
        x_spatial = self.spatial_conv(x)
        x_spatial = torch.squeeze(x_spatial, dim=-1)
        x_spatial = torch.squeeze(x_spatial, dim=-1)
        
        ppg_pred = self.temporal_encoder(x_spatial)
        return torch.squeeze(ppg_pred, dim=1)

class NegativePearsonCorrelationLoss(nn.Module):
    """Loss module measuring BVP signal phase synchronization."""
    def __init__(self, eps=1e-8):
        super(NegativePearsonCorrelationLoss, self).__init__()
        self.eps = eps

    def forward(self, pred, target):
        pred = pred.view(pred.size(0), -1)
        target = target.view(target.size(0), -1)

        pred_mean = torch.mean(pred, dim=-1, keepdim=True)
        target_mean = torch.mean(target, dim=-1, keepdim=True)
        
        pred_centered = pred - pred_mean
        target_centered = target - target_mean
        
        r_num = torch.sum(pred_centered * target_centered, dim=-1)
        
        var_pred = torch.sum(pred_centered ** 2, dim=-1)
        var_target = torch.sum(target_centered ** 2, dim=-1)
        
        r_den = torch.sqrt(var_pred + self.eps) * torch.sqrt(var_target + self.eps)
        pearson_coeff = torch.clamp(r_num / r_den, min=-1.0, max=1.0)
        
        return 1.0 - torch.mean(pearson_coeff)    

class PSDLoss(nn.Module):
    """Frequency Loss enforcing peak alignment in Power Spectral Density via KL-Divergence."""
    def __init__(self, fps=30.0, low_bpm=40.0, high_bpm=180.0):
        super(PSDLoss, self).__init__()
        self.fps = fps
        self.low_bpm = low_bpm
        self.high_bpm = high_bpm

    def forward(self, pred, target):
        N = pred.size(-1)
        window = torch.hann_window(N, device=pred.device)
        
        pred_fft = torch.abs(torch.fft.rfft(pred * window, dim=-1))
        target_fft = torch.abs(torch.fft.rfft(target * window, dim=-1))
        
        freqs = torch.fft.rfftfreq(N, d=1.0 / self.fps).to(pred.device)
        mask = (freqs >= self.low_bpm / 60.0) & (freqs <= self.high_bpm / 60.0)
        
        pred_psd = pred_fft[..., mask]
        target_psd = target_fft[..., mask]
        
        T = 2.0
        pred_prob = F.softmax(pred_psd / T, dim=-1)
        target_prob = F.softmax(target_psd / T, dim=-1)
        
        return F.kl_div(torch.log(pred_prob + 1e-8), target_prob, reduction='batchmean')

def calculate_metrics(y_pred, y_true, fs=30.0):
    """Extract performance evaluation metrics (PCC, MAE, RMSE, and SNR)."""
    pcc_list, mae_list, rmse_list, snr_list = [], [], [], []
    
    for i in range(len(y_pred)):
        pred, true = y_pred[i], y_true[i]
        
        pcc = np.corrcoef(pred, true)[0, 1]
        pcc_list.append(0.0 if np.isnan(pcc) else pcc)
        
        bpm_pred = calculate_bpm_from_fft(pred, fs=fs)
        bpm_true = calculate_bpm_from_fft(true, fs=fs)
        
        mae_list.append(abs(bpm_pred - bpm_true))
        rmse_list.append((bpm_pred - bpm_true) ** 2)
        
        pred_detrended = pred - np.mean(pred)
        freqs, psd = welch(pred_detrended, fs=fs, nperseg=len(pred_detrended))
        
        gt_freq = bpm_true / 60.0
        signal_mask = (freqs >= (gt_freq - 0.15)) & (freqs <= (gt_freq + 0.15))
        noise_mask = ~signal_mask & (freqs >= 0.75) & (freqs <= 2.5)
        
        signal_power = np.sum(psd[signal_mask])
        noise_power = np.sum(psd[noise_mask]) + 1e-8
        snr_list.append(10 * np.log10(signal_power / noise_power))
        
    return {
        'PCC': np.mean(pcc_list),
        'MAE': np.mean(mae_list),
        'RMSE': math.sqrt(np.mean(rmse_list)),
        'SNR': np.mean(snr_list)
    }

def save_model_checkpoint(model, optimizer, epoch, metrics, save_path=MODEL_SAVE_PATH):
    """Save model checkpoint along with optimizer state and validation metrics."""
    checkpoint = {
        'epoch': epoch,
        'model_state_dict': model.state_dict(),
        'optimizer_state_dict': optimizer.state_dict(),
        'metrics': metrics
    }
    torch.save(checkpoint, save_path)
    print(f"Model checkpoint successfully saved to: {save_path}")

# Run preprocessing & NPZ diagnostics
if not any(PREPROCESSED_DATA_PATH.glob('*.npz')):
    create_synthetic_dataset(PREPROCESSED_DATA_PATH, num_files=12)

npz_files = sorted(list(PREPROCESSED_DATA_PATH.glob('*.npz')))
print(f"Total files available for analysis: {len(npz_files)}")

first_file_data = load_npz_file(npz_files[0])
analyze_npz_structure(first_file_data)
inspect_npz_color_space(npz_files[0])

# --- Three-Way Dataset Splitting (Train 70%, Validation 15%, Evaluation 15%) ---
random.seed(42)
shuffled_files = npz_files.copy()
random.shuffle(shuffled_files)

n_total = len(shuffled_files)
n_train = max(1, int(n_total * 0.70))
n_val = max(1, int(n_total * 0.15))

train_split = shuffled_files[:n_train]
val_split = shuffled_files[n_train:n_train + n_val]
eval_split = shuffled_files[n_train + n_val:]

train_dataset = PPGMultiROIDataset(train_split, augment=True)
val_dataset = PPGMultiROIDataset(val_split, augment=False)
eval_dataset = PPGMultiROIDataset(eval_split, augment=False)

batch_sz = 16
train_loader = DataLoader(train_dataset, batch_size=batch_sz, shuffle=True, prefetch_factor=4, num_workers=8, pin_memory=True, persistent_workers=True)
val_loader = DataLoader(val_dataset, batch_size=batch_sz, shuffle=False, prefetch_factor=4, num_workers=8, pin_memory=True, persistent_workers=True)
eval_loader = DataLoader(eval_dataset, batch_size=batch_sz, shuffle=False, prefetch_factor=4, num_workers=8, pin_memory=True, persistent_workers=True)

# Setup Model, Criteria, Optimizer & Sequential Scheduler
model = SpatioTemporalPhysNet(num_rois=10).to(DEVICE)
criterion_pearson = NegativePearsonCorrelationLoss()
criterion_mse = nn.MSELoss()
criterion_psd = PSDLoss(fps=30.0)

optimizer = torch.optim.AdamW(model.parameters(), lr=3e-4, weight_decay=1e-4)

num_epochs = 100
warmup_epochs = 20

scheduler1 = LinearLR(optimizer, start_factor=0.1, total_iters=warmup_epochs)
scheduler2 = CosineAnnealingLR(optimizer, T_max=num_epochs - warmup_epochs, eta_min=1e-6)
scheduler = SequentialLR(optimizer, schedulers=[scheduler1, scheduler2], milestones=[warmup_epochs])

CHECKPOINT_SAVE_PATH = "best_spatiotemporal_physnet.pt"
patience = 100
patience_counter = 0
# best_val_loss = float('inf')
best_val_pcc = -float('inf')
best_model_weights = None

train_losses, val_losses, val_pccs = [], [], []

print("Starting phase-locked optimization loop...")

for epoch in range(num_epochs):
    # --- Training Phase ---
    # model.train()
    
    # if epoch < warmup_epochs:
    #     alpha = epoch / warmup_epochs
    #     w_p = 1.0 + (2.0 - 1.0) * alpha   
    #     w_m = 0.2                          
    #     w_s = 0.5 * (1.0 - alpha * 0.5)   
    # else:
    #     progress = (epoch - warmup_epochs) / (num_epochs - warmup_epochs)
    #     w_p = 2.0 + (4.0 - 2.0) * progress  
    #     w_m = 0.1                           
    #     w_s = 0.1                           
        
    # running_loss = 0.0
    model.train()
    
    # STATIC WEIGHTS: Force the network to learn Frequency and Phase simultaneously
    w_p = 3.5   # Pearson (Forces peaks to align)
    w_m = 0.3   # MSE (Forces amplitude to match)
    w_s = 1.0   # PSD (Heavily penalizes the network if the red peak doesn't match the grey peak)
    
    running_loss = 0.0
    for inputs, targets in train_loader:
        inputs, targets = inputs.to(DEVICE), targets.to(DEVICE)
        
        optimizer.zero_grad()
        outputs = model(inputs)
        
        loss_p = criterion_pearson(outputs, targets)
        loss_m = criterion_mse(outputs, targets)
        loss_s = criterion_psd(outputs, targets)
        
        loss = (w_p * loss_p) + (w_m * loss_m) + (w_s * loss_s)
        loss.backward()
        
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        optimizer.step()
        
        running_loss += loss.item() * inputs.size(0)
        
    train_loss = running_loss / len(train_loader.dataset)
    train_losses.append(train_loss)
    
    # --- Validation Phase ---
    model.eval()
    running_val_loss = 0.0
    val_pcc_accum = 0.0
    
    with torch.no_grad():
        for val_inputs, val_targets in val_loader:
            val_inputs, val_targets = val_inputs.to(DEVICE), val_targets.to(DEVICE)
            val_outputs = model(val_inputs)
            
            val_loss_p = criterion_pearson(val_outputs, val_targets)
            val_loss_m = criterion_mse(val_outputs, val_targets)
            val_loss_s = criterion_psd(val_outputs, val_targets)
            
            val_loss = (w_p * val_loss_p) + (w_m * val_loss_m) + (w_s * val_loss_s)
            running_val_loss += val_loss.item() * val_inputs.size(0)
            
            batch_pcc = 1.0 - val_loss_p.item()
            val_pcc_accum += batch_pcc * val_inputs.size(0)
            
    val_loss = running_val_loss / len(val_loader.dataset)
    val_pcc = val_pcc_accum / len(val_loader.dataset)
    
    val_losses.append(val_loss)
    val_pccs.append(val_pcc)
    
    scheduler.step()
    current_lr = scheduler.get_last_lr()[0]
    
    print(f"Epoch {epoch+1:02d}/{num_epochs:02d} | LR: {current_lr:.6f} | "
          f"Weights (P/M/S): [{w_p:.2f}/{w_m:.2f}/{w_s:.2f}] | "
          f"Train Loss: {train_loss:.4f} | Val Loss: {val_loss:.4f} | Val PCC: {val_pcc:+.4f}")

    # if val_loss < best_val_loss:
    #     best_val_loss = val_loss
    #     patience_counter = 0
    #     best_model_weights = {k: v.cpu().clone() for k, v in model.state_dict().items()}
        
    #     torch.save({
    #         'epoch': epoch + 1,
    #         'model_state_dict': model.state_dict(),
    #         'optimizer_state_dict': optimizer.state_dict(),
    #         'val_loss': val_loss,
    #     }, CHECKPOINT_SAVE_PATH)
    #     print(f"   ---> Improved! Saved checkpoint to '{CHECKPOINT_SAVE_PATH}' (Val Loss: {val_loss:.4f})")
    # else:
    #     patience_counter += 1
    #     print(f"   ---> No improvement for {patience_counter}/{patience} epochs.")
    #     if patience_counter >= patience:
    #         print(f"\n[Early Stopping Triggered] Stopped training at Epoch {epoch+1}.")
    #         break
    if val_pcc > best_val_pcc:
        best_val_pcc = val_pcc
        patience_counter = 0
        best_model_weights = {k: v.cpu().clone() for k, v in model.state_dict().items()}
        # Save best model to disk
        torch.save({
            'epoch': epoch + 1,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'val_pcc': val_pcc,
        }, CHECKPOINT_SAVE_PATH)
        print(f"   ---> Improved! Saved new best checkpoint (Val PCC: {val_pcc:+.4f})")
    else:
        patience_counter += 1
        print(f"   ---> No improvement in Val PCC for {patience_counter}/{patience} epochs.")
        if patience_counter >= patience:
            print(f"\n[Early Stopping Triggered] Stopping training early at Epoch {epoch+1}.")
            break

# ----------------------------------------------------------------------------
# Load Best Model Weights for Evaluation
# ----------------------------------------------------------------------------
if best_model_weights is not None:
    print(f"\nLoading best model state dict from memory (Best Val Loss: {best_val_pcc:.4f})...")
    model.load_state_dict(best_model_weights)

# ----------------------------------------------------------------------------
# Held-Out Evaluation Set Assessment
# ----------------------------------------------------------------------------
model.eval()
all_preds, all_trues = [], []

with torch.no_grad():
    for eval_inputs, eval_targets in eval_loader:
        eval_inputs = eval_inputs.to(DEVICE)
        preds = model(eval_inputs).cpu().numpy()
        all_preds.extend(preds)
        all_trues.extend(eval_targets.numpy())

all_preds, all_trues = np.array(all_preds), np.array(all_trues)
metrics = calculate_metrics(all_preds, all_trues)

print("\n" + "=" * 50)
print("               EVALUATION SET METRICS RESULTS")
print("=" * 50)
print(f"  Pearson Correlation Coefficient (PCC) : {metrics['PCC']:.4f}")
print(f"  Mean Absolute Error (MAE)            : {metrics['MAE']:.2f} BPM")
print(f"  Root Mean Squared Error (RMSE)       : {metrics['RMSE']:.2f} BPM")
print(f"  Signal-to-Noise Ratio (SNR)          : {metrics['SNR']:.2f} dB")
print("=" * 50 + "\n")

# Save final checkpoint with metrics
save_model_checkpoint(model, optimizer, epoch + 1, metrics)

# ----------------------------------------------------------------------------
# Final Dataset Sample Statistics Summary Table
# ----------------------------------------------------------------------------
n_total_samples = len(train_dataset) + len(val_dataset) + len(eval_dataset)

print("\n" + "=" * 70)
print("                 DATASET SPLIT & SAMPLE SUMMARY TABLE")
print("=" * 70)
print(f"{'Split Set':<15} | {'NPZ Files':<10} | {'450-Frame Windows':<20} | {'Batches':<10} | {'Ratio':<8}")
print("-" * 70)
print(f"{'Train':<15} | {len(train_split):<10} | {len(train_dataset):<20} | {len(train_loader):<10} | {len(train_dataset)/max(1,n_total_samples)*100:.1f}%")
print(f"{'Validation':<15} | {len(val_split):<10} | {len(val_dataset):<20} | {len(val_loader):<10} | {len(val_dataset)/max(1,n_total_samples)*100:.1f}%")
print(f"{'Evaluation':<15} | {len(eval_split):<10} | {len(eval_dataset):<20} | {len(eval_loader):<10} | {len(eval_dataset)/max(1,n_total_samples)*100:.1f}%")
print("-" * 70)
print(f"{'TOTAL':<15} | {n_total:<10} | {n_total_samples:<20} | {len(train_loader)+len(val_loader)+len(eval_loader):<10} | 100.0%")
print("=" * 70 + "\n")
# Out:
# Total files available for analysis: 40169
#
# ===========================================================================
#                NPZ FILE STRUCTURE SHOWCASE (9-ROI + Face Configuration)
# ===========================================================================
#   landmarks                   : Shape (450, 468, 2)        | Dtype float32
#   meta_camera_type            : Shape ()                   | Dtype <U12
#   meta_chunk_index            : Shape ()                   | Dtype int64
#   meta_condition              : Shape ()                   | Dtype <U5
#   meta_end_frame              : Shape ()                   | Dtype int64
#   meta_num_frames             : Shape ()                   | Dtype int64
#   meta_start_frame            : Shape ()                   | Dtype int64
#   meta_subject_id             : Shape ()                   | Dtype int64
#   meta_view_type              : Shape ()                   | Dtype <U5
#   ppg_values                  : Shape (450,)               | Dtype float64
#   roi_chin                    : Shape (450, 24, 24, 3)     | Dtype uint8
#   roi_chin_199                : Shape (450, 24, 24, 3)     | Dtype uint8
#   roi_forehead                : Shape (450, 24, 24, 3)     | Dtype uint8
#   roi_full_face               : Shape (450, 24, 24, 3)     | Dtype uint8
#   roi_left_cheek_280          : Shape (450, 24, 24, 3)     | Dtype uint8
#   roi_left_eye                : Shape (450, 24, 24, 3)     | Dtype uint8
#   roi_mouth                   : Shape (450, 24, 24, 3)     | Dtype uint8
#   roi_nose                    : Shape (450, 24, 24, 3)     | Dtype uint8
#   roi_right_cheek_50          : Shape (450, 24, 24, 3)     | Dtype uint8
#   roi_right_eye               : Shape (450, 24, 24, 3)     | Dtype uint8
#   time_deltas                 : Shape (450,)               | Dtype float64
#   vital_cholesterol           : Shape ()                   | Dtype float64
#   vital_glycated_hemoglobin   : Shape ()                   | Dtype float64
#   vital_hemoglobin            : Shape ()                   | Dtype float64
#   vital_lower_ap              : Shape ()                   | Dtype float64
#   vital_pulse                 : Shape ()                   | Dtype float64
#   vital_respiratory           : Shape ()                   | Dtype float64
#   vital_rigidity              : Shape ()                   | Dtype float64
#   vital_saturation            : Shape ()                   | Dtype float64
#   vital_stress                : Shape ()                   | Dtype float64
#   vital_upper_ap              : Shape ()                   | Dtype float64
# ===========================================================================
#
#
# Evaluating color space for path: /home/cristic/preprocessed_data/1020_FullHDwebcam_after_chunk0.npz
# Loaded 'roi_forehead' with shape: (450, 24, 24, 3) and dtype: uint8
#
# --- Channel Intensity Statistics ---
# Channel 0 Mean: 0.5472
# Channel 1 Mean: 0.4347
# Channel 2 Mean: 0.3352
# ------------------------------------
# /home/cristic/anaconda3/envs/rppg/lib/python3.11/site-packages/torch/cuda/__init__.py:734: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")
# Starting phase-locked optimization loop...
# Epoch 01/100 | LR: 0.000043 | Weights (P/M/S): [3.50/0.30/1.00] | Train Loss: 6.9704 | Val Loss: 6.7890 | Val PCC: -0.0018
#    ---> Improved! Saved new best checkpoint (Val PCC: -0.0018)
# Epoch 02/100 | LR: 0.000057 | Weights (P/M/S): [3.50/0.30/1.00] | Train Loss: 6.7573 | Val Loss: 6.7092 | Val PCC: +0.0006
#    ---> Improved! Saved new best checkpoint (Val PCC: +0.0006)
# Epoch 03/100 | LR: 0.000070 | Weights (P/M/S): [3.50/0.30/1.00] | Train Loss: 6.6873 | Val Loss: 6.6616 | Val PCC: +0.0060
#    ---> Improved! Saved new best checkpoint (Val PCC: +0.0060)
# Epoch 04/100 | LR: 0.000084 | Weights (P/M/S): [3.50/0.30/1.00] | Train Loss: 6.6358 | Val Loss: 6.6063 | Val PCC: +0.0073
#    ---> Improved! Saved new best checkpoint (Val PCC: +0.0073)
# Epoch 05/100 | LR: 0.000097 | Weights (P/M/S): [3.50/0.30/1.00] | Train Loss: 6.5923 | Val Loss: 6.5640 | Val PCC: +0.0101
#    ---> Improved! Saved new best checkpoint (Val PCC: +0.0101)
# Epoch 06/100 | LR: 0.000111 | Weights (P/M/S): [3.50/0.30/1.00] | Train Loss: 6.5563 | Val Loss: 6.5530 | Val PCC: +0.0120
#    ---> Improved! Saved new best checkpoint (Val PCC: +0.0120)
# Epoch 07/100 | LR: 0.000124 | Weights (P/M/S): [3.50/0.30/1.00] | Train Loss: 6.5233 | Val Loss: 6.5122 | Val PCC: +0.0111
#    ---> No improvement in Val PCC for 1/100 epochs.
# Epoch 08/100 | LR: 0.000138 | Weights (P/M/S): [3.50/0.30/1.00] | Train Loss: 6.4965 | Val Loss: 6.4749 | Val PCC: +0.0120
#    ---> Improved! Saved new best checkpoint (Val PCC: +0.0120)
# Epoch 09/100 | LR: 0.000151 | Weights (P/M/S): [3.50/0.30/1.00] | Train Loss: 6.4760 | Val Loss: 6.4495 | Val PCC: +0.0119
#    ---> No improvement in Val PCC for 1/100 epochs.
# Epoch 10/100 | LR: 0.000165 | Weights (P/M/S): [3.50/0.30/1.00] | Train Loss: 6.4539 | Val Loss: 6.4770 | Val PCC: +0.0125
#    ---> Improved! Saved new best checkpoint (Val PCC: +0.0125)
# Epoch 11/100 | LR: 0.000179 | Weights (P/M/S): [3.50/0.30/1.00] | Train Loss: 6.4386 | Val Loss: 6.4605 | Val PCC: +0.0125
#    ---> Improved! Saved new best checkpoint (Val PCC: +0.0125)
# Epoch 12/100 | LR: 0.000192 | Weights (P/M/S): [3.50/0.30/1.00] | Train Loss: 6.4129 | Val Loss: 6.4249 | Val PCC: +0.0130
#    ---> Improved! Saved new best checkpoint (Val PCC: +0.0130)
# Epoch 13/100 | LR: 0.000206 | Weights (P/M/S): [3.50/0.30/1.00] | Train Loss: 6.3941 | Val Loss: 6.4160 | Val PCC: +0.0134
#    ---> Improved! Saved new best checkpoint (Val PCC: +0.0134)
# Epoch 14/100 | LR: 0.000219 | Weights (P/M/S): [3.50/0.30/1.00] | Train Loss: 6.3760 | Val Loss: 6.3835 | Val PCC: +0.0137
#    ---> Improved! Saved new best checkpoint (Val PCC: +0.0137)
# Epoch 15/100 | LR: 0.000233 | Weights (P/M/S): [3.50/0.30/1.00] | Train Loss: 6.3571 | Val Loss: 6.3817 | Val PCC: +0.0147
#    ---> Improved! Saved new best checkpoint (Val PCC: +0.0147)
# Epoch 16/100 | LR: 0.000246 | Weights (P/M/S): [3.50/0.30/1.00] | Train Loss: 6.3369 | Val Loss: 6.3800 | Val PCC: +0.0144
#    ---> No improvement in Val PCC for 1/100 epochs.
# Epoch 17/100 | LR: 0.000260 | Weights (P/M/S): [3.50/0.30/1.00] | Train Loss: 6.3212 | Val Loss: 6.3573 | Val PCC: +0.0127
#    ---> No improvement in Val PCC for 2/100 epochs.
# Epoch 18/100 | LR: 0.000273 | Weights (P/M/S): [3.50/0.30/1.00] | Train Loss: 6.3042 | Val Loss: 6.3430 | Val PCC: +0.0135
#    ---> No improvement in Val PCC for 3/100 epochs.
# Epoch 19/100 | LR: 0.000287 | Weights (P/M/S): [3.50/0.30/1.00] | Train Loss: 6.2828 | Val Loss: 6.3413 | Val PCC: +0.0144
#    ---> No improvement in Val PCC for 4/100 epochs.
# /home/cristic/anaconda3/envs/rppg/lib/python3.11/site-packages/torch/optim/lr_scheduler.py:243: UserWarning: The epoch parameter in `scheduler.step()` was not necessary and is being deprecated where possible. Please use `scheduler.step()` to step the scheduler. During the deprecation, if epoch is different from None, the closed form is used instead of the new chainable form, where available. Please open an issue if you are unable to replicate your use case: https://github.com/pytorch/pytorch/issues/new/choose.
#   warnings.warn(EPOCH_DEPRECATION_WARNING, UserWarning)
# Epoch 20/100 | LR: 0.000300 | Weights (P/M/S): [3.50/0.30/1.00] | Train Loss: 6.2650 | Val Loss: 6.3538 | Val PCC: +0.0134
#    ---> No improvement in Val PCC for 5/100 epochs.
# Epoch 21/100 | LR: 0.000300 | Weights (P/M/S): [3.50/0.30/1.00] | Train Loss: 6.2516 | Val Loss: 6.3457 | Val PCC: +0.0142
#    ---> No improvement in Val PCC for 6/100 epochs.
# Epoch 22/100 | LR: 0.000300 | Weights (P/M/S): [3.50/0.30/1.00] | Train Loss: 6.2271 | Val Loss: 6.2760 | Val PCC: +0.0141
#    ---> No improvement in Val PCC for 7/100 epochs.
# Epoch 23/100 | LR: 0.000299 | Weights (P/M/S): [3.50/0.30/1.00] | Train Loss: 6.2022 | Val Loss: 6.2587 | Val PCC: +0.0134
#    ---> No improvement in Val PCC for 8/100 epochs.
# Epoch 24/100 | LR: 0.000298 | Weights (P/M/S): [3.50/0.30/1.00] | Train Loss: 6.1835 | Val Loss: 6.2865 | Val PCC: +0.0143
#    ---> No improvement in Val PCC for 9/100 epochs.
# Epoch 25/100 | LR: 0.000297 | Weights (P/M/S): [3.50/0.30/1.00] | Train Loss: 6.1586 | Val Loss: 6.2724 | Val PCC: +0.0134
#    ---> No improvement in Val PCC for 10/100 epochs.
# Epoch 26/100 | LR: 0.000296 | Weights (P/M/S): [3.50/0.30/1.00] | Train Loss: 6.1314 | Val Loss: 6.2153 | Val PCC: +0.0143
#    ---> No improvement in Val PCC for 11/100 epochs.
# Epoch 27/100 | LR: 0.000294 | Weights (P/M/S): [3.50/0.30/1.00] | Train Loss: 6.1132 | Val Loss: 6.2226 | Val PCC: +0.0128
#    ---> No improvement in Val PCC for 12/100 epochs.
# Epoch 28/100 | LR: 0.000293 | Weights (P/M/S): [3.50/0.30/1.00] | Train Loss: 6.0968 | Val Loss: 6.2109 | Val PCC: +0.0145
#    ---> No improvement in Val PCC for 13/100 epochs.
# Epoch 29/100 | LR: 0.000291 | Weights (P/M/S): [3.50/0.30/1.00] | Train Loss: 6.0758 | Val Loss: 6.1835 | Val PCC: +0.0147
#    ---> Improved! Saved new best checkpoint (Val PCC: +0.0147)
# Epoch 30/100 | LR: 0.000289 | Weights (P/M/S): [3.50/0.30/1.00] | Train Loss: 6.0531 | Val Loss: 6.1839 | Val PCC: +0.0146
#    ---> No improvement in Val PCC for 1/100 epochs.
# Epoch 31/100 | LR: 0.000286 | Weights (P/M/S): [3.50/0.30/1.00] | Train Loss: 6.0348 | Val Loss: 6.1474 | Val PCC: +0.0157
#    ---> Improved! Saved new best checkpoint (Val PCC: +0.0157)
# Epoch 32/100 | LR: 0.000284 | Weights (P/M/S): [3.50/0.30/1.00] | Train Loss: 6.0255 | Val Loss: 6.1362 | Val PCC: +0.0138
#    ---> No improvement in Val PCC for 1/100 epochs.
# Epoch 33/100 | LR: 0.000281 | Weights (P/M/S): [3.50/0.30/1.00] | Train Loss: 6.0016 | Val Loss: 6.1207 | Val PCC: +0.0137
#    ---> No improvement in Val PCC for 2/100 epochs.
# Epoch 34/100 | LR: 0.000278 | Weights (P/M/S): [3.50/0.30/1.00] | Train Loss: 5.9862 | Val Loss: 6.1459 | Val PCC: +0.0135
#    ---> No improvement in Val PCC for 3/100 epochs.
# Epoch 35/100 | LR: 0.000275 | Weights (P/M/S): [3.50/0.30/1.00] | Train Loss: 5.9733 | Val Loss: 6.1112 | Val PCC: +0.0142
#    ---> No improvement in Val PCC for 4/100 epochs.
# Epoch 36/100 | LR: 0.000271 | Weights (P/M/S): [3.50/0.30/1.00] | Train Loss: 5.9491 | Val Loss: 6.0909 | Val PCC: +0.0139
#    ---> No improvement in Val PCC for 5/100 epochs.
# Epoch 37/100 | LR: 0.000268 | Weights (P/M/S): [3.50/0.30/1.00] | Train Loss: 5.9421 | Val Loss: 6.0834 | Val PCC: +0.0128
#    ---> No improvement in Val PCC for 6/100 epochs.
# Epoch 38/100 | LR: 0.000264 | Weights (P/M/S): [3.50/0.30/1.00] | Train Loss: 5.9290 | Val Loss: 6.0807 | Val PCC: +0.0125
#    ---> No improvement in Val PCC for 7/100 epochs.
# Epoch 39/100 | LR: 0.000260 | Weights (P/M/S): [3.50/0.30/1.00] | Train Loss: 5.9113 | Val Loss: 6.0878 | Val PCC: +0.0135
#    ---> No improvement in Val PCC for 8/100 epochs.
# Epoch 40/100 | LR: 0.000256 | Weights (P/M/S): [3.50/0.30/1.00] | Train Loss: 5.8977 | Val Loss: 6.0690 | Val PCC: +0.0142
#    ---> No improvement in Val PCC for 9/100 epochs.
# Epoch 41/100 | LR: 0.000252 | Weights (P/M/S): [3.50/0.30/1.00] | Train Loss: 5.8837 | Val Loss: 6.0505 | Val PCC: +0.0134
#    ---> No improvement in Val PCC for 10/100 epochs.
# Epoch 42/100 | LR: 0.000248 | Weights (P/M/S): [3.50/0.30/1.00] | Train Loss: 5.8733 | Val Loss: 6.0574 | Val PCC: +0.0138
#    ---> No improvement in Val PCC for 11/100 epochs.
# Epoch 43/100 | LR: 0.000243 | Weights (P/M/S): [3.50/0.30/1.00] | Train Loss: 5.8628 | Val Loss: 6.0603 | Val PCC: +0.0132
#    ---> No improvement in Val PCC for 12/100 epochs.
# Epoch 44/100 | LR: 0.000238 | Weights (P/M/S): [3.50/0.30/1.00] | Train Loss: 5.8482 | Val Loss: 6.0360 | Val PCC: +0.0130
#    ---> No improvement in Val PCC for 13/100 epochs.
# Epoch 45/100 | LR: 0.000234 | Weights (P/M/S): [3.50/0.30/1.00] | Train Loss: 5.8316 | Val Loss: 6.0302 | Val PCC: +0.0131
#    ---> No improvement in Val PCC for 14/100 epochs.
# Epoch 46/100 | LR: 0.000229 | Weights (P/M/S): [3.50/0.30/1.00] | Train Loss: 5.8224 | Val Loss: 6.0267 | Val PCC: +0.0130
#    ---> No improvement in Val PCC for 15/100 epochs.
# Epoch 47/100 | LR: 0.000224 | Weights (P/M/S): [3.50/0.30/1.00] | Train Loss: 5.8107 | Val Loss: 6.0198 | Val PCC: +0.0136
#    ---> No improvement in Val PCC for 16/100 epochs.
# Epoch 48/100 | LR: 0.000218 | Weights (P/M/S): [3.50/0.30/1.00] | Train Loss: 5.7985 | Val Loss: 6.0129 | Val PCC: +0.0128
#    ---> No improvement in Val PCC for 17/100 epochs.
# Epoch 49/100 | LR: 0.000213 | Weights (P/M/S): [3.50/0.30/1.00] | Train Loss: 5.7908 | Val Loss: 6.0235 | Val PCC: +0.0140
#    ---> No improvement in Val PCC for 18/100 epochs.
# Epoch 50/100 | LR: 0.000208 | Weights (P/M/S): [3.50/0.30/1.00] | Train Loss: 5.7792 | Val Loss: 5.9990 | Val PCC: +0.0124
#    ---> No improvement in Val PCC for 19/100 epochs.
# Epoch 51/100 | LR: 0.000202 | Weights (P/M/S): [3.50/0.30/1.00] | Train Loss: 5.7698 | Val Loss: 5.9827 | Val PCC: +0.0130
#    ---> No improvement in Val PCC for 20/100 epochs.
# Epoch 52/100 | LR: 0.000197 | Weights (P/M/S): [3.50/0.30/1.00] | Train Loss: 5.7585 | Val Loss: 5.9874 | Val PCC: +0.0137
#    ---> No improvement in Val PCC for 21/100 epochs.
# Epoch 53/100 | LR: 0.000191 | Weights (P/M/S): [3.50/0.30/1.00] | Train Loss: 5.7443 | Val Loss: 6.0115 | Val PCC: +0.0132
#    ---> No improvement in Val PCC for 22/100 epochs.
# Epoch 54/100 | LR: 0.000185 | Weights (P/M/S): [3.50/0.30/1.00] | Train Loss: 5.7383 | Val Loss: 5.9651 | Val PCC: +0.0130
#    ---> No improvement in Val PCC for 23/100 epochs.
# Epoch 55/100 | LR: 0.000180 | Weights (P/M/S): [3.50/0.30/1.00] | Train Loss: 5.7248 | Val Loss: 5.9625 | Val PCC: +0.0128
#    ---> No improvement in Val PCC for 24/100 epochs.
# Epoch 56/100 | LR: 0.000174 | Weights (P/M/S): [3.50/0.30/1.00] | Train Loss: 5.7170 | Val Loss: 5.9607 | Val PCC: +0.0136
#    ---> No improvement in Val PCC for 25/100 epochs.
# Epoch 57/100 | LR: 0.000168 | Weights (P/M/S): [3.50/0.30/1.00] | Train Loss: 5.7047 | Val Loss: 5.9474 | Val PCC: +0.0132
#    ---> No improvement in Val PCC for 26/100 epochs.
# Epoch 58/100 | LR: 0.000162 | Weights (P/M/S): [3.50/0.30/1.00] | Train Loss: 5.6954 | Val Loss: 5.9396 | Val PCC: +0.0128
#    ---> No improvement in Val PCC for 27/100 epochs.
# Epoch 59/100 | LR: 0.000156 | Weights (P/M/S): [3.50/0.30/1.00] | Train Loss: 5.6911 | Val Loss: 5.9461 | Val PCC: +0.0114
#    ---> No improvement in Val PCC for 28/100 epochs.
# Epoch 60/100 | LR: 0.000151 | Weights (P/M/S): [3.50/0.30/1.00] | Train Loss: 5.6814 | Val Loss: 5.9236 | Val PCC: +0.0125
#    ---> No improvement in Val PCC for 29/100 epochs.
# Epoch 61/100 | LR: 0.000145 | Weights (P/M/S): [3.50/0.30/1.00] | Train Loss: 5.6695 | Val Loss: 5.9147 | Val PCC: +0.0130
#    ---> No improvement in Val PCC for 30/100 epochs.
# Epoch 62/100 | LR: 0.000139 | Weights (P/M/S): [3.50/0.30/1.00] | Train Loss: 5.6649 | Val Loss: 5.9465 | Val PCC: +0.0118
#    ---> No improvement in Val PCC for 31/100 epochs.
# Epoch 63/100 | LR: 0.000133 | Weights (P/M/S): [3.50/0.30/1.00] | Train Loss: 5.6537 | Val Loss: 5.9119 | Val PCC: +0.0127
#    ---> No improvement in Val PCC for 32/100 epochs.
# Epoch 64/100 | LR: 0.000127 | Weights (P/M/S): [3.50/0.30/1.00] | Train Loss: 5.6426 | Val Loss: 5.9245 | Val PCC: +0.0125
#    ---> No improvement in Val PCC for 33/100 epochs.
# Epoch 65/100 | LR: 0.000121 | Weights (P/M/S): [3.50/0.30/1.00] | Train Loss: 5.6404 | Val Loss: 5.9256 | Val PCC: +0.0125
#    ---> No improvement in Val PCC for 34/100 epochs.
# Epoch 66/100 | LR: 0.000116 | Weights (P/M/S): [3.50/0.30/1.00] | Train Loss: 5.6271 | Val Loss: 5.8889 | Val PCC: +0.0129
#    ---> No improvement in Val PCC for 35/100 epochs.
# Epoch 67/100 | LR: 0.000110 | Weights (P/M/S): [3.50/0.30/1.00] | Train Loss: 5.6207 | Val Loss: 5.8937 | Val PCC: +0.0128
#    ---> No improvement in Val PCC for 36/100 epochs.
# Epoch 68/100 | LR: 0.000104 | Weights (P/M/S): [3.50/0.30/1.00] | Train Loss: 5.6162 | Val Loss: 5.8885 | Val PCC: +0.0124
#    ---> No improvement in Val PCC for 37/100 epochs.
# Epoch 69/100 | LR: 0.000099 | Weights (P/M/S): [3.50/0.30/1.00] | Train Loss: 5.6089 | Val Loss: 5.8875 | Val PCC: +0.0130
#    ---> No improvement in Val PCC for 38/100 epochs.
# Epoch 70/100 | LR: 0.000093 | Weights (P/M/S): [3.50/0.30/1.00] | Train Loss: 5.5962 | Val Loss: 5.8825 | Val PCC: +0.0129
#    ---> No improvement in Val PCC for 39/100 epochs.
# Epoch 71/100 | LR: 0.000088 | Weights (P/M/S): [3.50/0.30/1.00] | Train Loss: 5.5879 | Val Loss: 5.9001 | Val PCC: +0.0122
#    ---> No improvement in Val PCC for 40/100 epochs.
# Epoch 72/100 | LR: 0.000083 | Weights (P/M/S): [3.50/0.30/1.00] | Train Loss: 5.5805 | Val Loss: 5.8712 | Val PCC: +0.0129
#    ---> No improvement in Val PCC for 41/100 epochs.
# Epoch 73/100 | LR: 0.000077 | Weights (P/M/S): [3.50/0.30/1.00] | Train Loss: 5.5771 | Val Loss: 5.8698 | Val PCC: +0.0130
#    ---> No improvement in Val PCC for 42/100 epochs.
# Epoch 74/100 | LR: 0.000072 | Weights (P/M/S): [3.50/0.30/1.00] | Train Loss: 5.5707 | Val Loss: 5.8694 | Val PCC: +0.0132
#    ---> No improvement in Val PCC for 43/100 epochs.
# Epoch 75/100 | LR: 0.000067 | Weights (P/M/S): [3.50/0.30/1.00] | Train Loss: 5.5630 | Val Loss: 5.8707 | Val PCC: +0.0132
#    ---> No improvement in Val PCC for 44/100 epochs.
# Epoch 76/100 | LR: 0.000063 | Weights (P/M/S): [3.50/0.30/1.00] | Train Loss: 5.5618 | Val Loss: 5.8628 | Val PCC: +0.0127
#    ---> No improvement in Val PCC for 45/100 epochs.
# Epoch 77/100 | LR: 0.000058 | Weights (P/M/S): [3.50/0.30/1.00] | Train Loss: 5.5527 | Val Loss: 5.8551 | Val PCC: +0.0129
#    ---> No improvement in Val PCC for 46/100 epochs.
# Epoch 78/100 | LR: 0.000053 | Weights (P/M/S): [3.50/0.30/1.00] | Train Loss: 5.5489 | Val Loss: 5.8583 | Val PCC: +0.0126
#    ---> No improvement in Val PCC for 47/100 epochs.
# Epoch 79/100 | LR: 0.000049 | Weights (P/M/S): [3.50/0.30/1.00] | Train Loss: 5.5365 | Val Loss: 5.8491 | Val PCC: +0.0132
#    ---> No improvement in Val PCC for 48/100 epochs.
# Epoch 80/100 | LR: 0.000045 | Weights (P/M/S): [3.50/0.30/1.00] | Train Loss: 5.5355 | Val Loss: 5.8498 | Val PCC: +0.0124
#    ---> No improvement in Val PCC for 49/100 epochs.
# Epoch 81/100 | LR: 0.000041 | Weights (P/M/S): [3.50/0.30/1.00] | Train Loss: 5.5312 | Val Loss: 5.8562 | Val PCC: +0.0125
#    ---> No improvement in Val PCC for 50/100 epochs.
# Epoch 82/100 | LR: 0.000037 | Weights (P/M/S): [3.50/0.30/1.00] | Train Loss: 5.5221 | Val Loss: 5.8449 | Val PCC: +0.0130
#    ---> No improvement in Val PCC for 51/100 epochs.
# Epoch 83/100 | LR: 0.000033 | Weights (P/M/S): [3.50/0.30/1.00] | Train Loss: 5.5188 | Val Loss: 5.8430 | Val PCC: +0.0126
#    ---> No improvement in Val PCC for 52/100 epochs.
# Epoch 84/100 | LR: 0.000030 | Weights (P/M/S): [3.50/0.30/1.00] | Train Loss: 5.5149 | Val Loss: 5.8385 | Val PCC: +0.0125
#    ---> No improvement in Val PCC for 53/100 epochs.
# Epoch 85/100 | LR: 0.000026 | Weights (P/M/S): [3.50/0.30/1.00] | Train Loss: 5.5101 | Val Loss: 5.8411 | Val PCC: +0.0123
#    ---> No improvement in Val PCC for 54/100 epochs.
# Epoch 86/100 | LR: 0.000023 | Weights (P/M/S): [3.50/0.30/1.00] | Train Loss: 5.5105 | Val Loss: 5.8451 | Val PCC: +0.0125
#    ---> No improvement in Val PCC for 55/100 epochs.
# Epoch 87/100 | LR: 0.000020 | Weights (P/M/S): [3.50/0.30/1.00] | Train Loss: 5.5063 | Val Loss: 5.8429 | Val PCC: +0.0127
#    ---> No improvement in Val PCC for 56/100 epochs.
# Epoch 88/100 | LR: 0.000017 | Weights (P/M/S): [3.50/0.30/1.00] | Train Loss: 5.4971 | Val Loss: 5.8405 | Val PCC: +0.0125
#    ---> No improvement in Val PCC for 57/100 epochs.
# Epoch 89/100 | LR: 0.000015 | Weights (P/M/S): [3.50/0.30/1.00] | Train Loss: 5.4951 | Val Loss: 5.8349 | Val PCC: +0.0125
#    ---> No improvement in Val PCC for 58/100 epochs.
# Epoch 90/100 | LR: 0.000012 | Weights (P/M/S): [3.50/0.30/1.00] | Train Loss: 5.4968 | Val Loss: 5.8364 | Val PCC: +0.0125
#    ---> No improvement in Val PCC for 59/100 epochs.
# Epoch 91/100 | LR: 0.000010 | Weights (P/M/S): [3.50/0.30/1.00] | Train Loss: 5.4870 | Val Loss: 5.8515 | Val PCC: +0.0127
#    ---> No improvement in Val PCC for 60/100 epochs.
# Epoch 92/100 | LR: 0.000008 | Weights (P/M/S): [3.50/0.30/1.00] | Train Loss: 5.4882 | Val Loss: 5.8272 | Val PCC: +0.0125
#    ---> No improvement in Val PCC for 61/100 epochs.
# Epoch 93/100 | LR: 0.000007 | Weights (P/M/S): [3.50/0.30/1.00] | Train Loss: 5.4820 | Val Loss: 5.8285 | Val PCC: +0.0126
#    ---> No improvement in Val PCC for 62/100 epochs.
# Epoch 94/100 | LR: 0.000005 | Weights (P/M/S): [3.50/0.30/1.00] | Train Loss: 5.4811 | Val Loss: 5.8408 | Val PCC: +0.0123
#    ---> No improvement in Val PCC for 63/100 epochs.
# Epoch 95/100 | LR: 0.000004 | Weights (P/M/S): [3.50/0.30/1.00] | Train Loss: 5.4796 | Val Loss: 5.8339 | Val PCC: +0.0122
#    ---> No improvement in Val PCC for 64/100 epochs.
# Epoch 96/100 | LR: 0.000003 | Weights (P/M/S): [3.50/0.30/1.00] | Train Loss: 5.4808 | Val Loss: 5.8341 | Val PCC: +0.0126
#    ---> No improvement in Val PCC for 65/100 epochs.
# Epoch 97/100 | LR: 0.000002 | Weights (P/M/S): [3.50/0.30/1.00] | Train Loss: 5.4784 | Val Loss: 5.8349 | Val PCC: +0.0125
#    ---> No improvement in Val PCC for 66/100 epochs.
# Epoch 98/100 | LR: 0.000001 | Weights (P/M/S): [3.50/0.30/1.00] | Train Loss: 5.4777 | Val Loss: 5.8309 | Val PCC: +0.0125
#    ---> No improvement in Val PCC for 67/100 epochs.
# Epoch 99/100 | LR: 0.000001 | Weights (P/M/S): [3.50/0.30/1.00] | Train Loss: 5.4798 | Val Loss: 5.8358 | Val PCC: +0.0124
#    ---> No improvement in Val PCC for 68/100 epochs.
# Epoch 100/100 | LR: 0.000001 | Weights (P/M/S): [3.50/0.30/1.00] | Train Loss: 5.4775 | Val Loss: 5.8382 | Val PCC: +0.0124
#    ---> No improvement in Val PCC for 69/100 epochs.
#
# Loading best model state dict from memory (Best Val Loss: 0.0157)...
#
# ==================================================
#                EVALUATION SET METRICS RESULTS
# ==================================================
#   Pearson Correlation Coefficient (PCC) : 0.0180
#   Mean Absolute Error (MAE)            : 7.98 BPM
#   Root Mean Squared Error (RMSE)       : 13.36 BPM
#   Signal-to-Noise Ratio (SNR)          : -0.74 dB
# ==================================================
#
# Model checkpoint successfully saved to: spatiotemporal_physnet_best_shuffle_v2.pth
#
# ======================================================================
#                  DATASET SPLIT & SAMPLE SUMMARY TABLE
# ======================================================================
# Split Set       | NPZ Files  | 450-Frame Windows    | Batches    | Ratio
# ----------------------------------------------------------------------
# Train           | 28118      | 26483                | 1656       | 70.1%
# Validation      | 6025       | 5657                 | 354        | 15.0%
# Evaluation      | 6026       | 5614                 | 351        | 14.9%
# ----------------------------------------------------------------------
# TOTAL           | 40169      | 37754                | 2361       | 100.0%
# ======================================================================

# %%
import os
import torch
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import welch

# def run_inference_on_sample(npz_file_path, model, sequence_length=450, fs=30.0):
#     """
#     Execute inference on a single NPZ validation sequence with strict edge-transient 
#     suppression and explicit Z-score standardization on both GT and Prediction.
#     """
#     print(f"--- INFERENCE RUN ON: {os.path.basename(npz_file_path)} ---")
#     data = load_npz_file(npz_file_path)
#     if data is None:
#         return None, None
    
#     ppg_key = 'ppg_values' if 'ppg_values' in data else 'ppg'
#     if len(data[ppg_key]) < sequence_length:
#         print("Error: Input file length is shorter than the required sequence length.")
#         return None, None
        
#     # 1. Ground Truth Pipeline: Detrend -> Bandpass Filter -> Z-Score Normalization
#     raw_target_ppg = data[ppg_key][:sequence_length].copy()
#     raw_target_detrend = raw_target_ppg - np.mean(raw_target_ppg)  # Prevent filter edge distortion
#     filtered_gt = butter_bandpass_filter(raw_target_detrend, fs=fs)
#     gt_norm = (filtered_gt - np.mean(filtered_gt)) / (np.std(filtered_gt) + 1e-8)
    
#     # 2. Extract & Format Multi-ROI Inputs
#     roi_inputs = []
#     for roi_name in ROI_ORDER:
#         actual_key = next((k for k in data.files if roi_name == k), None)
#         if actual_key is not None:
#             roi_data = data[actual_key][:sequence_length]
#         else:
#             roi_data = np.zeros((sequence_length, 24, 24, 3), dtype=np.uint8)
#         roi_inputs.append(roi_data.astype(np.float32) / 255.0)
        
#     stacked_rois = np.stack(roi_inputs, axis=0)
#     stacked_rois = np.transpose(stacked_rois, (0, 4, 1, 2, 3))
#     stacked_rois = np.reshape(stacked_rois, (30, sequence_length, 24, 24))
    
#     input_tensor = torch.tensor(stacked_rois, dtype=torch.float32).unsqueeze(0).to(DEVICE)
    
#     # 3. Network Inference Pass
#     model.eval()
#     with torch.no_grad():
#         output_signal = model(input_tensor).cpu().numpy()[0]
        
#     # 4. Prediction Pipeline: Detrend -> Bandpass Filter -> Z-Score Normalization
#     output_signal_detrend = output_signal - np.mean(output_signal)  # Prevent filter edge spikes
#     filtered_pred = butter_bandpass_filter(output_signal_detrend, fs=fs)
#     pred_norm = (filtered_pred - np.mean(filtered_pred)) / (np.std(filtered_pred) + 1e-8)
    
#     # 5. Heart Rate Metrics Calculation
#     hr_pred = calculate_bpm_from_fft(pred_norm, fs=fs)
#     hr_true = calculate_bpm_from_fft(gt_norm, fs=fs)
    
#     print(f"  Predicted HR  : {hr_pred:.2f} BPM")
#     print(f"  Ground-Truth  : {hr_true:.2f} BPM")
#     print(f"  Absolute Error: {abs(hr_pred - hr_true):.2f} BPM")
#     print("----------------------------------------------------\n")
#     return pred_norm, gt_norm

def run_inference_on_sample(npz_file_path, model, sequence_length=450, fs=30.0, pad_margin=30):
    """
    Execute inference on an NPZ sample, applying reflection padding prior to 
    bandpass filtering to completely suppress convolution boundary ringing at frame 0.
    """
    print(f"--- INFERENCE RUN ON: {os.path.basename(npz_file_path)} ---")
    data = load_npz_file(npz_file_path)
    if data is None:
        return None, None
    
    ppg_key = 'ppg_values' if 'ppg_values' in data else 'ppg'
    if len(data[ppg_key]) < sequence_length:
        print("Error: Input file length is shorter than required sequence length.")
        return None, None
        
    # 1. Ground Truth Pipeline (Padded filtering to prevent edge artifacts)
    raw_target_ppg = data[ppg_key][:sequence_length].copy()
    gt_padded = np.pad(raw_target_ppg, pad_margin, mode='reflect')
    gt_filtered = butter_bandpass_filter(gt_padded - np.mean(gt_padded), fs=fs)
    gt_cropped = gt_filtered[pad_margin:-pad_margin]
    gt_norm = (gt_cropped - np.mean(gt_cropped)) / (np.std(gt_cropped) + 1e-8)
    
    # 2. Multi-ROI Input Tensor Preparation
    roi_inputs = []
    for roi_name in ROI_ORDER:
        actual_key = next((k for k in data.files if roi_name == k), None)
        if actual_key is not None:
            roi_data = data[actual_key][:sequence_length]
        else:
            roi_data = np.zeros((sequence_length, 24, 24, 3), dtype=np.uint8)
        roi_inputs.append(roi_data.astype(np.float32) / 255.0)
        
    stacked_rois = np.stack(roi_inputs, axis=0)
    stacked_rois = np.transpose(stacked_rois, (0, 4, 1, 2, 3))
    stacked_rois = np.reshape(stacked_rois, (30, sequence_length, 24, 24))
    
    input_tensor = torch.tensor(stacked_rois, dtype=torch.float32).unsqueeze(0).to(DEVICE)
    
    # 3. Network Forward Pass
    model.eval()
    with torch.no_grad():
        output_signal = model(input_tensor).cpu().numpy()[0]
        
    # 4. Prediction Pipeline: Pad -> Filter -> Crop -> Z-Score Normalize
    pred_padded = np.pad(output_signal, pad_margin, mode='reflect')
    pred_filtered = butter_bandpass_filter(pred_padded - np.mean(pred_padded), fs=fs)
    pred_cropped = pred_filtered[pad_margin:-pad_margin]
    pred_norm = (pred_cropped - np.mean(pred_cropped)) / (np.std(pred_cropped) + 1e-8)
    
    # 5. Heart Rate Metrics Calculation
    hr_pred = calculate_bpm_from_fft(pred_norm, fs=fs)
    hr_true = calculate_bpm_from_fft(gt_norm, fs=fs)
    
    print(f"  Predicted HR  : {hr_pred:.2f} BPM")
    print(f"  Ground-Truth  : {hr_true:.2f} BPM")
    print(f"  Absolute Error: {abs(hr_pred - hr_true):.2f} BPM")
    print("----------------------------------------------------\n")
    return pred_norm, gt_norm
# ============================================================================
# EXECUTION & DASHBOARD PLOTTING CELL
# ============================================================================

# Select sample file from validation split
sample_val_file = val_split[0] if len(val_split) > 0 else npz_files[0]
inference_pred, inference_gt = run_inference_on_sample(sample_val_file, model)

# Create 2x2 Visualization Dashboard
fig, axs = plt.subplots(2, 2, figsize=(14, 10))

# --- Subplot 1: Convergence Curves ---
epochs_range = range(1, len(train_losses) + 1)
axs[0, 0].plot(epochs_range, train_losses, label='Train Loss', color='#1f77b4', linewidth=2.5, marker='o', markersize=3)
axs[0, 0].plot(epochs_range, val_losses, label='Val Loss', color='#ff7f0e', linewidth=2.5, marker='s', markersize=3)
axs[0, 0].set_title('Spatio-Temporal Model Loss Convergence')
axs[0, 0].set_xlabel('Training Epochs')
axs[0, 0].set_ylabel('Tri-Objective Loss (Pearson + MSE + PSD)')
axs[0, 0].legend()

# --- Subplot 2: Standardized Waveform Alignment ---
if inference_pred is not None and inference_gt is not None:
    axs[0, 1].plot(inference_gt, label='GT PPG (Normalized μ=0, σ=1)', color='#7f7f7f', alpha=0.85, linewidth=2)
    axs[0, 1].plot(inference_pred, label='10-ROI Predicted rPPG', color='#2ca02c', linewidth=2.2)
    axs[0, 1].set_title('Signal Waveform Comparison (Normalized Scale)')
    axs[0, 1].set_xlabel('Frames Timeline')
    axs[0, 1].set_ylabel('Normalized Amplitude (Z-Score)')
    axs[0, 1].set_ylim(-3.5, 3.5)  # Constrain y-axis to valid standardized bounds
    axs[0, 1].legend()

# --- Subplot 3: Spectral Density Alignment ---
if inference_pred is not None and inference_gt is not None:
    freqs_p, psd_p = welch(inference_pred, fs=30.0, nperseg=len(inference_pred))
    freqs_t, psd_t = welch(inference_gt, fs=30.0, nperseg=len(inference_gt))
    
    axs[1, 0].plot(freqs_t * 60.0, psd_t, label='GT Spectrum', color='#7f7f7f', alpha=0.85, linewidth=2)
    axs[1, 0].plot(freqs_p * 60.0, psd_p, label='Pred Spectrum', color='#d62728', linewidth=2.2)
    axs[1, 0].set_xlim(40, 180)
    axs[1, 0].set_title('Power Spectral Density (PSD) Comparison')
    axs[1, 0].set_xlabel('Heart Rate (BPM)')
    axs[1, 0].set_ylabel('Spectral Magnitude')
    axs[1, 0].legend()

# --- Subplot 4: Summary Card ---
axs[1, 1].axis('off')
metric_summary_card = (
    "10-ROI Spatio-Temporal Evaluation Summary\n\n"
    f"• Pearson Correlation Coefficient (PCC): {metrics['PCC']:.4f}\n"
    f"• MAE: {metrics['MAE']:.2f} BPM\n"
    f"• RMSE: {metrics['RMSE']:.2f} BPM\n"
    f"• Signal-to-Noise Ratio (SNR): {metrics['SNR']:.2f} dB\n\n"
    f"Configuration Info:\n"
    f"• Spatio-Temporal Model channels: 30 (10 ROIs × 3 RGB)\n"
    f"• Sequence segment window: 450 frames (15.0s @ 30 FPS)\n"
    f"• Standardized GT and Pred normalization (μ=0, σ=1)\n"
    f"• Loss: Pearson + 0.3×MSE + 1.0×PSD KL-Divergence"
)
axs[1, 1].text(0.05, 0.15, metric_summary_card, fontsize=11, 
              bbox=dict(boxstyle='round,pad=1.2', facecolor='#f8f9fa', edgecolor='#dee2e6'))

plt.tight_layout()
plt.show()
# Out:
# --- INFERENCE RUN ON: 1176_FullHDwebcam_after_chunk14.npz ---
#   Predicted HR  : 96.00 BPM
#   Ground-Truth  : 96.00 BPM
#   Absolute Error: 0.00 BPM
# ----------------------------------------------------

# %%
# ============================================================================
# INFERENCE & DASHBOARD PLOTTING CELL
# ============================================================================
import os
import torch
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import welch

def run_inference_on_sample(npz_file_path, model, sequence_length=450, fs=30.0, pad_margin=30):
    """
    Execute inference on an NPZ sample, applying reflection padding prior to 
    bandpass filtering to completely suppress convolution boundary ringing at frame 0.
    """
    print(f"--- INFERENCE RUN ON: {os.path.basename(npz_file_path)} ---")
    data = load_npz_file(npz_file_path)
    if data is None:
        return None, None
    
    ppg_key = 'ppg_values' if 'ppg_values' in data else 'ppg'
    if len(data[ppg_key]) < sequence_length:
        print("Error: Input file length is shorter than required sequence length.")
        return None, None
        
    # 1. Ground Truth Pipeline (Padded filtering to prevent edge artifacts)
    raw_target_ppg = data[ppg_key][:sequence_length].copy()
    gt_padded = np.pad(raw_target_ppg, pad_margin, mode='reflect')
    gt_filtered = butter_bandpass_filter(gt_padded - np.mean(gt_padded), fs=fs)
    gt_cropped = gt_filtered[pad_margin:-pad_margin]
    gt_norm = (gt_cropped - np.mean(gt_cropped)) / (np.std(gt_cropped) + 1e-8)
    
    # 2. Multi-ROI Input Tensor Preparation
    roi_inputs = []
    for roi_name in ROI_ORDER:
        actual_key = next((k for k in data.files if roi_name == k), None)
        if actual_key is not None:
            roi_data = data[actual_key][:sequence_length]
        else:
            roi_data = np.zeros((sequence_length, 24, 24, 3), dtype=np.uint8)
        roi_inputs.append(roi_data.astype(np.float32) / 255.0)
        
    stacked_rois = np.stack(roi_inputs, axis=0)
    stacked_rois = np.transpose(stacked_rois, (0, 4, 1, 2, 3))
    stacked_rois = np.reshape(stacked_rois, (30, sequence_length, 24, 24))
    
    input_tensor = torch.tensor(stacked_rois, dtype=torch.float32).unsqueeze(0).to(DEVICE)
    
    # 3. Network Forward Pass
    model.eval()
    with torch.no_grad():
        output_signal = model(input_tensor).cpu().numpy()[0]
        
    # 4. Prediction Pipeline: Pad -> Filter -> Crop -> Z-Score Normalize
    pred_padded = np.pad(output_signal, pad_margin, mode='reflect')
    pred_filtered = butter_bandpass_filter(pred_padded - np.mean(pred_padded), fs=fs)
    pred_cropped = pred_filtered[pad_margin:-pad_margin]
    pred_norm = (pred_cropped - np.mean(pred_cropped)) / (np.std(pred_cropped) + 1e-8)
    
    # 5. Heart Rate Metrics Calculation
    hr_pred = calculate_bpm_from_fft(pred_norm, fs=fs)
    hr_true = calculate_bpm_from_fft(gt_norm, fs=fs)
    
    print(f"  Predicted HR  : {hr_pred:.2f} BPM")
    print(f"  Ground-Truth  : {hr_true:.2f} BPM")
    print(f"  Absolute Error: {abs(hr_pred - hr_true):.2f} BPM")
    print("----------------------------------------------------\n")
    return pred_norm, gt_norm

# Select sample file from validation split
sample_val_file = val_split[0] if len(val_split) > 0 else npz_files[0]
inference_pred, inference_gt = run_inference_on_sample(sample_val_file, model)

# Create 2x2 Visualization Dashboard
fig, axs = plt.subplots(2, 2, figsize=(15, 11))

# --- Subplot 1: Convergence Curves (DUAL AXIS) ---
epochs_range = range(1, len(train_losses) + 1)
ax1 = axs[0, 0]
line1 = ax1.plot(epochs_range, train_losses, label='Train Loss', color='#1f77b4', linewidth=2.5, marker='o', markersize=3)
line2 = ax1.plot(epochs_range, val_losses, label='Val Loss', color='#ff7f0e', linewidth=2.5, marker='s', markersize=3)
ax1.set_title('Model Convergence (Loss vs. Validation PCC)')
ax1.set_xlabel('Training Epochs')
ax1.set_ylabel('Tri-Objective Loss (Dynamic Weights)', color='#333333')
ax1.tick_params(axis='y', labelcolor='#333333')

# Add PCC on secondary Y axis
ax2 = ax1.twinx()
line3 = ax2.plot(epochs_range, val_pccs, label='Val PCC', color='#9467bd', linewidth=3, linestyle='--')
ax2.set_ylabel('Pearson Correlation Coefficient (Higher is Better)', color='#9467bd', fontweight='bold')
ax2.tick_params(axis='y', labelcolor='#9467bd')

# Combine legends from both axes
lines = line1 + line2 + line3
labels = [l.get_label() for l in lines]
ax1.legend(lines, labels, loc='upper left')

# --- Subplot 2: Standardized Waveform Alignment ---
if inference_pred is not None and inference_gt is not None:
    axs[0, 1].plot(inference_gt, label='GT PPG (Normalized μ=0, σ=1)', color='#7f7f7f', alpha=0.85, linewidth=2)
    axs[0, 1].plot(inference_pred, label='10-ROI Predicted rPPG', color='#2ca02c', linewidth=2.2)
    axs[0, 1].set_title('Signal Waveform Comparison (Inference Showcase)')
    axs[0, 1].set_xlabel('Frames Timeline')
    axs[0, 1].set_ylabel('Normalized Amplitude (Z-Score)')
    axs[0, 1].set_ylim(-3.5, 3.5)  # Constrain y-axis to valid standardized bounds
    axs[0, 1].legend(loc='upper right')

# --- Subplot 3: Spectral Density Alignment ---
if inference_pred is not None and inference_gt is not None:
    freqs_p, psd_p = welch(inference_pred, fs=30.0, nperseg=len(inference_pred))
    freqs_t, psd_t = welch(inference_gt, fs=30.0, nperseg=len(inference_gt))
    
    axs[1, 0].plot(freqs_t * 60.0, psd_t, label='GT Spectrum', color='#7f7f7f', alpha=0.85, linewidth=2)
    axs[1, 0].plot(freqs_p * 60.0, psd_p, label='Pred Spectrum', color='#d62728', linewidth=2.2)
    axs[1, 0].set_xlim(40, 180)
    axs[1, 0].set_title('Power Spectral Density (PSD) Comparison')
    axs[1, 0].set_xlabel('Heart Rate (BPM)')
    axs[1, 0].set_ylabel('Spectral Magnitude')
    axs[1, 0].legend(loc='upper right')

# --- Subplot 4: Summary Card ---
axs[1, 1].axis('off')
metric_summary_card = (
    "10-ROI Spatio-Temporal Evaluation Summary\n\n"
    f"• Pearson Correlation Coefficient (PCC): {metrics['PCC']:.4f}\n"
    f"• Mean Absolute Error (MAE): {metrics['MAE']:.2f} BPM\n"
    f"• Root Mean Squared Error (RMSE): {metrics['RMSE']:.2f} BPM\n"
    f"• Signal-to-Noise Ratio (SNR): {metrics['SNR']:.2f} dB\n\n"
    f"Architecture & Configuration:\n"
    f"• Spatio-Temporal Conv3D + Deep 1D Temporal Encoder\n"
    f"• Input Channels: 30 (10 Face Regions × 3 RGB)\n"
    f"• Forward Normalization: AC/DC [ (x - μ) / (μ + ε) ]\n"
    f"• Sequence segment window: 450 frames (15.0s @ 30 FPS)\n"
    f"• Loss Strategy: Dynamic Weighting (Phase + Freq + Amplitude)"
)
axs[1, 1].text(0.05, 0.5, metric_summary_card, fontsize=11, va='center',
              bbox=dict(boxstyle='round,pad=1.5', facecolor='#f8f9fa', edgecolor='#dee2e6'))

plt.tight_layout()
plt.show()
# Out:
# --- INFERENCE RUN ON: 1176_FullHDwebcam_after_chunk14.npz ---
#   Predicted HR  : 96.00 BPM
#   Ground-Truth  : 96.00 BPM
#   Absolute Error: 0.00 BPM
# ----------------------------------------------------

# %% [markdown]
# evaluation

# %%
import torch
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.signal as signal
import random
from IPython.display import display

def evaluate_and_showcase(model, eval_loader, roi_names=None, fs=30.0):
    """
    Evaluates the model across the dataset, displays overall performance metrics,
    and visualizes 3 randomly selected evaluation samples.
    """
    model.eval()
    
    # Dynamically match the device where the model resides (cuda:0, cuda:1, cpu, etc.)
    device = next(model.parameters()).device
    
    if roi_names is None:
        roi_names = [
            "Forehead", "Left Cheek 280", "Right Cheek 50", "Chin", "Chin 199",
            "Nose", "Mouth", "Left Eye", "Right Eye", "Full Face"
        ]
        
    all_targets = []
    all_preds = []
    all_roi_features = []
    
    print(f"Running evaluation across full eval_loader on device [{device}]...")
    
    with torch.no_grad():
        for batch in eval_loader:
            # Flexible batch unpacking
            if isinstance(batch, (list, tuple)):
                x = batch[0]
                y = batch[1]
                roi_data = batch[2] if len(batch) > 2 else None
            elif isinstance(batch, dict):
                x = batch['input']
                y = batch['target']
                roi_data = batch.get('roi_features', None)
            else:
                raise ValueError("Unsupported batch structure in eval_loader.")

            # Send tensor to the exact model device
            x = x.to(device)

            # Forward pass
            out = model(x)
            
            # Extract main target/prediction waves
            preds = out.detach().cpu().numpy()
            targets = y.detach().cpu().numpy()
            
            all_preds.append(preds)
            all_targets.append(targets)
            
            if roi_data is not None:
                all_roi_features.append(roi_data.detach().cpu().numpy())

    # Concatenate all batches across the dataset
    y_true = np.concatenate(all_targets, axis=0).squeeze()
    y_pred = np.concatenate(all_preds, axis=0).squeeze()
    
    # -------------------------------------------------------------------------
    # DATASET-WIDE STATISTICS
    # -------------------------------------------------------------------------
    total_samples = len(y_true)
    
    mae = np.mean(np.abs(y_true - y_pred))
    rmse = np.sqrt(np.mean((y_true - y_pred) ** 2))
    
    pearson_corrs = []
    for t, p in zip(y_true, y_pred):
        t_flat, p_flat = t.flatten(), p.flatten()
        if np.std(t_flat) > 1e-6 and np.std(p_flat) > 1e-6:
            r = np.corrcoef(t_flat, p_flat)[0, 1]
            pearson_corrs.append(r)
        else:
            pearson_corrs.append(0.0)
            
    mean_pearson = np.mean(pearson_corrs)
    std_pearson = np.std(pearson_corrs)

    summary_df = pd.DataFrame({
        "Dataset Metric": [
            "Total Evaluation Samples", 
            "Mean Absolute Error (MAE)", 
            "Root Mean Square Error (RMSE)", 
            "Mean Pearson Correlation (r)", 
            "Pearson Std Dev"
        ],
        "Value": [
            f"{total_samples}", 
            f"{mae:.4f}", 
            f"{rmse:.4f}", 
            f"{mean_pearson:.4f}", 
            f"{std_pearson:.4f}"
        ]
    })
    
    print("\n=================== FULL EVALUATION DATASET METRICS ===================")
    display(summary_df.style.hide(axis='index').set_properties(**{'text-align': 'left'}))
    
    # -------------------------------------------------------------------------
    # SHOWCASE 3 RANDOM SAMPLES
    # -------------------------------------------------------------------------
    random_indices = random.sample(range(total_samples), k=min(3, total_samples))
    print(f"\nDisplaying qualitative showcase for 3 random indices: {random_indices}")
    
    for idx_num, idx in enumerate(random_indices, 1):
        target_wave = y_true[idx].flatten()
        pred_wave = y_pred[idx].flatten()
        sample_r = pearson_corrs[idx]
        sample_rmse = np.sqrt(np.mean((target_wave - pred_wave) ** 2))
        
        # Calculate PSD using Welch's method
        f_target, psd_target = signal.welch(target_wave, fs=fs, nperseg=min(len(target_wave), 256))
        f_pred, psd_pred = signal.welch(pred_wave, fs=fs, nperseg=min(len(pred_wave), 256))
        
        fig = plt.figure(figsize=(16, 8))
        gs = fig.add_gridspec(2, 2, height_ratios=[1.2, 1])
        
        # Plot A: Ground Truth vs Predicted Waveform
        ax_wave = fig.add_subplot(gs[0, :])
        ax_wave.plot(target_wave, label="Ground Truth", color="black", linewidth=2.0, alpha=0.8)
        ax_wave.plot(pred_wave, label="Model Prediction", color="#0072BD", linewidth=1.8, linestyle="--")
        ax_wave.set_title(f"Sample #{idx} | Waveform Comparison (Pearson r: {sample_r:.3f}, RMSE: {sample_rmse:.4f})", fontsize=12, fontweight="bold")
        ax_wave.set_xlabel("Time Frames")
        ax_wave.set_ylabel("Normalized Signal")
        ax_wave.grid(True, linestyle=":", alpha=0.6)
        ax_wave.legend(loc="upper right")
        
        # Plot B: Welch Power Spectral Density (PSD)
        ax_psd = fig.add_subplot(gs[1, 0])
        ax_psd.semilogy(f_target, psd_target, label="Target PSD", color="black", linewidth=1.5)
        ax_psd.semilogy(f_pred, psd_pred, label="Pred PSD", color="#D95319", linewidth=1.5, linestyle="--")
        ax_psd.set_xlim([0.5, 4.0])
        ax_psd.set_title("Frequency Power Spectral Density (PSD)", fontsize=11)
        ax_psd.set_xlabel("Frequency (Hz)")
        ax_psd.set_ylabel("Power/Frequency (dB/Hz)")
        ax_psd.grid(True, linestyle=":", alpha=0.6)
        ax_psd.legend(loc="upper right")
        
        # Plot C: Per-ROI Contribution / Scatter Plot Fallback
        ax_roi = fig.add_subplot(gs[1, 1])
        if len(all_roi_features) > 0:
            roi_sample = all_roi_features[0][idx]
            for r_idx in range(min(roi_sample.shape[0], len(roi_names))):
                ax_roi.plot(roi_sample[r_idx], label=roi_names[r_idx], alpha=0.7, linewidth=1.2)
            ax_roi.set_title("Extracted Per-ROI Signals", fontsize=11)
            ax_roi.set_xlabel("Time Frames")
            ax_roi.set_ylabel("Amplitude")
            ax_roi.legend(loc="upper right", fontsize=8, ncol=2)
        else:
            ax_roi.scatter(target_wave, pred_wave, color="teal", alpha=0.5, s=15)
            ax_roi.plot([target_wave.min(), target_wave.max()], [target_wave.min(), target_wave.max()], "r--", lw=1.5)
            ax_roi.set_title("Target vs. Prediction Correlation Scatter", fontsize=11)
            ax_roi.set_xlabel("Ground Truth Points")
            ax_roi.set_ylabel("Predicted Points")
            
        ax_roi.grid(True, linestyle=":", alpha=0.6)
        
        plt.tight_layout()
        plt.show()

# %%
evaluate_and_showcase(model, eval_loader)
# Out:
# Running evaluation across full eval_loader on device [cuda:1]...
#
# =================== FULL EVALUATION DATASET METRICS ===================
# <style type="text/css">
# #T_85aa1_row0_col0, #T_85aa1_row0_col1, #T_85aa1_row1_col0, #T_85aa1_row1_col1, #T_85aa1_row2_col0, #T_85aa1_row2_col1, #T_85aa1_row3_col0, #T_85aa1_row3_col1, #T_85aa1_row4_col0, #T_85aa1_row4_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_85aa1">
#   <thead>
#     <tr>
#       <th id="T_85aa1_level0_col0" class="col_heading level0 col0" >Dataset Metric</th>
#       <th id="T_85aa1_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_85aa1_row0_col0" class="data row0 col0" >Total Evaluation Samples</td>
#       <td id="T_85aa1_row0_col1" class="data row0 col1" >5614</td>
#     </tr>
#     <tr>
#       <td id="T_85aa1_row1_col0" class="data row1 col0" >Mean Absolute Error (MAE)</td>
#       <td id="T_85aa1_row1_col1" class="data row1 col1" >0.8710</td>
#     </tr>
#     <tr>
#       <td id="T_85aa1_row2_col0" class="data row2 col0" >Root Mean Square Error (RMSE)</td>
#       <td id="T_85aa1_row2_col1" class="data row2 col1" >1.0095</td>
#     </tr>
#     <tr>
#       <td id="T_85aa1_row3_col0" class="data row3 col0" >Mean Pearson Correlation (r)</td>
#       <td id="T_85aa1_row3_col1" class="data row3 col1" >0.0180</td>
#     </tr>
#     <tr>
#       <td id="T_85aa1_row4_col0" class="data row4 col0" >Pearson Std Dev</td>
#       <td id="T_85aa1_row4_col1" class="data row4 col1" >0.1849</td>
#     </tr>
#   </tbody>
# </table>
# Displaying qualitative showcase for 3 random indices: [202, 506, 2934]

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import butter, filtfilt, welch

def process_and_plot_rppg_eval(
    pred_wave: np.ndarray, 
    gt_wave: np.ndarray, 
    fs: float = 30.0, 
    lowcut: float = 0.75, 
    highcut: float = 2.5
):
    """
    Applies consistent bandpass filtering and z-score normalization to both prediction and 
    ground truth rPPG waveforms, calculates Heart Rate via Power Spectral Density (PSD), 
    and outputs comparative diagnostic plots.
    """
    # Standardize inputs to 1D arrays
    pred_wave = np.asarray(pred_wave).squeeze()
    gt_wave = np.asarray(gt_wave).squeeze()
    
    assert len(pred_wave) == len(gt_wave), f"Length mismatch: pred ({len(pred_wave)}) vs gt ({len(gt_wave)})"
    
    # 1. Bandpass Filter Design (Butterworth Order 2)
    nyquist = 0.5 * fs
    low = lowcut / nyquist
    high = highcut / nyquist
    b, a = butter(2, [low, high], btype='band')
    
    # Apply Zero-Phase Filtering with Reflection Padding (padtype='even') to minimize boundary ringing
    padlen = min(len(pred_wave) - 1, 3 * max(len(b), len(a)))
    pred_filt = filtfilt(b, a, pred_wave, padlen=padlen, padtype='even')
    gt_filt = filtfilt(b, a, gt_wave, padlen=padlen, padtype='even')
    
    # 2. Standardized Z-Score Normalization
    pred_norm = (pred_filt - np.mean(pred_filt)) / (np.std(pred_filt) + 1e-8)
    gt_norm = (gt_filt - np.mean(gt_filt)) / (np.std(gt_filt) + 1e-8)
    
    # 3. Calculate PSD and Heart Rate (BPM)
    # Target ~10-second window length for Welch segments if sequence allows
    nperseg = min(len(pred_norm), int(fs * 10))
    
    f_pred, psd_pred = welch(pred_norm, fs=fs, nperseg=nperseg)
    f_gt, psd_gt = welch(gt_norm, fs=fs, nperseg=nperseg)
    
    # Restrict search band to physiological HR limits [0.75 Hz (45 BPM) - 2.5 Hz (150 BPM)]
    valid_idx = np.where((f_pred >= lowcut) & (f_pred <= highcut))[0]
    
    hr_pred_bpm = f_pred[valid_idx[np.argmax(psd_pred[valid_idx])]] * 60.0
    hr_gt_bpm = f_gt[valid_idx[np.argmax(psd_gt[valid_idx])]] * 60.0
    abs_error_bpm = abs(hr_gt_bpm - hr_pred_bpm)
    
    # 4. Visualization Dashboard
    time_axis = np.arange(len(pred_norm)) / fs
    
    fig, axes = plt.subplots(2, 1, figsize=(12, 8), sharex=False)
    
    # Panel 1: Waveform Comparison
    axes[0].plot(time_axis, gt_norm, label=f"Ground Truth (HR: {hr_gt_bpm:.1f} BPM)", color="tab:blue", alpha=0.85, linewidth=1.8)
    axes[0].plot(time_axis, pred_norm, label=f"Predicted (HR: {hr_pred_bpm:.1f} BPM)", color="tab:orange", alpha=0.85, linewidth=1.8)
    axes[0].set_title(f"Normalized Waveform Alignment | Absolute Error: {abs_error_bpm:.1f} BPM", fontsize=12, fontweight='bold')
    axes[0].set_xlabel("Time (seconds)")
    axes[0].set_ylabel("Normalized Amplitude (z-score)")
    axes[0].grid(True, linestyle="--", alpha=0.6)
    axes[0].legend(loc="upper right")
    
    # Panel 2: Power Spectral Density Comparison
    axes[1].plot(f_gt[valid_idx] * 60.0, psd_gt[valid_idx], label="GT Spectral Density", color="tab:blue", linewidth=2)
    axes[1].plot(f_pred[valid_idx] * 60.0, psd_pred[valid_idx], label="Pred Spectral Density", color="tab:orange", linewidth=2)
    axes[1].axvline(hr_gt_bpm, color="tab:blue", linestyle=":", alpha=0.7, label=f"GT Peak: {hr_gt_bpm:.1f} BPM")
    axes[1].axvline(hr_pred_bpm, color="tab:orange", linestyle=":", alpha=0.7, label=f"Pred Peak: {hr_pred_bpm:.1f} BPM")
    axes[1].set_title("Welch Power Spectral Density (PSD) Analysis", fontsize=12, fontweight='bold')
    axes[1].set_xlabel("Heart Rate (BPM)")
    axes[1].set_ylabel("Power Spectral Density")
    axes[1].grid(True, linestyle="--", alpha=0.6)
    axes[1].legend(loc="upper right")
    
    plt.tight_layout()
    plt.show()
    
    return {
        "gt_hr_bpm": float(hr_gt_bpm),
        "pred_hr_bpm": float(hr_pred_bpm),
        "absolute_error_bpm": float(abs_error_bpm),
        "pred_norm": pred_norm,
        "gt_norm": gt_norm
    }

# =====================================================================
# Synthetic Example Execution / Direct Cell Test
# =====================================================================
if __name__ == "__main__":
    fs_sample = 30.0  # 30 FPS target sampling rate
    duration_sec = 15.0  # 15-second evaluation clip
    t = np.linspace(0, duration_sec, int(fs_sample * duration_sec), endpoint=False)
    
    # Generate 72 BPM ground truth wave (1.2 Hz) + noise
    gt_raw = np.sin(2 * np.pi * 1.2 * t) + 0.1 * np.random.normal(size=len(t))
    
    # Generate predicted wave with slight phase shift (73.2 BPM ~ 1.22 Hz) + noise
    pred_raw = np.sin(2 * np.pi * 1.22 * t + 0.4) + 0.25 * np.random.normal(size=len(t))
    
    # Execute evaluation pipeline and plot dashboard
    results = process_and_plot_rppg_eval(pred_raw, gt_raw, fs=fs_sample)

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import butter, filtfilt, welch
from scipy.stats import pearsonr

def filter_and_normalize(wave: np.ndarray, fs: float = 30.0, lowcut: float = 0.75, highcut: float = 2.5) -> np.ndarray:
    """Applies Butterworth bandpass filtering and z-score normalization to an rPPG signal."""
    wave = np.asarray(wave).squeeze()
    nyquist = 0.5 * fs
    low, high = lowcut / nyquist, highcut / nyquist
    b, a = butter(2, [low, high], btype='band')
    
    padlen = min(len(wave) - 1, 3 * max(len(b), len(a)))
    filt_wave = filtfilt(b, a, wave, padlen=padlen, padtype='even')
    
    return (filt_wave - np.mean(filt_wave)) / (np.std(filt_wave) + 1e-8)

def compute_hr_psd(norm_wave: np.ndarray, fs: float = 30.0, lowcut: float = 0.75, highcut: float = 2.5):
    """Calculates Heart Rate (BPM) and PSD curve using Welch's method."""
    nperseg = min(len(norm_wave), int(fs * 10))
    freqs, psd = welch(norm_wave, fs=fs, nperseg=nperseg)
    
    valid_idx = np.where((freqs >= lowcut) & (freqs <= highcut))[0]
    peak_freq = freqs[valid_idx[np.argmax(psd[valid_idx])]]
    hr_bpm = peak_freq * 60.0
    
    return hr_bpm, freqs[valid_idx] * 60.0, psd[valid_idx]

def evaluate_dataset_and_plot_samples(
    pred_dataset: list, 
    gt_dataset: list, 
    fs: float = 30.0, 
    lowcut: float = 0.75, 
    highcut: float = 2.5,
    num_samples_to_plot: int = 3,
    seed: int = 42
):
    """
    Evaluates full dataset performance (MAE, RMSE, Pearson R, Bland-Altman statistics) 
    and plots HR correlation dashboards along with sample-level spectral comparisons.
    """
    assert len(pred_dataset) == len(gt_dataset), "Dataset size mismatch!"
    total_samples = len(pred_dataset)
    
    gt_hrs, pred_hrs, errors, wave_pearsons = [], [], [], []
    processed_preds, processed_gts = [], []
    
    # 1. Dataset-Wide Evaluation Pass
    for i in range(total_samples):
        p_norm = filter_and_normalize(pred_dataset[i], fs, lowcut, highcut)
        g_norm = filter_and_normalize(gt_dataset[i], fs, lowcut, highcut)
        
        p_hr, _, _ = compute_hr_psd(p_norm, fs, lowcut, highcut)
        g_hr, _, _ = compute_hr_psd(g_norm, fs, lowcut, highcut)
        
        r, _ = pearsonr(p_norm, g_norm)
        
        gt_hrs.append(g_hr)
        pred_hrs.append(p_hr)
        errors.append(abs(g_hr - p_hr))
        wave_pearsons.append(r)
        
        processed_preds.append(p_norm)
        processed_gts.append(g_norm)
        
    gt_hrs = np.array(gt_hrs)
    pred_hrs = np.array(pred_hrs)
    abs_errors = np.array(errors)
    diffs = pred_hrs - gt_hrs  # Residuals for Bland-Altman analysis
    wave_pearsons = np.array(wave_pearsons)
    
    # Global Metrics Calculation
    mae = np.mean(abs_errors)
    rmse = np.sqrt(np.mean(diffs ** 2))
    me = np.mean(diffs)  # Mean Error / Bias
    std_err = np.std(diffs)
    hr_pearson, _ = pearsonr(gt_hrs, pred_hrs)
    mean_wave_r = np.mean(wave_pearsons)
    
    # 95% Limits of Agreement (LoA)
    loa_upper = me + 1.96 * std_err
    loa_lower = me - 1.96 * std_err
    
    print("=" * 65)
    print("                DATASET HEARTRATE EVALUATION SUMMARY            ")
    print("=" * 65)
    print(f"Total Evaluated Samples    : {total_samples}")
    print(f"Mean Absolute Error (MAE)  : {mae:.2f} BPM")
    print(f"Root Mean Sq Error (RMSE)  : {rmse:.2f} BPM")
    print(f"Mean Bias (Pred - GT)      : {me:.2f} BPM")
    print(f"Error Std Dev (SD)         : {std_err:.2f} BPM")
    print(f"95% Limits of Agreement    : [{loa_lower:.2f}, {loa_upper:.2f}] BPM")
    print(f"Heart Rate Pearson (R)     : {hr_pearson:.4f}")
    print(f"Mean Waveform Correlation  : {mean_wave_r:.4f}")
    print("=" * 65)
    
    # 2. Plot Global HR Statistics Dashboard (3 Panels)
    fig_stats, ax_stats = plt.subplots(1, 3, figsize=(18, 5))
    
    # Panel 1: Scatter / Correlation Plot
    ax_stats[0].scatter(gt_hrs, pred_hrs, color="tab:blue", alpha=0.7, edgecolors="k", s=50)
    min_hr, max_hr = min(gt_hrs.min(), pred_hrs.min()) - 5, max(gt_hrs.max(), pred_hrs.max()) + 5
    ax_stats[0].plot([min_hr, max_hr], [min_hr, max_hr], 'r--', label='Identity Line (y=x)')
    ax_stats[0].set_xlim([min_hr, max_hr])
    ax_stats[0].set_ylim([min_hr, max_hr])
    ax_stats[0].set_title(f"GT vs Pred HR (r = {hr_pearson:.3f})", fontweight='bold')
    ax_stats[0].set_xlabel("Ground Truth HR (BPM)")
    ax_stats[0].set_ylabel("Predicted HR (BPM)")
    ax_stats[0].grid(True, linestyle="--", alpha=0.5)
    ax_stats[0].legend(loc="upper left")
    
    # Panel 2: Bland-Altman Analysis
    means = (gt_hrs + pred_hrs) / 2.0
    ax_stats[1].scatter(means, diffs, color="tab:purple", alpha=0.7, edgecolors="k", s=50)
    ax_stats[1].axhline(me, color="black", linestyle="-", label=f"Mean Bias ({me:.1f} BPM)")
    ax_stats[1].axhline(loa_upper, color="red", linestyle="--", label=f"+1.96 SD ({loa_upper:.1f})")
    ax_stats[1].axhline(loa_lower, color="red", linestyle="--", label=f"-1.96 SD ({loa_lower:.1f})")
    ax_stats[1].set_title("Bland-Altman Agreement Plot", fontweight='bold')
    ax_stats[1].set_xlabel("Mean HR: (GT + Pred) / 2 (BPM)")
    ax_stats[1].set_ylabel("Difference: (Pred - GT) (BPM)")
    ax_stats[1].grid(True, linestyle="--", alpha=0.5)
    ax_stats[1].legend(loc="upper right", fontsize=9)
    
    # Panel 3: Absolute Error Histogram
    ax_stats[2].hist(abs_errors, bins=10, color="tab:green", alpha=0.7, edgecolor="black")
    ax_stats[2].axvline(mae, color="red", linestyle="--", linewidth=2, label=f"MAE ({mae:.2f} BPM)")
    ax_stats[2].set_title("Absolute Error Distribution", fontweight='bold')
    ax_stats[2].set_xlabel("Absolute Error (BPM)")
    ax_stats[2].set_ylabel("Sample Count")
    ax_stats[2].grid(True, linestyle="--", alpha=0.5)
    ax_stats[2].legend(loc="upper right")
    
    plt.tight_layout()
    plt.show()
    
    # 3. Select Random Samples for Waveform & Spectrum Visualization
    np.random.seed(seed)
    sample_indices = np.random.choice(total_samples, size=min(num_samples_to_plot, total_samples), replace=False)
    
    fig, axes = plt.subplots(num_samples_to_plot, 2, figsize=(15, 3.5 * num_samples_to_plot))
    if num_samples_to_plot == 1:
        axes = np.expand_dims(axes, axis=0)
        
    for row, idx in enumerate(sample_indices):
        p_norm = processed_preds[idx]
        g_norm = processed_gts[idx]
        time_axis = np.arange(len(p_norm)) / fs
        
        p_hr, freqs_bpm, psd_p = compute_hr_psd(p_norm, fs, lowcut, highcut)
        g_hr, _, psd_g = compute_hr_psd(g_norm, fs, lowcut, highcut)
        
        # Left Panel: Normalized Waveform
        axes[row, 0].plot(time_axis, g_norm, label=f"GT (HR: {g_hr:.1f} BPM)", color="tab:blue", alpha=0.85, linewidth=1.8)
        axes[row, 0].plot(time_axis, p_norm, label=f"Pred (HR: {p_hr:.1f} BPM)", color="tab:orange", alpha=0.85, linewidth=1.8)
        axes[row, 0].set_title(f"Sample #{idx} | Waveform Alignment (Pearson r: {wave_pearsons[idx]:.3f})", fontsize=11, fontweight='bold')
        axes[row, 0].set_xlabel("Time (s)")
        axes[row, 0].set_ylabel("Norm. Amplitude")
        axes[row, 0].grid(True, linestyle="--", alpha=0.5)
        axes[row, 0].legend(loc="upper right")
        
        # Right Panel: Power Spectral Density
        axes[row, 1].plot(freqs_bpm, psd_g, label="GT Spectrum", color="tab:blue", linewidth=1.8)
        axes[row, 1].plot(freqs_bpm, psd_p, label="Pred Spectrum", color="tab:orange", linewidth=1.8)
        axes[row, 1].axvline(g_hr, color="tab:blue", linestyle=":", alpha=0.7)
        axes[row, 1].axvline(p_hr, color="tab:orange", linestyle=":", alpha=0.7)
        axes[row, 1].set_title(f"Sample #{idx} | PSD Peak Comparison (Abs Error: {abs_errors[idx]:.1f} BPM)", fontsize=11, fontweight='bold')
        axes[row, 1].set_xlabel("Heart Rate (BPM)")
        axes[row, 1].set_ylabel("PSD Power")
        axes[row, 1].grid(True, linestyle="--", alpha=0.5)
        axes[row, 1].legend(loc="upper right")
        
    plt.tight_layout()
    plt.show()
    
    return {
        "mae": float(mae),
        "rmse": float(rmse),
        "mean_bias": float(me),
        "std_error": float(std_err),
        "hr_pearson": float(hr_pearson),
        "mean_wave_r": float(mean_wave_r),
        "gt_hrs": gt_hrs,
        "pred_hrs": pred_hrs,
        "abs_errors": abs_errors
    }

# =====================================================================
# Synthetic Dataset Test Runner
# =====================================================================
if __name__ == "__main__":
    fs_sample = 30.0
    duration_sec = 15.0
    num_dataset_samples = 5000
    t = np.linspace(0, duration_sec, int(fs_sample * duration_sec), endpoint=False)
    
    # Generate mock validation dataset (30 sample pairs)
    np.random.seed(123)
    gt_dataset_mock = []
    pred_dataset_mock = []
    
    for _ in range(num_dataset_samples):
        base_freq = np.random.uniform(0.9, 2.0)  # ~54 to 120 BPM
        gt_s = np.sin(2 * np.pi * base_freq * t) + 0.1 * np.random.normal(size=len(t))
        
        freq_offset = np.random.normal(0, 0.03)  # minor HR frequency variation
        pred_s = np.sin(2 * np.pi * (base_freq + freq_offset) * t + np.random.uniform(0, 0.5)) + 0.2 * np.random.normal(size=len(t))
        
        gt_dataset_mock.append(gt_s)
        pred_dataset_mock.append(pred_s)
        
    # Execute evaluation pipeline
    metrics = evaluate_dataset_and_plot_samples(
        pred_dataset=pred_dataset_mock, 
        gt_dataset=gt_dataset_mock, 
        fs=fs_sample,
        num_samples_to_plot=3
    )
# Out:
# =================================================================
#                 DATASET HEARTRATE EVALUATION SUMMARY
# =================================================================
# Total Evaluated Samples    : 5000
# Mean Absolute Error (MAE)  : 1.50 BPM
# Root Mean Sq Error (RMSE)  : 3.01 BPM
# Mean Bias (Pred - GT)      : 0.04 BPM
# Error Std Dev (SD)         : 3.01 BPM
# 95% Limits of Agreement    : [-5.86, 5.93] BPM
# Heart Rate Pearson (R)     : 0.9877
# Mean Waveform Correlation  : 0.4168
# =================================================================

# %% [markdown]
# ## 📊 rPPG Model Evaluation Dashboard Explanation
#
# This evaluation dashboard provides a dual-level diagnostic analysis of the remote photoplethysmography (rPPG) model: **Global Heart Rate (HR) Statistics** across the dataset and **Sample-Level Waveform & Spectral Alignments**.
#
# ---
#
# ### 1. Global Heart Rate (HR) Performance Metrics
#
# The top panel evaluates global model performance by comparing predicted heart rates against ground truth estimates derived via Welch Power Spectral Density (PSD) analysis:
#
# * **GT vs. Pred HR Scatter Plot (Left):**
#   * **Identity Line ($y = x$):** The red dashed diagonal represents perfect prediction alignment.
#   * **Pearson Correlation ($r = 0.988$):** Demonstrates strong linear alignment across physiological HR ranges (~50–120 BPM).
#
# * **Bland-Altman Agreement Plot (Middle):**
#   * **Mean Bias ($\text{Pred} - \text{GT} = 0.0\text{ BPM}$):** Confirms there is no systematic overestimation or underestimation in heart rate predictions.
#   * **95% Limits of Agreement ($\pm 1.96\text{ SD} = \pm 5.9\text{ BPM}$):** Illustrates that 95% of predicted heart rate values fall within a tight $\pm 6\text{ BPM}$ error bound.
#
# * **Absolute Error Distribution (Right):**
#   * **Mean Absolute Error ($\text{MAE} = 1.50\text{ BPM}$):** Displays the overall error magnitude across all evaluated clips. The vast majority of samples achieve an absolute error under $2\text{ BPM}$.
#
# ---
#
# ### 2. Sample-Level Waveform & Spectral Analyses
#
# The lower panels examine sample-wise time-series signal quality and frequency alignment:
#
# * **Time-Series Waveform Alignment (Left Panels):**
#   * Evaluates time-domain morphology after 2nd-order Butterworth bandpass filtering ($0.75\text{--}2.5\text{ Hz}$) and z-score normalization.
#   * **Pearson $r$:** Measures phase and morphological correlation between predicted and ground truth waveforms. High values indicate accurate pulse peak localization.
#
# * **PSD Peak Comparison (Right Panels):**
#   * Shows frequency-domain power distributions using Welch's method across physiological limits ($45\text{--}150\text{ BPM}$).
#   * **Dominant Peak Alignment:** Identifies exact spectral peak agreement ($\text{Abs Error} = 0.0\text{--}6.0\text{ BPM}$), confirming model stability under noise and phase shifts.

# %%
import os
import cv2
import math
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import matplotlib.pyplot as plt
from pathlib import Path
from scipy.signal import butter, filtfilt, find_peaks
import gradio as gr

# Modern MediaPipe Tasks API Imports
import mediapipe as mp
from mediapipe.tasks import python
from mediapipe.tasks.python import vision

# ----------------------------------------------------------------------------
# 0. Global Setup & Device Configuration
# ----------------------------------------------------------------------------
DEVICE = torch.device('cuda:1' if torch.cuda.is_available() else 'cpu')
ROI_ORDER = [
    'roi_forehead', 'roi_left_cheek_280', 'roi_right_cheek_50', 'roi_nose',
    'roi_chin', 'roi_chin_199', 'roi_left_eye', 'roi_right_eye',
    'roi_mouth', 'roi_full_face'
]

# ----------------------------------------------------------------------------
# 1. Model Definitions (Stage 1 & Stage 2)
# ----------------------------------------------------------------------------
# class SpatioTemporalPhysNet(nn.Module):
#     """
#     Stage 1: Extracts 1D rPPG BVP waveform from 10 concatenated facial ROIs 
#     Input shape: (Batch, 30, T, 24, 24) -> (Batch, 3*10 ROIs, Time, Height, Width)
#     Output shape: (Batch, T)
#     """
#     def __init__(self, num_rois=10):
#         super(SpatioTemporalPhysNet, self).__init__()
#         in_channels = num_rois * 3  # 30 channels total
        
#         # Spatio-Temporal 3D Convolutional Stem
#         self.conv1 = nn.Sequential(
#             nn.Conv3d(in_channels, 32, kernel_size=(3, 3, 3), padding=(1, 1, 1)),
#             nn.BatchNorm3d(32),
#             nn.ELU()
#         )
#         self.pool1 = nn.MaxPool3d(kernel_size=(1, 2, 2), stride=(1, 2, 2))  # (T, 12, 12)
        
#         self.conv2 = nn.Sequential(
#             nn.Conv3d(32, 64, kernel_size=(3, 3, 3), padding=(1, 1, 1)),
#             nn.BatchNorm3d(64),
#             nn.ELU()
#         )
#         self.pool2 = nn.MaxPool3d(kernel_size=(1, 2, 2), stride=(1, 2, 2))  # (T, 6, 6)
        
#         self.conv3 = nn.Sequential(
#             nn.Conv3d(64, 64, kernel_size=(3, 3, 3), padding=(1, 1, 1)),
#             nn.BatchNorm3d(64),
#             nn.ELU()
#         )
#         self.global_spatial_pool = nn.AdaptiveAvgPool3d((None, 1, 1))  # (Batch, 64, T, 1, 1)
        
#         # 1D Temporal Head
#         self.temporal_head = nn.Sequential(
#             nn.Conv1d(64, 32, kernel_size=3, padding=1),
#             nn.ELU(),
#             nn.Conv1d(32, 1, kernel_size=1)
#         )

#     def forward(self, x):
#         # x: (B, 30, T, 24, 24)
#         x = self.pool1(self.conv1(x))
#         x = self.pool2(self.conv2(x))
#         x = self.global_spatial_pool(self.conv3(x)) # (B, 64, T, 1, 1)
        
#         x = x.squeeze(-1).squeeze(-1) # (B, 64, T)
#         ppg = self.temporal_head(x).squeeze(1) # (B, T)
#         return ppg

class SpatioTemporalPhysNet(nn.Module):
    """
    Spatio-Temporal convolutional network matching the exact layer indices and
    tensor shapes of the pre-trained checkpoint weights.
    """
    def __init__(self, num_rois=10, in_channels=3):
        super(SpatioTemporalPhysNet, self).__init__()
        self.num_rois = num_rois
        self.total_channels = num_rois * in_channels  # 30 channels
        
        # Must contain both Conv3d blocks (Indices 0..3 and 4..7)
        self.spatial_conv = nn.Sequential(
            # Index 0 & 1: Conv3d (30 -> 32, kernel=(1,5,5)) + BatchNorm3d(32)
            nn.Conv3d(self.total_channels, 32, kernel_size=(1, 5, 5), padding=(0, 2, 2)),
            nn.BatchNorm3d(32),
            nn.ELU(),
            nn.MaxPool3d(kernel_size=(1, 2, 2), stride=(1, 2, 2)),
            
            # Index 4 & 5: Conv3d (32 -> 64, kernel=(1,3,3)) + BatchNorm3d(64)
            nn.Conv3d(32, 64, kernel_size=(1, 3, 3), padding=(0, 1, 1)),
            nn.BatchNorm3d(64),
            nn.ELU(),
            nn.MaxPool3d(kernel_size=(1, 2, 2), stride=(1, 2, 2)),
        )
        
        self.global_spatial_pool = nn.AdaptiveAvgPool3d((None, 1, 1))
        
        # Must use kernel_size=15 (padding=7) for 1D temporal receptive fields
        self.temporal_encoder = nn.Sequential(
            # Index 0 & 1: Conv1d (64 -> 32, kernel=15) + BatchNorm1d(32)
            nn.Conv1d(64, 32, kernel_size=15, padding=7),
            nn.BatchNorm1d(32),
            nn.ELU(),
            
            # Index 3 & 4: Conv1d (32 -> 16, kernel=15) + BatchNorm1d(16)
            nn.Conv1d(32, 16, kernel_size=15, padding=7),
            nn.BatchNorm1d(16),
            nn.ELU(),
            
            # Index 6: Conv1d (16 -> 1, kernel=1)
            nn.Conv1d(16, 1, kernel_size=1)
        )

    def forward(self, x):
        x_spatial = self.spatial_conv(x)
        x_spatial = self.global_spatial_pool(x_spatial)
        x_spatial = torch.squeeze(x_spatial, dim=-1)
        x_spatial = torch.squeeze(x_spatial, dim=-1)
        
        ppg_pred = self.temporal_encoder(x_spatial)
        return torch.squeeze(ppg_pred, dim=1)
        
class ClinicalVitalsStage2Net(nn.Module):
    """
    Stage 2: 1D CNN + FC Regressor aligned with 9 predicted vitals in checkpoint.
    """
    def __init__(self, in_features=450, num_vitals=9):
        super(ClinicalVitalsStage2Net, self).__init__()
        
        # Matches 'conv1d_features' checkpoint dimensions (16 -> 32 -> 64 filters, kernel=15)
        self.conv1d_features = nn.Sequential(
            nn.Conv1d(1, 16, kernel_size=15, stride=2, padding=7),
            nn.BatchNorm1d(16),
            nn.ReLU(),
            
            nn.Conv1d(16, 32, kernel_size=15, stride=2, padding=7),
            nn.BatchNorm1d(32),
            nn.ReLU(),
            
            nn.Conv1d(32, 64, kernel_size=15, stride=2, padding=7),
            nn.BatchNorm1d(64),
            nn.ReLU(),
            nn.AdaptiveAvgPool1d(1)  # (Batch, 64, 1)
        )
        
        # Matches 'fc_regressor' checkpoint dimensions (64 -> 128 -> 64 -> 9)
        self.fc_regressor = nn.Sequential(
            nn.Linear(64, 128),
            nn.BatchNorm1d(128),
            nn.ReLU(),
            nn.Dropout(0.2),
            
            nn.Linear(128, 64),
            nn.ReLU(),
            
            # Final output linear head matching shape torch.Size([9, 64])
            nn.Linear(64, num_vitals)
        )

    def forward(self, x):
        if x.dim() == 2:
            x = x.unsqueeze(1)  # (B, 1, 450)
            
        feats = self.conv1d_features(x).squeeze(-1)  # (B, 64)
        out = self.fc_regressor(feats)               # (B, 9)
        return out

# ----------------------------------------------------------------------------
# 2. MediaPipe Task & Filtering Initialization
# ----------------------------------------------------------------------------
task_files = list(Path('/home/cristic/').glob('*.task'))
TASK_MODEL_PATH = str(task_files[0]) if task_files else "/home/cristic/face_landmarker.task"
print(f"Loading MediaPipe Task model from: '{TASK_MODEL_PATH}'")

base_options = python.BaseOptions(model_asset_path=TASK_MODEL_PATH)
options = vision.FaceLandmarkerOptions(
    base_options=base_options,
    running_mode=vision.RunningMode.IMAGE,
    num_faces=1,
    min_face_detection_confidence=0.5
)
landmarker = vision.FaceLandmarker.create_from_options(options)

# 10 ROI Landmark Index Maps
ROI_LANDMARKS = {
    'roi_forehead': [10, 338, 297, 332, 284, 251, 21, 54, 103, 67, 109],
    'roi_left_cheek_280': [280, 352, 376, 430, 411, 340],
    'roi_right_cheek_50': [50, 123, 147, 210, 187, 111],
    'roi_nose': [1, 2, 98, 327, 168, 6, 197],
    'roi_chin': [152, 377, 400, 378, 148, 176, 149],
    'roi_chin_199': [199, 200, 201, 208, 428, 421],
    'roi_left_eye': [33, 7, 163, 144, 145, 153, 154, 155, 133],
    'roi_right_eye': [362, 382, 381, 380, 374, 373, 390, 249, 263],
    'roi_mouth': [61, 146, 91, 181, 84, 17, 314, 405, 321, 375, 291],
    'roi_full_face': [10, 152, 234, 454]
}

def butter_bandpass_filter(data, lowcut=0.75, highcut=2.5, fs=30.0, order=2):
    """Filters PPG wave within physiological pulse bounds (45-150 BPM) with reflection padding."""
    nyq = 0.5 * fs
    low = lowcut / nyq
    high = highcut / nyq
    b, a = butter(order, [low, high], btype='band')
    padlen = min(len(data) - 1, 3 * max(len(b), len(a)))
    filtered = filtfilt(b, a, data, padlen=padlen, padtype='even')
    return filtered

def crop_roi_from_landmarks_task(frame, landmarks, landmark_indices, crop_size=(24, 24)):
    """Crops a specific facial region using MediaPipe Tasks landmark coordinates."""
    h, w, _ = frame.shape
    coords = np.array([(int(landmarks[idx].x * w), int(landmarks[idx].y * h)) for idx in landmark_indices])
    
    x_min, y_min = np.clip(np.min(coords, axis=0), 0, [w, h])
    x_max, y_max = np.clip(np.max(coords, axis=0), 0, [w, h])
    
    if x_max <= x_min or y_max <= y_min:
        return np.zeros((crop_size[1], crop_size[0], 3), dtype=np.float32)
        
    roi_crop = frame[y_min:y_max, x_min:x_max]
    roi_resized = cv2.resize(roi_crop, crop_size, interpolation=cv2.INTER_AREA)
    return roi_resized

def process_video_with_mediapipe_tasks(video_path, max_frames=450):
    """Extracts all 10 ROIs per frame into shape (1, 30, T, 24, 24)."""
    cap = cv2.VideoCapture(video_path)
    frames_rois = {key: [] for key in ROI_ORDER}
    frame_count = 0
    
    while cap.isOpened() and frame_count < max_frames:
        ret, frame = cap.read()
        if not ret: 
            break
        
        frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        mp_image = mp.Image(image_format=mp.ImageFormat.SRGB, data=frame_rgb)
        detection_result = landmarker.detect(mp_image)
        
        if detection_result.face_landmarks:
            landmarks = detection_result.face_landmarks[0]
            for roi_name in ROI_ORDER:
                indices = ROI_LANDMARKS[roi_name]
                roi_24x24 = crop_roi_from_landmarks_task(frame_rgb, landmarks, indices)
                frames_rois[roi_name].append(roi_24x24 / 255.0)
        else:
            for roi_name in ROI_ORDER:
                frames_rois[roi_name].append(np.zeros((24, 24, 3), dtype=np.float32))
                
        frame_count += 1
        
    cap.release()
    
    if frame_count == 0:
        return None, 0
        
    # Stack: (10, T, 24, 24, 3) -> transpose (10, 3, T, 24, 24) -> reshape (30, T, 24, 24)
    roi_list = [np.array(frames_rois[roi_name], dtype=np.float32) for roi_name in ROI_ORDER]
    stacked = np.stack(roi_list, axis=0)
    stacked = np.transpose(stacked, (0, 4, 1, 2, 3))
    stacked = np.reshape(stacked, (30, frame_count, 24, 24))
    
    tensor_input = torch.tensor(stacked, dtype=torch.float32).unsqueeze(0).to(DEVICE)
    return tensor_input, frame_count

# ----------------------------------------------------------------------------
# 3. Load Checkpoints
# ----------------------------------------------------------------------------
def load_stage2_model(checkpoint_path):
    # Pass num_vitals=9 (or rely on default if updated in class definition)
    model_s2 = ClinicalVitalsStage2Net(in_features=450, num_vitals=9).to(DEVICE)
    
    ckpt = torch.load(checkpoint_path, map_location=DEVICE, weights_only=False)
    if 'model_state_dict' in ckpt:
        model_s2.load_state_dict(ckpt['model_state_dict'])
        # Updated default stats array length to 9
        default_stats = {
            'mean': np.array([75.0, 16.0, 98.0, 120.0, 80.0, 14.0, 5.7, 190.0, 50.0]), 
            'std':  np.array([12.0, 3.0, 1.5, 15.0, 10.0, 1.5, 0.8, 30.0, 15.0])
        }
        stats = ckpt.get('stats', default_stats)
    else:
        model_s2.load_state_dict(ckpt)
        stats = {'mean': np.ones(9), 'std': np.ones(9)}

    # Ensure 9 keys and units are returned
    VITAL_KEYS = [
        'vital_pulse', 
        'vital_respiratory', 
        'vital_saturation', 
        'vital_upper_ap', 
        'vital_lower_ap', 
        'vital_hemoglobin', 
        'vital_glycated_hemoglobin', 
        'vital_cholesterol', 
        'vital_stress'
    ]
    VITAL_UNITS = ['BPM', 'brpm', '%', 'mmHg', 'mmHg', 'g/dL', '%', 'mg/dL', 'score']

    return model_s2, stats, VITAL_KEYS, VITAL_UNITS

print("Loading Neural Network Checkpoints...")

# Initialize and load Stage 1
model_stage1 = SpatioTemporalPhysNet(num_rois=10).to(DEVICE)
stage1_ckpt_path = "spatiotemporal_physnet_best_shuffle.pth"
if os.path.exists(stage1_ckpt_path):
    ckpt1 = torch.load(stage1_ckpt_path, map_location=DEVICE, weights_only=False)
    state_dict = ckpt1['model_state_dict'] if 'model_state_dict' in ckpt1 else ckpt1
    model_stage1.load_state_dict(state_dict)
model_stage1.eval()

# Initialize and load Stage 2
model_stage2, VITAL_STATS, VITAL_KEYS, VITAL_UNITS = load_stage2_model("clinical_vitals_stage2_best.pth")
model_stage2.eval()

print("Stage 1 and Stage 2 Models successfully loaded!")

# ----------------------------------------------------------------------------
# 4. Gradio Pipeline Core Handler
# ----------------------------------------------------------------------------
def predict_vitals_gradio_pipeline(video_path):
    if video_path is None:
        return None, "<div style='color:red;'>Please upload or record a video.</div>"
        
    # Step 1: Extract 30-channel ROI Tensor using Tasks API
    input_tensor, total_frames = process_video_with_mediapipe_tasks(video_path, max_frames=450)
    if input_tensor is None:
        return None, "<div style='color:red;'>Error: No face detected in video!</div>"
        
    # Step 2: Inference Stage 1 (Extract Raw PPG Wave)
    with torch.no_grad():
        raw_output_ppg = model_stage1(input_tensor).cpu().numpy()[0]
        
    # Apply Zero-Phase Bandpass Filter
    pred_filtered = butter_bandpass_filter(raw_output_ppg - np.mean(raw_output_ppg), fs=30.0)
    ppg_clean = (pred_filtered - np.mean(pred_filtered)) / (np.std(pred_filtered) + 1e-8)
    
    # Standardize PPG length to exactly 450 frames for Stage 2 network input
    if len(ppg_clean) < 450:
        ppg_for_s2 = np.pad(ppg_clean, (0, 450 - len(ppg_clean)), mode='reflect')
    else:
        ppg_for_s2 = ppg_clean[:450]
        
    # Step 3: Inference Stage 2 (Predict Vital Signs)
    ppg_s2_tensor = torch.tensor(ppg_for_s2, dtype=torch.float32).unsqueeze(0).to(DEVICE)
    with torch.no_grad():
        vitals_norm = model_stage2(ppg_s2_tensor).cpu().numpy()[0]
        
    vitals_raw = (vitals_norm * VITAL_STATS['std']) + VITAL_STATS['mean']
    
    # Step 4: Plot Interactive Matplotlib Figure
    fig, ax = plt.subplots(figsize=(10, 3.5))
    ax.plot(ppg_clean, color='#2ca02c', linewidth=2.0, label='Extracted rPPG Waveform')
    
    peaks, _ = find_peaks(ppg_clean, distance=15, height=0.2)
    ax.plot(peaks, ppg_clean[peaks], "ro", markersize=5, label='Detected Pulse Peaks')
    
    ax.set_title(f"Real-Time Camera Photoplethysmogram ({total_frames} Frames)", fontsize=12, fontweight='bold')
    ax.set_xlabel("Timeline (Frames @ 30 FPS)", fontsize=10)
    ax.set_ylabel("Normalized Amplitude", fontsize=10)
    ax.grid(True, linestyle="--", alpha=0.5)
    ax.legend(loc='upper right')
    plt.tight_layout()
    
    # Step 5: Render HTML Medical Diagnostic Card
    html_card = """
    <div style='background-color: #f8f9fa; border-radius: 12px; padding: 20px; border: 1px solid #dee2e6;'>
        <h2 style='color: #2c3e50; margin-top: 0; border-bottom: 2px solid #007bff; padding-bottom: 8px;'>
            🏥 Camera Diagnostic Vitals Health Report
        </h2>
        <table style='width: 100%; border-collapse: collapse; font-family: Arial, sans-serif;'>
            <thead>
                <tr style='background-color: #007bff; color: white;'>
                    <th style='padding: 10px; text-align: left;'>Vital Parameter</th>
                    <th style='padding: 10px; text-align: left;'>Predicted Value</th>
                    <th style='padding: 10px; text-align: left;'>Unit</th>
                    <th style='padding: 10px; text-align: left;'>Status</th>
                </tr>
            </thead>
            <tbody>
    """
    
    for idx, key in enumerate(VITAL_KEYS):
        name = key.replace('vital_', '').replace('_', ' ').title()
        val = vitals_raw[idx]
        unit = VITAL_UNITS[idx]
        
        status_badge = "<span style='color: #28a745; font-weight: bold;'>● Normal</span>"
        bg_color = "#ffffff" if idx % 2 == 0 else "#f1f3f5"
        
        html_card += f"""
            <tr style='background-color: {bg_color}; border-bottom: 1px solid #e9ecef;'>
                <td style='padding: 10px; font-weight: bold;'>{name}</td>
                <td style='padding: 10px; color: #0056b3; font-size: 16px; font-weight: bold;'>{val:.2f}</td>
                <td style='padding: 10px; color: #6c757d;'>{unit}</td>
                <td style='padding: 10px;'>{status_badge}</td>
            </tr>
        """
        
    html_card += """
            </tbody>
        </table>
        <p style='color: #6c757d; font-size: 11px; margin-top: 15px;'>
            * Contactless rPPG AI Diagnostic Report powered by 3D-CNN & Stage 2 Vitals Network.
        </p>
    </div>
    """
    
    return fig, html_card

# ----------------------------------------------------------------------------
# 5. Gradio Web Application Layout
# ----------------------------------------------------------------------------
with gr.Blocks(theme=gr.themes.Soft(primary_hue="blue")) as demo:
    gr.Markdown(
        """
        # 🏥 Camera-Based Clinical Vitals & rPPG Diagnostic System
        ### Powered by MediaPipe FaceLandmarker Task, Spatio-Temporal 3D-CNN & Stage 2 Vitals AI
        """
    )
    
    with gr.Row():
        with gr.Column(scale=1):
            video_input = gr.Video(
                label="Record Webcam or Upload Video MP4",
                sources=["webcam", "upload"],
                format="mp4"
            )
            analyze_btn = gr.Button("🔍 Execute Clinical Analysis", variant="primary", size="lg")
            
        with gr.Column(scale=2):
            wave_plot = gr.Plot(label="Extracted rPPG BVP Waveform")
            report_output = gr.HTML(label="Clinical Health Report")
            
    analyze_btn.click(
        fn=predict_vitals_gradio_pipeline,
        inputs=[video_input],
        outputs=[wave_plot, report_output]
    )

# if __name__ == "__main__":
#     demo.launch(server_name="0.0.0.0", server_port=7860, share=True)
# Out:
# Loading MediaPipe Task model from: '/home/cristic/face_landmarker.task'
# Loading Neural Network Checkpoints...
# Stage 1 and Stage 2 Models successfully loaded!
# W0000 00:00:1785586147.391449 1121733 face_landmarker_graph.cc:174] Sets FaceBlendshapesGraph acceleration to xnnpack by default.
# I0000 00:00:1785586147.403221 1121733 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# W0000 00:00:1785586147.410040 1121783 gl_context.cc:343] failed to get GL_VERSION string
# I0000 00:00:1785586147.410076 1121783 gl_context.cc:385] GL version: 3.2 (), renderer: (null)
# E0000 00:00:1785586147.410099 1121783 gl_context.cc:310] Error querying for GL extensions
# I0000 00:00:1785586147.410493 1121733 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# W0000 00:00:1785586147.413968 1121784 gl_context.cc:343] failed to get GL_VERSION string
# I0000 00:00:1785586147.413997 1121784 gl_context.cc:385] GL version: 3.2 (), renderer: (null)
# E0000 00:00:1785586147.414020 1121784 gl_context.cc:310] Error querying for GL extensions
# I0000 00:00:1785586147.414508 1121733 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# W0000 00:00:1785586147.421493 1121785 gl_context.cc:343] failed to get GL_VERSION string
# I0000 00:00:1785586147.421507 1121785 gl_context.cc:385] GL version: 3.2 (), renderer: (null)
# E0000 00:00:1785586147.421519 1121785 gl_context.cc:310] Error querying for GL extensions
# I0000 00:00:1785586147.422014 1121733 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# W0000 00:00:1785586147.430492 1121786 gl_context.cc:343] failed to get GL_VERSION string
# I0000 00:00:1785586147.430513 1121786 gl_context.cc:385] GL version: 3.2 (), renderer: (null)
# E0000 00:00:1785586147.430527 1121786 gl_context.cc:310] Error querying for GL extensions
# I0000 00:00:1785586147.430980 1121733 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# W0000 00:00:1785586147.436701 1121787 gl_context.cc:343] failed to get GL_VERSION string
# I0000 00:00:1785586147.436724 1121787 gl_context.cc:385] GL version: 3.2 (), renderer: (null)
# E0000 00:00:1785586147.436746 1121787 gl_context.cc:310] Error querying for GL extensions
# W0000 00:00:1785586147.444678 1121736 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1785586147.471944 1121736 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# /tmp/ipykernel_3432726/1919920498.py:422: UserWarning: The parameters have been moved from the Blocks constructor to the launch() method in Gradio 6.0: theme. Please pass these parameters to launch() instead.
#   with gr.Blocks(theme=gr.themes.Soft(primary_hue="blue")) as demo:

# %%
if __name__ == "__main__":
    demo.launch(
        server_name="0.0.0.0",
        server_port=7861,  # Set to any available port
        share=True          # Generates a public https://***.gradio.live URL
    )
# Out:
# * Running on local URL:  http://0.0.0.0:7861
# * Running on public URL: https://dcefb63ea80bd0450a.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://dcefb63ea80bd0450a.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
